# %% [markdown]
# # GREMIO X CORINTHIANS DATA ANALYSIS

# %% [markdown]
# The objective of this analyisis is to work on data of brazilian football match between Gremio and Corinthians, played on 2020 August 15th, and understand how data from the match can explain the result of the match

# %% [markdown]
# Find the commented video analysis for this match on my youtube channel, here: https://youtu.be/8o6lAGcCGfk

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/teams/league/1396", headers=headers)

res = conn.getresponse()
data = res.read()


team=json.loads(data.decode("utf-8"))
team
# Out:
# {'api': {'results': 20,
#   'teams': [{'team_id': 127,
#     'name': 'Flamengo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/127.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1895,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 1062,
#     'name': 'Atletico-MG',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/1062.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1908,
#     'venue_name': 'Estádio Raimundo Sampaio',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Ismênia Tunes, Bairro Horto',
#     'venue_city': 'Belo Horizonte, Minas Gerais',
#     'venue_capacity': 23018},
#    {'team_id': 120,
#     'name': 'Botafogo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/120.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1904,
#     'venue_name': 'Estádio Nilton Santos',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Arquias Cordeiro, Engenho de Dentro',
#     'venue_city': 'Rio de Janeiro',
#     'venue_capacity': 46931},
#    {'team_id': 118,
#     'name': 'Bahia',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/118.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1931,
#     'venue_name': 'Arena Fonte Nova',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Lions Club, Nazaré',
#     'venue_city': 'Salvador, Bahia',
#     'venue_capacity': 56500},
#    {'team_id': 121,
#     'name': 'Palmeiras',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/121.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Allianz Parque',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Turiaçu 1840, Perdizes',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 43713},
#    {'team_id': 133,
#     'name': 'Vasco DA Gama',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/133.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1898,
#     'venue_name': 'Estádio Club de Regatas Vasco da Gama',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Gal Almério de Moura 131, Bairro Vasco da Gama',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 22076},
#    {'team_id': 128,
#     'name': 'Santos',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/128.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1912,
#     'venue_name': 'Nickerie Stadion',
#     'venue_surface': 'grass',
#     'venue_address': 'F. O. Lashleystraat',
#     'venue_city': 'Nieuw Nickerie',
#     'venue_capacity': 3400},
#    {'team_id': 794,
#     'name': 'Bragantino',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/794.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1928,
#     'venue_name': 'Estádio Nabi Abi Chedid',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Emílio Coleta',
#     'venue_city': 'Bragança Paulista, São Paulo',
#     'venue_capacity': 17128},
#    {'team_id': 131,
#     'name': 'Corinthians',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/131.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1910,
#     'venue_name': 'Arena Corinthians',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Miguel Inácio Curi, 111, Vila Carmosina, Itaquera',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 47605},
#    {'team_id': 144,
#     'name': 'Atletico Goianiense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/144.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1937,
#     'venue_name': 'Estádio Antônio Accioly',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Perimetral 923 / Avenida 24 de Outubro, Bairro Campinas',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10525},
#    {'team_id': 130,
#     'name': 'Gremio',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/130.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1903,
#     'venue_name': 'Arena do Grêmio',
#     'venue_surface': 'grass',
#     'venue_address': 'Bairro Humaitá',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 60540},
#    {'team_id': 124,
#     'name': 'Fluminense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/124.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1902,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 123,
#     'name': 'Sport Recife',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/123.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1905,
#     'venue_name': 'Estádio Adelmar da Costa Carvalho',
#     'venue_surface': 'grass',
#     'venue_address': 'Praça da Bandeira',
#     'venue_city': 'Recife, Pernambuco',
#     'venue_capacity': 32983},
#    {'team_id': 129,
#     'name': 'Ceara',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/129.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 147,
#     'name': 'Coritiba',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/147.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio Major Antônio Couto Pereira',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Ubaldino do Amaral 37, Bairro Alto da Glória',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 45563},
#    {'team_id': 119,
#     'name': 'Internacional',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/119.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio José Pinheiro Borda',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 50128},
#    {'team_id': 154,
#     'name': 'Fortaleza EC',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/154.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1918,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 134,
#     'name': 'Atletico Paranaense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/134.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1924,
#     'venue_name': 'Estádio Joaquim Américo Guimarães',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Buenos Aires 1260, Água Verde',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 43981},
#    {'team_id': 151,
#     'name': 'Goias',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/151.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1943,
#     'venue_name': 'Estádio de Hailé Pinheiro',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Edmundo Pinheiro de Abreu 721, Setor Bela Vista',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10000},
#    {'team_id': 126,
#     'name': 'Sao Paulo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/126.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1930,
#     'venue_name': 'Estádio Cícero Pompeu de Toledo (Morumbi)',
#     'venue_surface': 'grass',
#     'venue_address': 'Praca Roberto Gomes Pedrosa 1, Morumbi',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 73501}]}}

# %%
#find last fixture
import http.client
import json
import pandas as pd
import numpy as np

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/fixtures/team/130/last/1", headers=headers)

res = conn.getresponse()
data = res.read()

fix=json.loads(data.decode("utf-8"))
with open('20200815_gre_cor_fix.txt','w') as outfile:
    json.dump(fix,outfile)
fix
# Out:
# {'api': {'results': 1,
#   'fixtures': [{'fixture_id': 328010,
#     'league_id': 1396,
#     'league': {'name': 'Serie A',
#      'country': 'Brazil',
#      'logo': 'https://media.api-sports.io/football/leagues/71.png',
#      'flag': 'https://media.api-sports.io/flags/br.svg'},
#     'event_date': '2020-08-15T22:00:00+00:00',
#     'event_timestamp': 1597528800,
#     'firstHalfStart': 1597528800,
#     'secondHalfStart': 1597532400,
#     'round': 'Regular Season - 3',
#     'status': 'Match Finished',
#     'statusShort': 'FT',
#     'elapsed': 90,
#     'venue': 'Arena do Grêmio',
#     'referee': 'Bruno Arleu de Araujo, Brazil',
#     'homeTeam': {'team_id': 130,
#      'team_name': 'Gremio',
#      'logo': 'https://media.api-sports.io/football/teams/130.png'},
#     'awayTeam': {'team_id': 131,
#      'team_name': 'Corinthians',
#      'logo': 'https://media.api-sports.io/football/teams/131.png'},
#     'goalsHomeTeam': 0,
#     'goalsAwayTeam': 0,
#     'score': {'halftime': '0-0',
#      'fulltime': '0-0',
#      'extratime': None,
#      'penalty': None}}]}}

# %%
#Request statistical data from fixture
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/statistics/fixture/328010/", headers=headers)

res = conn.getresponse()
data = res.read()

match=json.loads(data.decode("utf-8"))
with open('20200815_gre_cor_fixstat.txt','w') as outfile:
    json.dump(fix,outfile)
match
# Out:
# {'api': {'results': 16,
#   'statistics': {'Shots on Goal': {'home': '8', 'away': '2'},
#    'Shots off Goal': {'home': '8', 'away': '2'},
#    'Total Shots': {'home': '23', 'away': '5'},
#    'Blocked Shots': {'home': '7', 'away': '1'},
#    'Shots insidebox': {'home': '16', 'away': '4'},
#    'Shots outsidebox': {'home': '7', 'away': '1'},
#    'Fouls': {'home': '16', 'away': '14'},
#    'Corner Kicks': {'home': '6', 'away': '5'},
#    'Offsides': {'home': None, 'away': None},
#    'Ball Possession': {'home': '47%', 'away': '53%'},
#    'Yellow Cards': {'home': '2', 'away': '3'},
#    'Red Cards': {'home': None, 'away': None},
#    'Goalkeeper Saves': {'home': '2', 'away': '7'},
#    'Total passes': {'home': '486', 'away': '568'},
#    'Passes accurate': {'home': '424', 'away': '500'},
#    'Passes %': {'home': '87%', 'away': '88%'}}}}

# %%
#Request statistical data from players on fixture
import http.client
import json

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/players/fixture/328010", headers=headers)

res = conn.getresponse()
data = res.read()

match_palyers=json.loads(data.decode("utf-8"))
with open('202000815_gre_cor_plrstats.txt','w') as outfile:
    json.dump(match_palyers,outfile)
match_palyers
# Out:
# {'api': {'results': 30,
#   'players': [{'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 9977,
#     'player_name': 'Vanderlei',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 27,
#     'position': 'G',
#     'rating': '6.9',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 2},
#     'passes': {'total': 10, 'key': 0, 'accuracy': 71},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 2485,
#     'player_name': 'Luis Orejuela',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 17,
#     'position': 'D',
#     'rating': '6.5',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 40, 'key': 0, 'accuracy': 87},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 9, 'won': 1},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 3},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10485,
#     'player_name': 'Pedro Geromel',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 3,
#     'position': 'D',
#     'rating': '7.2',
#     'minutes_played': 97,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 35, 'key': 3, 'accuracy': 94},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 2},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 2466,
#     'player_name': 'Walter Kannemann',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 4,
#     'position': 'D',
#     'rating': '7.0',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 18, 'key': 0, 'accuracy': 81},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 11, 'won': 7},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10480,
#     'player_name': 'Bruno Cortêz',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 12,
#     'position': 'D',
#     'rating': '7.2',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 44, 'key': 0, 'accuracy': 89},
#     'tackles': {'total': 4, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 8, 'won': 6},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10494,
#     'player_name': 'Matheuzinho',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 7,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 48, 'key': 2, 'accuracy': 85},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 16, 'won': 7},
#     'dribbles': {'attempts': 9, 'success': 6, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 3},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10498,
#     'player_name': 'Maicon',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 8,
#     'position': 'M',
#     'rating': '7.6',
#     'minutes_played': 84,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 74, 'key': 3, 'accuracy': 93},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 5},
#     'dribbles': {'attempts': 3, 'success': 3, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10501,
#     'player_name': 'Alisson',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 23,
#     'position': 'M',
#     'rating': '7.3',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 5, 'on': 4},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 45, 'key': 1, 'accuracy': 84},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 22, 'won': 12},
#     'dribbles': {'attempts': 9, 'success': 5, 'past': 3},
#     'fouls': {'drawn': 3, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10491,
#     'player_name': 'Jean Pyerre',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 21,
#     'position': 'M',
#     'rating': '8.0',
#     'minutes_played': 80,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 4, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 46, 'key': 3, 'accuracy': 92},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 13, 'won': 9},
#     'dribbles': {'attempts': 5, 'success': 4, 'past': 1},
#     'fouls': {'drawn': 2, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 80262,
#     'player_name': 'Pepê',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 25,
#     'position': 'M',
#     'rating': '7.2',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 7, 'on': 3},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 24, 'key': 2, 'accuracy': 70},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 15, 'won': 7},
#     'dribbles': {'attempts': 7, 'success': 2, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10072,
#     'player_name': 'Diego Souza',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 29,
#     'position': 'F',
#     'rating': '7.2',
#     'minutes_played': 86,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 3, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 12, 'key': 2, 'accuracy': 70},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 16, 'won': 11},
#     'dribbles': {'attempts': 5, 'success': 5, 'past': 1},
#     'fouls': {'drawn': 2, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 1,
#      'commited': 0,
#      'success': 0,
#      'missed': 1,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10492,
#     'player_name': 'Thaciano',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 20,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 11,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 4, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 80536,
#     'player_name': 'Isaque',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 46,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 17,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 10, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 4, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10102,
#     'player_name': 'Lucas Silva',
#     'team_id': 130,
#     'team_name': 'Gremio',
#     'number': 16,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 13,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 14, 'key': 0, 'accuracy': 93},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 2, 'won': 1},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10229,
#     'player_name': 'Cássio',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 12,
#     'position': 'G',
#     'rating': '8.2',
#     'minutes_played': 97,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 7},
#     'passes': {'total': 28, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10236,
#     'player_name': 'Michel',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 2,
#     'position': 'D',
#     'rating': '6.7',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 44, 'key': 0, 'accuracy': 91},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 8, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 1,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 12744,
#     'player_name': 'Gil',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 4,
#     'position': 'D',
#     'rating': '8.0',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 56, 'key': 0, 'accuracy': 87},
#     'tackles': {'total': 4, 'blocks': 3, 'interceptions': 1},
#     'duels': {'total': 6, 'won': 4},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10230,
#     'player_name': 'Danilo Avelar',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 35,
#     'position': 'D',
#     'rating': '7.0',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 38, 'key': 0, 'accuracy': 90},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 3},
#     'duels': {'total': 10, 'won': 3},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 2162,
#     'player_name': 'Sidcley',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 16,
#     'position': 'D',
#     'rating': '7.5',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 37, 'key': 3, 'accuracy': 90},
#     'tackles': {'total': 3, 'blocks': 1, 'interceptions': 3},
#     'duels': {'total': 10, 'won': 5},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 3},
#     'fouls': {'drawn': 2, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10247,
#     'player_name': 'Gabriel Girotto',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 5,
#     'position': 'M',
#     'rating': '7.0',
#     'minutes_played': 91,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 62, 'key': 0, 'accuracy': 92},
#     'tackles': {'total': 6, 'blocks': 2, 'interceptions': 2},
#     'duels': {'total': 17, 'won': 7},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 6},
#     'fouls': {'drawn': 1, 'committed': 3},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 13580,
#     'player_name': 'Victor Cantillo',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 24,
#     'position': 'M',
#     'rating': '7.2',
#     'minutes_played': 91,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 70, 'key': 0, 'accuracy': 95},
#     'tackles': {'total': 6, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 17, 'won': 10},
#     'dribbles': {'attempts': 2, 'success': 2, 'past': 3},
#     'fouls': {'drawn': 2, 'committed': 3},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10241,
#     'player_name': 'Mateus Vital',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 22,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 36,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 10, 'key': 1, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10502,
#     'player_name': 'Luan',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 7,
#     'position': 'M',
#     'rating': '6.9',
#     'minutes_played': 80,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 53, 'key': 1, 'accuracy': 86},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 9, 'won': 4},
#     'dribbles': {'attempts': 3, 'success': 2, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10249,
#     'player_name': 'Ramiro',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 8,
#     'position': 'M',
#     'rating': '7.3',
#     'minutes_played': 80,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 56, 'key': 0, 'accuracy': 88},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 9, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 2},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 32906,
#     'player_name': 'Jô',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 77,
#     'position': 'F',
#     'rating': '6.9',
#     'minutes_played': 97,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 16, 'key': 0, 'accuracy': 76},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 0},
#     'duels': {'total': 8, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 267862,
#     'player_name': 'Ruan Oliveira',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 36,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 17,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 2, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 5, 'won': 3},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10097,
#     'player_name': 'Éderson',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 15,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 17,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 2, 'key': 0, 'accuracy': 66},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10131,
#     'player_name': 'Camacho',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 20,
#     'position': 'M',
#     'rating': '–',
#     'minutes_played': 6,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 3, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 10239,
#     'player_name': 'Ángelo Araos',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 21,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 61,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 23, 'key': 0, 'accuracy': 65},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 9, 'won': 3},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 3},
#     'fouls': {'drawn': 2, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328010,
#     'updateAt': 1597561815,
#     'player_id': 15303,
#     'player_name': 'Léo Natel',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'number': 18,
#     'position': 'M',
#     'rating': '–',
#     'minutes_played': 6,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 0, 'key': 0, 'accuracy': 0},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 4, 'won': 1},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}}]}}

# %%
times = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
gols = [fix['api']['fixtures'][0]['goalsHomeTeam'],fix['api']['fixtures'][0]['goalsAwayTeam']]
posse = [match['api']['statistics']['Ball Possession']['home'],match['api']['statistics']['Ball Possession']['away']]
chutes = [match['api']['statistics']['Total Shots']['home'],match['api']['statistics']['Total Shots']['away']]
chutes_a_gol = [int(chutes[0])-int(match['api']['statistics']['Shots off Goal']['home'])-int(match['api']['statistics']['Blocked Shots']['home']),
               int(chutes[1])-int(match['api']['statistics']['Shots off Goal']['away'])-int(match['api']['statistics']['Blocked Shots']['away'])]
amarelos = [match['api']['statistics']['Yellow Cards']['home'],match['api']['statistics']['Yellow Cards']['away']]
vermelhos = [match['api']['statistics']['Red Cards']['home'],match['api']['statistics']['Red Cards']['away']]
acerto_passes = [match['api']['statistics']['Passes %']['home'],match['api']['statistics']['Passes %']['away']]
chutes_dentro_area = [match['api']['statistics']['Shots insidebox']['home'],match['api']['statistics']['Shots insidebox']['away']]
chutes_fora_area = [match['api']['statistics']['Shots outsidebox']['home'],match['api']['statistics']['Shots outsidebox']['away']]
faltas = [match['api']['statistics']['Fouls']['home'],match['api']['statistics']['Fouls']['away']]
defesas_goleiro = [match['api']['statistics']['Goalkeeper Saves']['home'],match['api']['statistics']['Goalkeeper Saves']['away']]

# %%
geral = pd.DataFrame([gols, posse, chutes, chutes_a_gol, amarelos, vermelhos, acerto_passes,chutes_dentro_area,chutes_fora_area,
                     faltas,defesas_goleiro],
                     index=['Placar','Posse de bola','Chutes','Chutes no gol','Cartões amarelos','Cartões vermelhos','Passes acertados',
                           'Chutes dentro área','Chutes fora área','Faltas','Defesas do goleiro'],
                    columns = times)
print('Visão Geral')
geral
# Out:
# Visão Geral
#                    Gremio Corinthians
# Placar                  0           0
# Posse de bola         47%         53%
# Chutes                 23           5
# Chutes no gol           8           2
# Cartões amarelos        2           3
# Cartões vermelhos    None        None
# Passes acertados      87%         88%
# Chutes dentro área     16           4
# Chutes fora área        7           1
# Faltas                 16          14
# Defesas do goleiro      2           7

# %%
#Players data to dataframe
players_Df = pd.DataFrame(match_palyers['api']['players'])
players_Df
# Out:
#     event_id    updateAt  player_id       player_name  team_id    team_name  \
# 0     328010  1597561815       9977         Vanderlei      130       Gremio
# 1     328010  1597561815       2485     Luis Orejuela      130       Gremio
# 2     328010  1597561815      10485     Pedro Geromel      130       Gremio
# 3     328010  1597561815       2466  Walter Kannemann      130       Gremio
# 4     328010  1597561815      10480      Bruno Cortêz      130       Gremio
# 5     328010  1597561815      10494       Matheuzinho      130       Gremio
# 6     328010  1597561815      10498            Maicon      130       Gremio
# 7     328010  1597561815      10501           Alisson      130       Gremio
# 8     328010  1597561815      10491       Jean Pyerre      130       Gremio
# 9     328010  1597561815      80262              Pepê      130       Gremio
# 10    328010  1597561815      10072       Diego Souza      130       Gremio
# 11    328010  1597561815      10492          Thaciano      130       Gremio
# 12    328010  1597561815      80536            Isaque      130       Gremio
# 13    328010  1597561815      10102       Lucas Silva      130       Gremio
# 14    328010  1597561815      10229            Cássio      131  Corinthians
# 15    328010  1597561815      10236            Michel      131  Corinthians
# 16    328010  1597561815      12744               Gil      131  Corinthians
# 17    328010  1597561815      10230     Danilo Avelar      131  Corinthians
# 18    328010  1597561815       2162           Sidcley      131  Corinthians
# 19    328010  1597561815      10247   Gabriel Girotto      131  Corinthians
# 20    328010  1597561815      13580   Victor Cantillo      131  Corinthians
# 21    328010  1597561815      10241      Mateus Vital      131  Corinthians
# 22    328010  1597561815      10502              Luan      131  Corinthians
# 23    328010  1597561815      10249            Ramiro      131  Corinthians
# 24    328010  1597561815      32906                Jô      131  Corinthians
# 25    328010  1597561815     267862     Ruan Oliveira      131  Corinthians
# 26    328010  1597561815      10097           Éderson      131  Corinthians
# 27    328010  1597561815      10131           Camacho      131  Corinthians
# 28    328010  1597561815      10239      Ángelo Araos      131  Corinthians
# 29    328010  1597561815      15303         Léo Natel      131  Corinthians
#
#     number position rating  minutes_played  ... offsides  \
# 0       27        G    6.9              97  ...     None
# 1       17        D    6.5              97  ...     None
# 2        3        D    7.2              97  ...     None
# 3        4        D    7.0              97  ...     None
# 4       12        D    7.2              97  ...     None
# 5        7        M    6.6              97  ...     None
# 6        8        M    7.6              84  ...     None
# 7       23        M    7.3              97  ...     None
# 8       21        M    8.0              80  ...     None
# 9       25        M    7.2              97  ...     None
# 10      29        F    7.2              86  ...     None
# 11      20        M    6.3              11  ...     None
# 12      46        M    6.5              17  ...     None
# 13      16        M    6.6              13  ...     None
# 14      12        G    8.2              97  ...     None
# 15       2        D    6.7              97  ...     None
# 16       4        D    8.0              97  ...     None
# 17      35        D    7.0              97  ...     None
# 18      16        D    7.5              97  ...     None
# 19       5        M    7.0              91  ...     None
# 20      24        M    7.2              91  ...     None
# 21      22        M    6.5              36  ...     None
# 22       7        M    6.9              80  ...     None
# 23       8        M    7.3              80  ...     None
# 24      77        F    6.9              97  ...     None
# 25      36        M    6.7              17  ...     None
# 26      15        M    6.7              17  ...     None
# 27      20        M      –               6  ...     None
# 28      21        M    6.3              61  ...     None
# 29      18        M      –               6  ...     None
#
#                     shots                                              goals  \
# 0   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 1   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 2   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 5, 'on': 4}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 4, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 7, 'on': 3}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 10  {'total': 3, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 15  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 16  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 22  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                       passes  \
# 0    {'total': 10, 'key': 0, 'accuracy': 71}
# 1    {'total': 40, 'key': 0, 'accuracy': 87}
# 2    {'total': 35, 'key': 3, 'accuracy': 94}
# 3    {'total': 18, 'key': 0, 'accuracy': 81}
# 4    {'total': 44, 'key': 0, 'accuracy': 89}
# 5    {'total': 48, 'key': 2, 'accuracy': 85}
# 6    {'total': 74, 'key': 3, 'accuracy': 93}
# 7    {'total': 45, 'key': 1, 'accuracy': 84}
# 8    {'total': 46, 'key': 3, 'accuracy': 92}
# 9    {'total': 24, 'key': 2, 'accuracy': 70}
# 10   {'total': 12, 'key': 2, 'accuracy': 70}
# 11   {'total': 4, 'key': 0, 'accuracy': 100}
# 12  {'total': 10, 'key': 0, 'accuracy': 100}
# 13   {'total': 14, 'key': 0, 'accuracy': 93}
# 14   {'total': 28, 'key': 0, 'accuracy': 82}
# 15   {'total': 44, 'key': 0, 'accuracy': 91}
# 16   {'total': 56, 'key': 0, 'accuracy': 87}
# 17   {'total': 38, 'key': 0, 'accuracy': 90}
# 18   {'total': 37, 'key': 3, 'accuracy': 90}
# 19   {'total': 62, 'key': 0, 'accuracy': 92}
# 20   {'total': 70, 'key': 0, 'accuracy': 95}
# 21  {'total': 10, 'key': 1, 'accuracy': 100}
# 22   {'total': 53, 'key': 1, 'accuracy': 86}
# 23   {'total': 56, 'key': 0, 'accuracy': 88}
# 24   {'total': 16, 'key': 0, 'accuracy': 76}
# 25   {'total': 2, 'key': 0, 'accuracy': 100}
# 26    {'total': 2, 'key': 0, 'accuracy': 66}
# 27   {'total': 3, 'key': 0, 'accuracy': 100}
# 28   {'total': 23, 'key': 0, 'accuracy': 65}
# 29     {'total': 0, 'key': 0, 'accuracy': 0}
#
#                                           tackles                     duels  \
# 0   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 0, 'won': 0}
# 1   {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 9, 'won': 1}
# 2   {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 1, 'won': 0}
# 3   {'total': 3, 'blocks': 0, 'interceptions': 2}   {'total': 11, 'won': 7}
# 4   {'total': 4, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 6}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 1}   {'total': 16, 'won': 7}
# 6   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 5}
# 7   {'total': 3, 'blocks': 0, 'interceptions': 1}  {'total': 22, 'won': 12}
# 8   {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 13, 'won': 9}
# 9   {'total': 0, 'blocks': 0, 'interceptions': 0}   {'total': 15, 'won': 7}
# 10  {'total': 0, 'blocks': 0, 'interceptions': 1}  {'total': 16, 'won': 11}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 12  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 4, 'won': 2}
# 13  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 14  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 15  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 4}
# 16  {'total': 4, 'blocks': 3, 'interceptions': 1}    {'total': 6, 'won': 4}
# 17  {'total': 0, 'blocks': 1, 'interceptions': 3}   {'total': 10, 'won': 3}
# 18  {'total': 3, 'blocks': 1, 'interceptions': 3}   {'total': 10, 'won': 5}
# 19  {'total': 6, 'blocks': 2, 'interceptions': 2}   {'total': 17, 'won': 7}
# 20  {'total': 6, 'blocks': 0, 'interceptions': 1}  {'total': 17, 'won': 10}
# 21  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 22  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 4}
# 23  {'total': 3, 'blocks': 0, 'interceptions': 2}    {'total': 9, 'won': 4}
# 24  {'total': 0, 'blocks': 1, 'interceptions': 0}    {'total': 8, 'won': 4}
# 25  {'total': 2, 'blocks': 0, 'interceptions': 1}    {'total': 5, 'won': 3}
# 26  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 27  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 28  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 3}
# 29  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 4, 'won': 1}
#
#                                     dribbles                         fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 1   {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 3}
# 2   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 3   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 2}
# 4   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 5   {'attempts': 9, 'success': 6, 'past': 1}  {'drawn': 1, 'committed': 3}
# 6   {'attempts': 3, 'success': 3, 'past': 0}  {'drawn': 1, 'committed': 0}
# 7   {'attempts': 9, 'success': 5, 'past': 3}  {'drawn': 3, 'committed': 1}
# 8   {'attempts': 5, 'success': 4, 'past': 1}  {'drawn': 2, 'committed': 1}
# 9   {'attempts': 7, 'success': 2, 'past': 0}  {'drawn': 2, 'committed': 2}
# 10  {'attempts': 5, 'success': 5, 'past': 1}  {'drawn': 2, 'committed': 1}
# 11  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 12  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 0}
# 13  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 0}
# 14  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 15  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 2, 'committed': 1}
# 16  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 17  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 18  {'attempts': 0, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 2}
# 19  {'attempts': 0, 'success': 0, 'past': 6}  {'drawn': 1, 'committed': 3}
# 20  {'attempts': 2, 'success': 2, 'past': 3}  {'drawn': 2, 'committed': 3}
# 21  {'attempts': 1, 'success': 0, 'past': 0}  {'drawn': 2, 'committed': 0}
# 22  {'attempts': 3, 'success': 2, 'past': 2}  {'drawn': 1, 'committed': 1}
# 23  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 1}
# 24  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 25  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 26  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 27  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 28  {'attempts': 1, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 1}
# 29  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 1}
#
#                       cards                                            penalty
# 0   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 1   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 2   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 3   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 4   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 5   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 6   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 7   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 8   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 9   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 10  {'yellow': 0, 'red': 0}  {'won': 1, 'commited': 0, 'success': 0, 'misse...
# 11  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 12  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 13  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 14  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 15  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 1, 'success': 0, 'misse...
# 16  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 17  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 18  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 19  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 20  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 21  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 22  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 23  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 24  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 25  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 26  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 27  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 28  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 29  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
#
# [30 rows x 22 columns]

# %%
#Open shots data to columns
shots_Df = pd.DataFrame(players_Df['shots'])
shots_rows = []
for r in range(0,len(shots_Df)):
    shots_rows.append(list(shots_Df.loc[r,'shots'].values()))
    
open_shots = pd.DataFrame(shots_rows,columns=['total shots','on goal'])
n_players_Df = pd.concat([players_Df,open_shots],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id       player_name  team_id    team_name  \
# 0     328010  1597561815       9977         Vanderlei      130       Gremio
# 1     328010  1597561815       2485     Luis Orejuela      130       Gremio
# 2     328010  1597561815      10485     Pedro Geromel      130       Gremio
# 3     328010  1597561815       2466  Walter Kannemann      130       Gremio
# 4     328010  1597561815      10480      Bruno Cortêz      130       Gremio
# 5     328010  1597561815      10494       Matheuzinho      130       Gremio
# 6     328010  1597561815      10498            Maicon      130       Gremio
# 7     328010  1597561815      10501           Alisson      130       Gremio
# 8     328010  1597561815      10491       Jean Pyerre      130       Gremio
# 9     328010  1597561815      80262              Pepê      130       Gremio
# 10    328010  1597561815      10072       Diego Souza      130       Gremio
# 11    328010  1597561815      10492          Thaciano      130       Gremio
# 12    328010  1597561815      80536            Isaque      130       Gremio
# 13    328010  1597561815      10102       Lucas Silva      130       Gremio
# 14    328010  1597561815      10229            Cássio      131  Corinthians
# 15    328010  1597561815      10236            Michel      131  Corinthians
# 16    328010  1597561815      12744               Gil      131  Corinthians
# 17    328010  1597561815      10230     Danilo Avelar      131  Corinthians
# 18    328010  1597561815       2162           Sidcley      131  Corinthians
# 19    328010  1597561815      10247   Gabriel Girotto      131  Corinthians
# 20    328010  1597561815      13580   Victor Cantillo      131  Corinthians
# 21    328010  1597561815      10241      Mateus Vital      131  Corinthians
# 22    328010  1597561815      10502              Luan      131  Corinthians
# 23    328010  1597561815      10249            Ramiro      131  Corinthians
# 24    328010  1597561815      32906                Jô      131  Corinthians
# 25    328010  1597561815     267862     Ruan Oliveira      131  Corinthians
# 26    328010  1597561815      10097           Éderson      131  Corinthians
# 27    328010  1597561815      10131           Camacho      131  Corinthians
# 28    328010  1597561815      10239      Ángelo Araos      131  Corinthians
# 29    328010  1597561815      15303         Léo Natel      131  Corinthians
#
#     number position rating  minutes_played  ...  \
# 0       27        G    6.9              97  ...
# 1       17        D    6.5              97  ...
# 2        3        D    7.2              97  ...
# 3        4        D    7.0              97  ...
# 4       12        D    7.2              97  ...
# 5        7        M    6.6              97  ...
# 6        8        M    7.6              84  ...
# 7       23        M    7.3              97  ...
# 8       21        M    8.0              80  ...
# 9       25        M    7.2              97  ...
# 10      29        F    7.2              86  ...
# 11      20        M    6.3              11  ...
# 12      46        M    6.5              17  ...
# 13      16        M    6.6              13  ...
# 14      12        G    8.2              97  ...
# 15       2        D    6.7              97  ...
# 16       4        D    8.0              97  ...
# 17      35        D    7.0              97  ...
# 18      16        D    7.5              97  ...
# 19       5        M    7.0              91  ...
# 20      24        M    7.2              91  ...
# 21      22        M    6.5              36  ...
# 22       7        M    6.9              80  ...
# 23       8        M    7.3              80  ...
# 24      77        F    6.9              97  ...
# 25      36        M    6.7              17  ...
# 26      15        M    6.7              17  ...
# 27      20        M      –               6  ...
# 28      21        M    6.3              61  ...
# 29      18        M      –               6  ...
#
#                                                 goals  \
# 0   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 1   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 2   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 10  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 15  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 16  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 22  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                       passes  \
# 0    {'total': 10, 'key': 0, 'accuracy': 71}
# 1    {'total': 40, 'key': 0, 'accuracy': 87}
# 2    {'total': 35, 'key': 3, 'accuracy': 94}
# 3    {'total': 18, 'key': 0, 'accuracy': 81}
# 4    {'total': 44, 'key': 0, 'accuracy': 89}
# 5    {'total': 48, 'key': 2, 'accuracy': 85}
# 6    {'total': 74, 'key': 3, 'accuracy': 93}
# 7    {'total': 45, 'key': 1, 'accuracy': 84}
# 8    {'total': 46, 'key': 3, 'accuracy': 92}
# 9    {'total': 24, 'key': 2, 'accuracy': 70}
# 10   {'total': 12, 'key': 2, 'accuracy': 70}
# 11   {'total': 4, 'key': 0, 'accuracy': 100}
# 12  {'total': 10, 'key': 0, 'accuracy': 100}
# 13   {'total': 14, 'key': 0, 'accuracy': 93}
# 14   {'total': 28, 'key': 0, 'accuracy': 82}
# 15   {'total': 44, 'key': 0, 'accuracy': 91}
# 16   {'total': 56, 'key': 0, 'accuracy': 87}
# 17   {'total': 38, 'key': 0, 'accuracy': 90}
# 18   {'total': 37, 'key': 3, 'accuracy': 90}
# 19   {'total': 62, 'key': 0, 'accuracy': 92}
# 20   {'total': 70, 'key': 0, 'accuracy': 95}
# 21  {'total': 10, 'key': 1, 'accuracy': 100}
# 22   {'total': 53, 'key': 1, 'accuracy': 86}
# 23   {'total': 56, 'key': 0, 'accuracy': 88}
# 24   {'total': 16, 'key': 0, 'accuracy': 76}
# 25   {'total': 2, 'key': 0, 'accuracy': 100}
# 26    {'total': 2, 'key': 0, 'accuracy': 66}
# 27   {'total': 3, 'key': 0, 'accuracy': 100}
# 28   {'total': 23, 'key': 0, 'accuracy': 65}
# 29     {'total': 0, 'key': 0, 'accuracy': 0}
#
#                                           tackles                     duels  \
# 0   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 0, 'won': 0}
# 1   {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 9, 'won': 1}
# 2   {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 1, 'won': 0}
# 3   {'total': 3, 'blocks': 0, 'interceptions': 2}   {'total': 11, 'won': 7}
# 4   {'total': 4, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 6}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 1}   {'total': 16, 'won': 7}
# 6   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 5}
# 7   {'total': 3, 'blocks': 0, 'interceptions': 1}  {'total': 22, 'won': 12}
# 8   {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 13, 'won': 9}
# 9   {'total': 0, 'blocks': 0, 'interceptions': 0}   {'total': 15, 'won': 7}
# 10  {'total': 0, 'blocks': 0, 'interceptions': 1}  {'total': 16, 'won': 11}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 12  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 4, 'won': 2}
# 13  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 14  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 15  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 4}
# 16  {'total': 4, 'blocks': 3, 'interceptions': 1}    {'total': 6, 'won': 4}
# 17  {'total': 0, 'blocks': 1, 'interceptions': 3}   {'total': 10, 'won': 3}
# 18  {'total': 3, 'blocks': 1, 'interceptions': 3}   {'total': 10, 'won': 5}
# 19  {'total': 6, 'blocks': 2, 'interceptions': 2}   {'total': 17, 'won': 7}
# 20  {'total': 6, 'blocks': 0, 'interceptions': 1}  {'total': 17, 'won': 10}
# 21  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 22  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 4}
# 23  {'total': 3, 'blocks': 0, 'interceptions': 2}    {'total': 9, 'won': 4}
# 24  {'total': 0, 'blocks': 1, 'interceptions': 0}    {'total': 8, 'won': 4}
# 25  {'total': 2, 'blocks': 0, 'interceptions': 1}    {'total': 5, 'won': 3}
# 26  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 27  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 28  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 3}
# 29  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 4, 'won': 1}
#
#                                     dribbles                         fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 1   {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 3}
# 2   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 3   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 2}
# 4   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 5   {'attempts': 9, 'success': 6, 'past': 1}  {'drawn': 1, 'committed': 3}
# 6   {'attempts': 3, 'success': 3, 'past': 0}  {'drawn': 1, 'committed': 0}
# 7   {'attempts': 9, 'success': 5, 'past': 3}  {'drawn': 3, 'committed': 1}
# 8   {'attempts': 5, 'success': 4, 'past': 1}  {'drawn': 2, 'committed': 1}
# 9   {'attempts': 7, 'success': 2, 'past': 0}  {'drawn': 2, 'committed': 2}
# 10  {'attempts': 5, 'success': 5, 'past': 1}  {'drawn': 2, 'committed': 1}
# 11  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 12  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 0}
# 13  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 0}
# 14  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 15  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 2, 'committed': 1}
# 16  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 17  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 18  {'attempts': 0, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 2}
# 19  {'attempts': 0, 'success': 0, 'past': 6}  {'drawn': 1, 'committed': 3}
# 20  {'attempts': 2, 'success': 2, 'past': 3}  {'drawn': 2, 'committed': 3}
# 21  {'attempts': 1, 'success': 0, 'past': 0}  {'drawn': 2, 'committed': 0}
# 22  {'attempts': 3, 'success': 2, 'past': 2}  {'drawn': 1, 'committed': 1}
# 23  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 1}
# 24  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 25  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 26  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 27  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 28  {'attempts': 1, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 1}
# 29  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 1}
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 0, 'red': 0}
# 3   {'yellow': 1, 'red': 0}
# 4   {'yellow': 0, 'red': 0}
# 5   {'yellow': 1, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 0, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 0, 'red': 0}
# 16  {'yellow': 1, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 1, 'red': 0}
# 20  {'yellow': 0, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 0, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 1, 'red': 0}
#
#                                               penalty total shots on goal
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           5       4
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       1
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...           7       3
# 10  {'won': 1, 'commited': 0, 'success': 0, 'misse...           3       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 1, 'success': 0, 'misse...           1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
#
# [30 rows x 24 columns]

# %%
time = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
shots_position=[]

for p in position:
    shots_aux = []
    for t in time:
        shots_aux.append(n_players_Df[(n_players_Df['position']==p) & (n_players_Df['team_name']==t)]['total shots'].sum())
        
    shots_position.append(shots_aux)

shots_position_df = pd.DataFrame(shots_position, index=position, columns = time)
print('Shots by team and position')
shots_position_df
# Out:
# Shots by team and position
#    Gremio  Corinthians
# G       0            0
# D       3            2
# M      17            2
# F       3            1

# %%
#Total shots by player
import seaborn as sns
import matplotlib.pyplot as plt

home_player_shots=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['total shots','player_name','team_name']]
home_player_shots = home_player_shots[home_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
home_graph = sns.barplot(x=home_player_shots['total shots'],y=home_player_shots['player_name'],palette='Blues')
home_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,7)
plt.show()

away_player_shots=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['total shots','player_name','team_name']]
away_player_shots = away_player_shots[away_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
away_graph = sns.barplot(x=away_player_shots['total shots'],y=away_player_shots['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,7)
plt.show()

# %%
#passes
passes_Df = pd.DataFrame(players_Df['passes'])
passes_rows = []
for r in range(0,len(passes_Df)):
    passes_rows.append(list(passes_Df.loc[r,'passes'].values()))
    
open_passes = pd.DataFrame(passes_rows,columns=['total passes','keys','accuracy'])
n_players_Df = pd.concat([n_players_Df,open_passes],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id       player_name  team_id    team_name  \
# 0     328010  1597561815       9977         Vanderlei      130       Gremio
# 1     328010  1597561815       2485     Luis Orejuela      130       Gremio
# 2     328010  1597561815      10485     Pedro Geromel      130       Gremio
# 3     328010  1597561815       2466  Walter Kannemann      130       Gremio
# 4     328010  1597561815      10480      Bruno Cortêz      130       Gremio
# 5     328010  1597561815      10494       Matheuzinho      130       Gremio
# 6     328010  1597561815      10498            Maicon      130       Gremio
# 7     328010  1597561815      10501           Alisson      130       Gremio
# 8     328010  1597561815      10491       Jean Pyerre      130       Gremio
# 9     328010  1597561815      80262              Pepê      130       Gremio
# 10    328010  1597561815      10072       Diego Souza      130       Gremio
# 11    328010  1597561815      10492          Thaciano      130       Gremio
# 12    328010  1597561815      80536            Isaque      130       Gremio
# 13    328010  1597561815      10102       Lucas Silva      130       Gremio
# 14    328010  1597561815      10229            Cássio      131  Corinthians
# 15    328010  1597561815      10236            Michel      131  Corinthians
# 16    328010  1597561815      12744               Gil      131  Corinthians
# 17    328010  1597561815      10230     Danilo Avelar      131  Corinthians
# 18    328010  1597561815       2162           Sidcley      131  Corinthians
# 19    328010  1597561815      10247   Gabriel Girotto      131  Corinthians
# 20    328010  1597561815      13580   Victor Cantillo      131  Corinthians
# 21    328010  1597561815      10241      Mateus Vital      131  Corinthians
# 22    328010  1597561815      10502              Luan      131  Corinthians
# 23    328010  1597561815      10249            Ramiro      131  Corinthians
# 24    328010  1597561815      32906                Jô      131  Corinthians
# 25    328010  1597561815     267862     Ruan Oliveira      131  Corinthians
# 26    328010  1597561815      10097           Éderson      131  Corinthians
# 27    328010  1597561815      10131           Camacho      131  Corinthians
# 28    328010  1597561815      10239      Ángelo Araos      131  Corinthians
# 29    328010  1597561815      15303         Léo Natel      131  Corinthians
#
#     number position rating  minutes_played  ...                     duels  \
# 0       27        G    6.9              97  ...    {'total': 0, 'won': 0}
# 1       17        D    6.5              97  ...    {'total': 9, 'won': 1}
# 2        3        D    7.2              97  ...    {'total': 1, 'won': 0}
# 3        4        D    7.0              97  ...   {'total': 11, 'won': 7}
# 4       12        D    7.2              97  ...    {'total': 8, 'won': 6}
# 5        7        M    6.6              97  ...   {'total': 16, 'won': 7}
# 6        8        M    7.6              84  ...    {'total': 5, 'won': 5}
# 7       23        M    7.3              97  ...  {'total': 22, 'won': 12}
# 8       21        M    8.0              80  ...   {'total': 13, 'won': 9}
# 9       25        M    7.2              97  ...   {'total': 15, 'won': 7}
# 10      29        F    7.2              86  ...  {'total': 16, 'won': 11}
# 11      20        M    6.3              11  ...    {'total': 1, 'won': 0}
# 12      46        M    6.5              17  ...    {'total': 4, 'won': 2}
# 13      16        M    6.6              13  ...    {'total': 2, 'won': 1}
# 14      12        G    8.2              97  ...    {'total': 1, 'won': 0}
# 15       2        D    6.7              97  ...    {'total': 8, 'won': 4}
# 16       4        D    8.0              97  ...    {'total': 6, 'won': 4}
# 17      35        D    7.0              97  ...   {'total': 10, 'won': 3}
# 18      16        D    7.5              97  ...   {'total': 10, 'won': 5}
# 19       5        M    7.0              91  ...   {'total': 17, 'won': 7}
# 20      24        M    7.2              91  ...  {'total': 17, 'won': 10}
# 21      22        M    6.5              36  ...    {'total': 5, 'won': 2}
# 22       7        M    6.9              80  ...    {'total': 9, 'won': 4}
# 23       8        M    7.3              80  ...    {'total': 9, 'won': 4}
# 24      77        F    6.9              97  ...    {'total': 8, 'won': 4}
# 25      36        M    6.7              17  ...    {'total': 5, 'won': 3}
# 26      15        M    6.7              17  ...    {'total': 1, 'won': 1}
# 27      20        M      –               6  ...    {'total': 1, 'won': 0}
# 28      21        M    6.3              61  ...    {'total': 9, 'won': 3}
# 29      18        M      –               6  ...    {'total': 4, 'won': 1}
#
#                                     dribbles                         fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 1   {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 3}
# 2   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 3   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 2}
# 4   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 5   {'attempts': 9, 'success': 6, 'past': 1}  {'drawn': 1, 'committed': 3}
# 6   {'attempts': 3, 'success': 3, 'past': 0}  {'drawn': 1, 'committed': 0}
# 7   {'attempts': 9, 'success': 5, 'past': 3}  {'drawn': 3, 'committed': 1}
# 8   {'attempts': 5, 'success': 4, 'past': 1}  {'drawn': 2, 'committed': 1}
# 9   {'attempts': 7, 'success': 2, 'past': 0}  {'drawn': 2, 'committed': 2}
# 10  {'attempts': 5, 'success': 5, 'past': 1}  {'drawn': 2, 'committed': 1}
# 11  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 12  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 0}
# 13  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 0}
# 14  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 15  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 2, 'committed': 1}
# 16  {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 17  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 0}
# 18  {'attempts': 0, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 2}
# 19  {'attempts': 0, 'success': 0, 'past': 6}  {'drawn': 1, 'committed': 3}
# 20  {'attempts': 2, 'success': 2, 'past': 3}  {'drawn': 2, 'committed': 3}
# 21  {'attempts': 1, 'success': 0, 'past': 0}  {'drawn': 2, 'committed': 0}
# 22  {'attempts': 3, 'success': 2, 'past': 2}  {'drawn': 1, 'committed': 1}
# 23  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 1}
# 24  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 25  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 0}
# 26  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 27  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 1}
# 28  {'attempts': 1, 'success': 0, 'past': 3}  {'drawn': 2, 'committed': 1}
# 29  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 0, 'committed': 1}
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 0, 'red': 0}
# 3   {'yellow': 1, 'red': 0}
# 4   {'yellow': 0, 'red': 0}
# 5   {'yellow': 1, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 0, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 0, 'red': 0}
# 16  {'yellow': 1, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 1, 'red': 0}
# 20  {'yellow': 0, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 0, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 1, 'red': 0}
#
#                                               penalty total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           5       4
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       1
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...           7       3
# 10  {'won': 1, 'commited': 0, 'success': 0, 'misse...           3       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 1, 'success': 0, 'misse...           1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
#
#    total passes keys accuracy
# 0            10    0       71
# 1            40    0       87
# 2            35    3       94
# 3            18    0       81
# 4            44    0       89
# 5            48    2       85
# 6            74    3       93
# 7            45    1       84
# 8            46    3       92
# 9            24    2       70
# 10           12    2       70
# 11            4    0      100
# 12           10    0      100
# 13           14    0       93
# 14           28    0       82
# 15           44    0       91
# 16           56    0       87
# 17           38    0       90
# 18           37    3       90
# 19           62    0       92
# 20           70    0       95
# 21           10    1      100
# 22           53    1       86
# 23           56    0       88
# 24           16    0       76
# 25            2    0      100
# 26            2    0       66
# 27            3    0      100
# 28           23    0       65
# 29            0    0        0
#
# [30 rows x 27 columns]

# %%
#passes
time = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
columns = ['Home_passes','Home_keys','Home_acc','Away_passes','Away_keys','Away_acc']
passes_position = []

for p in position:
    passes_aux = []
    for t in time:
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['total passes'].sum())
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['keys'].sum())
        
        pass_list=[]
        acc_list=[]
        for i in n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)].index:
            pass_list.append(n_players_Df.loc[i,'total passes'])
            acc_list.append(n_players_Df.loc[i,'accuracy'])
            
        lists = pass_list, acc_list
        passes_aux.append(sum([x * y for x, y in zip(*lists)])/sum(pass_list))
    
    passes_position.append(passes_aux)
    
passes_position_df = pd.DataFrame(passes_position, index=position, columns = columns)
passes_position_df
# Out:
#    Home_passes  Home_keys   Home_acc  Away_passes  Away_keys   Away_acc
# G           10          0  71.000000           28          0  82.000000
# D          137          3  88.642336          175          3  89.291429
# M          265         11  88.135849          281          2  88.850534
# F           12          2  70.000000           16          0  76.000000

# %%
passes_sum = pd.DataFrame([[passes_position_df[columns[0]].sum(),passes_position_df[columns[1]].sum(),passes_position_df[columns[2]].sum(),
                          passes_position_df[columns[3]].sum(),passes_position_df[columns[4]].sum(),passes_position_df[columns[5]].sum()]],
                         index=['Total'],columns = columns)
passes_sum
# Out:
#        Home_passes  Home_keys    Home_acc  Away_passes  Away_keys    Away_acc
# Total          424         16  317.778185          500          5  336.141962

# %%
#Key passes by player
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['keys','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['keys'],y=home_player_passes['player_name'],palette='Blues')
home_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,3)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['keys','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['keys'],y=away_player_passes['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,3)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['total passes','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['total passes'],y=home_player_passes['player_name'],palette='Blues')
home_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,80)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['total passes','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['total passes'],y=away_player_passes['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,80)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['accuracy','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['accuracy'],y=home_player_passes['player_name'])
home_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['accuracy','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['accuracy'],y=away_player_passes['player_name'])
away_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.show()

# %%
#tackles
tackles_Df = pd.DataFrame(players_Df['tackles'])
tackles_rows = []
for r in range(0,len(tackles_Df)):
    tackles_rows.append(list(tackles_Df.loc[r,'tackles'].values()))
    
open_tackles = pd.DataFrame(tackles_rows,columns=['Desarmes','bloqueios','interceptações'])
n_players_Df = pd.concat([n_players_Df,open_tackles],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id       player_name  team_id    team_name  \
# 0     328010  1597561815       9977         Vanderlei      130       Gremio
# 1     328010  1597561815       2485     Luis Orejuela      130       Gremio
# 2     328010  1597561815      10485     Pedro Geromel      130       Gremio
# 3     328010  1597561815       2466  Walter Kannemann      130       Gremio
# 4     328010  1597561815      10480      Bruno Cortêz      130       Gremio
# 5     328010  1597561815      10494       Matheuzinho      130       Gremio
# 6     328010  1597561815      10498            Maicon      130       Gremio
# 7     328010  1597561815      10501           Alisson      130       Gremio
# 8     328010  1597561815      10491       Jean Pyerre      130       Gremio
# 9     328010  1597561815      80262              Pepê      130       Gremio
# 10    328010  1597561815      10072       Diego Souza      130       Gremio
# 11    328010  1597561815      10492          Thaciano      130       Gremio
# 12    328010  1597561815      80536            Isaque      130       Gremio
# 13    328010  1597561815      10102       Lucas Silva      130       Gremio
# 14    328010  1597561815      10229            Cássio      131  Corinthians
# 15    328010  1597561815      10236            Michel      131  Corinthians
# 16    328010  1597561815      12744               Gil      131  Corinthians
# 17    328010  1597561815      10230     Danilo Avelar      131  Corinthians
# 18    328010  1597561815       2162           Sidcley      131  Corinthians
# 19    328010  1597561815      10247   Gabriel Girotto      131  Corinthians
# 20    328010  1597561815      13580   Victor Cantillo      131  Corinthians
# 21    328010  1597561815      10241      Mateus Vital      131  Corinthians
# 22    328010  1597561815      10502              Luan      131  Corinthians
# 23    328010  1597561815      10249            Ramiro      131  Corinthians
# 24    328010  1597561815      32906                Jô      131  Corinthians
# 25    328010  1597561815     267862     Ruan Oliveira      131  Corinthians
# 26    328010  1597561815      10097           Éderson      131  Corinthians
# 27    328010  1597561815      10131           Camacho      131  Corinthians
# 28    328010  1597561815      10239      Ángelo Araos      131  Corinthians
# 29    328010  1597561815      15303         Léo Natel      131  Corinthians
#
#     number position rating  minutes_played  ...                    cards  \
# 0       27        G    6.9              97  ...  {'yellow': 0, 'red': 0}
# 1       17        D    6.5              97  ...  {'yellow': 0, 'red': 0}
# 2        3        D    7.2              97  ...  {'yellow': 0, 'red': 0}
# 3        4        D    7.0              97  ...  {'yellow': 1, 'red': 0}
# 4       12        D    7.2              97  ...  {'yellow': 0, 'red': 0}
# 5        7        M    6.6              97  ...  {'yellow': 1, 'red': 0}
# 6        8        M    7.6              84  ...  {'yellow': 0, 'red': 0}
# 7       23        M    7.3              97  ...  {'yellow': 0, 'red': 0}
# 8       21        M    8.0              80  ...  {'yellow': 0, 'red': 0}
# 9       25        M    7.2              97  ...  {'yellow': 0, 'red': 0}
# 10      29        F    7.2              86  ...  {'yellow': 0, 'red': 0}
# 11      20        M    6.3              11  ...  {'yellow': 0, 'red': 0}
# 12      46        M    6.5              17  ...  {'yellow': 0, 'red': 0}
# 13      16        M    6.6              13  ...  {'yellow': 0, 'red': 0}
# 14      12        G    8.2              97  ...  {'yellow': 0, 'red': 0}
# 15       2        D    6.7              97  ...  {'yellow': 0, 'red': 0}
# 16       4        D    8.0              97  ...  {'yellow': 1, 'red': 0}
# 17      35        D    7.0              97  ...  {'yellow': 0, 'red': 0}
# 18      16        D    7.5              97  ...  {'yellow': 0, 'red': 0}
# 19       5        M    7.0              91  ...  {'yellow': 1, 'red': 0}
# 20      24        M    7.2              91  ...  {'yellow': 0, 'red': 0}
# 21      22        M    6.5              36  ...  {'yellow': 0, 'red': 0}
# 22       7        M    6.9              80  ...  {'yellow': 0, 'red': 0}
# 23       8        M    7.3              80  ...  {'yellow': 0, 'red': 0}
# 24      77        F    6.9              97  ...  {'yellow': 0, 'red': 0}
# 25      36        M    6.7              17  ...  {'yellow': 0, 'red': 0}
# 26      15        M    6.7              17  ...  {'yellow': 0, 'red': 0}
# 27      20        M      –               6  ...  {'yellow': 0, 'red': 0}
# 28      21        M    6.3              61  ...  {'yellow': 0, 'red': 0}
# 29      18        M      –               6  ...  {'yellow': 1, 'red': 0}
#
#                                               penalty total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           5       4
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       1
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...           7       3
# 10  {'won': 1, 'commited': 0, 'success': 0, 'misse...           3       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 1, 'success': 0, 'misse...           1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
#
#    total passes keys accuracy Desarmes bloqueios interceptações
# 0            10    0       71        0         0              0
# 1            40    0       87        0         0              1
# 2            35    3       94        0         1              2
# 3            18    0       81        3         0              2
# 4            44    0       89        4         0              1
# 5            48    2       85        0         0              1
# 6            74    3       93        0         0              0
# 7            45    1       84        3         0              1
# 8            46    3       92        3         0              0
# 9            24    2       70        0         0              0
# 10           12    2       70        0         0              1
# 11            4    0      100        0         0              0
# 12           10    0      100        0         0              0
# 13           14    0       93        0         0              0
# 14           28    0       82        0         0              0
# 15           44    0       91        0         0              1
# 16           56    0       87        4         3              1
# 17           38    0       90        0         1              3
# 18           37    3       90        3         1              3
# 19           62    0       92        6         2              2
# 20           70    0       95        6         0              1
# 21           10    1      100        0         0              0
# 22           53    1       86        1         0              0
# 23           56    0       88        3         0              2
# 24           16    0       76        0         1              0
# 25            2    0      100        2         0              1
# 26            2    0       66        1         0              0
# 27            3    0      100        0         0              0
# 28           23    0       65        0         0              0
# 29            0    0        0        1         0              0
#
# [30 rows x 30 columns]

# %%
tackles_players = n_players_Df[n_players_Df['position']=='M'][['player_name','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players

#Tackles by player
home_player_tackles=tackles_players[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['player_name','interceptações','team_name']]
home_player_tackles = home_player_tackles[home_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
home_graph = sns.barplot(x=home_player_tackles['interceptações'],y=home_player_tackles['player_name'],palette='Blues')
home_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,5)
plt.show()

away_player_tackles=tackles_players[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['player_name','interceptações','team_name']]
away_player_tackles = away_player_tackles[away_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
away_graph = sns.barplot(x=away_player_tackles['interceptações'],y=away_player_tackles['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,5)
plt.show()
# Out:
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':

# %%
tackles_players = n_players_Df[['player_name','position','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players
# Out:
#          player_name position    team_name  Desarmes  bloqueios  \
# 0          Vanderlei        G       Gremio         0          0
# 1      Luis Orejuela        D       Gremio         0          0
# 2      Pedro Geromel        D       Gremio         0          1
# 3   Walter Kannemann        D       Gremio         3          0
# 4       Bruno Cortêz        D       Gremio         4          0
# 5        Matheuzinho        M       Gremio         0          0
# 6             Maicon        M       Gremio         0          0
# 7            Alisson        M       Gremio         3          0
# 8        Jean Pyerre        M       Gremio         3          0
# 9               Pepê        M       Gremio         0          0
# 10       Diego Souza        F       Gremio         0          0
# 11          Thaciano        M       Gremio         0          0
# 12            Isaque        M       Gremio         0          0
# 13       Lucas Silva        M       Gremio         0          0
# 14            Cássio        G  Corinthians         0          0
# 15            Michel        D  Corinthians         0          0
# 16               Gil        D  Corinthians         4          3
# 17     Danilo Avelar        D  Corinthians         0          1
# 18           Sidcley        D  Corinthians         3          1
# 19   Gabriel Girotto        M  Corinthians         6          2
# 20   Victor Cantillo        M  Corinthians         6          0
# 21      Mateus Vital        M  Corinthians         0          0
# 22              Luan        M  Corinthians         1          0
# 23            Ramiro        M  Corinthians         3          0
# 24                Jô        F  Corinthians         0          1
# 25     Ruan Oliveira        M  Corinthians         2          0
# 26           Éderson        M  Corinthians         1          0
# 27           Camacho        M  Corinthians         0          0
# 28      Ángelo Araos        M  Corinthians         0          0
# 29         Léo Natel        M  Corinthians         1          0
#
#     interceptações
# 0                0
# 1                1
# 2                2
# 3                2
# 4                1
# 5                1
# 6                0
# 7                1
# 8                0
# 9                0
# 10               1
# 11               0
# 12               0
# 13               0
# 14               0
# 15               1
# 16               1
# 17               3
# 18               3
# 19               2
# 20               1
# 21               0
# 22               0
# 23               2
# 24               0
# 25               1
# 26               0
# 27               0
# 28               0
# 29               0

# %% [markdown]
# Corinthians's GoalKeeper made 7 saves during the game, being this one of the reasons for Gremio having so many opportunities and not winning the match. So, let's get data from Fernando Prass last season and check what is his average save by match so we can compare with this match.

# %%
#Cassio statistics

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/players/player/10229/2019", headers=headers)

res = conn.getresponse()
data = res.read()

casio=json.loads(data.decode("utf-8"))
with open('20200815_gre_cor_cassio.txt','w') as outfile:
    json.dump(casio,outfile)
casio
# Out:
# {'api': {'results': 5,
#   'players': [{'player_id': 10229,
#     'player_name': 'Cássio',
#     'firstname': 'Cássio',
#     'lastname': 'Ramos',
#     'number': None,
#     'position': 'Goalkeeper',
#     'age': 33,
#     'birth_date': '06/06/1987',
#     'birth_place': 'Veranópolis',
#     'birth_country': 'Brazil',
#     'nationality': 'Brazil',
#     'height': '195 cm',
#     'weight': '92 kg',
#     'injured': None,
#     'rating': '7.017647',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'league': 'Paulista A1',
#     'season': '2019',
#     'captain': 5,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 13, 'assists': 0, 'saves': 48},
#     'passes': {'total': 232, 'key': 0, 'accuracy': 61},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 8, 'won': 8},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 4, 'committed': 0},
#     'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 1},
#     'games': {'appearences': 18, 'minutes_played': 1576, 'lineups': 18},
#     'substitutes': {'in': 0, 'out': 1, 'bench': 0}},
#    {'player_id': 10229,
#     'player_name': 'Cássio',
#     'firstname': 'Cássio',
#     'lastname': 'Ramos',
#     'number': None,
#     'position': 'Goalkeeper',
#     'age': 33,
#     'birth_date': '06/06/1987',
#     'birth_place': 'Veranópolis',
#     'birth_country': 'Brazil',
#     'nationality': 'Brazil',
#     'height': '195 cm',
#     'weight': '92 kg',
#     'injured': None,
#     'rating': '6.964516',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'league': 'Serie A',
#     'season': '2019',
#     'captain': 12,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 27, 'assists': 0, 'saves': 81},
#     'passes': {'total': 555, 'key': 1, 'accuracy': 67},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 5, 'won': 5},
#     'dribbles': {'attempts': 1, 'success': 1},
#     'fouls': {'drawn': 9, 'committed': 1},
#     'cards': {'yellow': 6, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 1},
#     'games': {'appearences': 32, 'minutes_played': 2860, 'lineups': 32},
#     'substitutes': {'in': 0, 'out': 1, 'bench': 0}},
#    {'player_id': 10229,
#     'player_name': 'Cássio',
#     'firstname': 'Cássio',
#     'lastname': 'Ramos',
#     'number': None,
#     'position': 'Goalkeeper',
#     'age': 33,
#     'birth_date': '06/06/1987',
#     'birth_place': 'Veranópolis',
#     'birth_country': 'Brazil',
#     'nationality': 'Brazil',
#     'height': '195 cm',
#     'weight': '92 kg',
#     'injured': None,
#     'rating': '6.742857',
#     'team_id': 131,
#     'team_name': 'Corinthians',
#     'league': 'Copa do Brasil',
#     'season': '2019',
#     'captain': 3,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 8, 'assists': 0, 'saves': 16},
#     'passes': {'total': 94, 'key': 0, 'accuracy': 62},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 2, 'won': 2},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'yellowred': 0, 'red': 1},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 7, 'minutes_played': 602, 'lineups': 7},
#     'substitutes': {'in': 0, 'out': 0, 'bench': 0}},
#    {'player_id': 10229,
#     'player_name': 'Cássio',
#     'firstname': 'Cássio',
#     'lastname': 'Ramos',
#     'number': None,
#     'position': 'Goalkeeper',
#     'age': 33,
#     'birth_date': '06/06/1987',
#     'birth_place': 'Veranópolis',
#     'birth_country': 'Brazil',
#     'nationality': 'Brazil',
#     'height': '195 cm',
#     'weight': '92 kg',
#     'injured': None,
#     'rating': None,
#     'team_id': 6,
#     'team_name': 'Brazil',
#     'league': 'Copa America',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 0, 'key': 0, 'accuracy': 0},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 0, 'minutes_played': 0, 'lineups': 0},
#     'substitutes': {'in': 0, 'out': 0, 'bench': 6}},
#    {'player_id': 10229,
#     'player_name': 'Cássio',
#     'firstname': 'Cássio',
#     'lastname': 'Ramos',
#     'number': None,
#     'position': 'Goalkeeper',
#     'age': 33,
#     'birth_date': '06/06/1987',
#     'birth_place': 'Veranópolis',
#     'birth_country': 'Brazil',
#     'nationality': 'Brazil',
#     'height': '195 cm',
#     'weight': '92 kg',
#     'injured': None,
#     'rating': None,
#     'team_id': 6,
#     'team_name': 'Brazil',
#     'league': 'Friendlies',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 0, 'key': 0, 'accuracy': 0},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 0, 'minutes_played': 0, 'lineups': 0},
#     'substitutes': {'in': 0, 'out': 0, 'bench': 2}}]}}

# %%
cassio_2019_A = list(filter(lambda p: p['league'] in ['Serie A'],casio['api']['players']))

saves = cassio_2019_A[0]['goals']['saves']

appearences = cassio_2019_A[0]['games']['appearences']

avg_saves = saves / appearences


print('Cassio saves/match in 2019: ' + str(avg_saves))
print('Cassio saves in the match: ' + str(list(filter(lambda p: p['player_name'] in ['Cássio'],match_palyers['api']['players']))[0]['goals']['saves']))
# Out:
# Cassio saves/match in 2019: 2.53125
# Cassio saves in the match: 7

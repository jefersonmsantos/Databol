# %% [markdown]
# # FLUMINENSE X INTERNACIONAL DATA ANALYSIS

# %% [markdown]
# The objective of this analyisis is to work on data of brazilian football match between Fluminense and Internacional, played on 2020 August 15th, and understand how data from the match can explain the result of the match

# %% [markdown]
# Find the commented video analysis for this match on my youtube channel, here: https://youtu.be/ngGOW5NOp_I

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/teams/league/1396", headers=headers)

res = conn.getresponse()
data = res.read()


team=json.loads(data.decode("utf-8"))
team
# Out:
# {'api': {'results': 20,
#   'teams': [{'team_id': 127,
#     'name': 'Flamengo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/127.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1895,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 1062,
#     'name': 'Atletico-MG',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/1062.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1908,
#     'venue_name': 'Estádio Raimundo Sampaio',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Ismênia Tunes, Bairro Horto',
#     'venue_city': 'Belo Horizonte, Minas Gerais',
#     'venue_capacity': 23018},
#    {'team_id': 120,
#     'name': 'Botafogo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/120.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1904,
#     'venue_name': 'Estádio Nilton Santos',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Arquias Cordeiro, Engenho de Dentro',
#     'venue_city': 'Rio de Janeiro',
#     'venue_capacity': 46931},
#    {'team_id': 118,
#     'name': 'Bahia',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/118.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1931,
#     'venue_name': 'Arena Fonte Nova',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Lions Club, Nazaré',
#     'venue_city': 'Salvador, Bahia',
#     'venue_capacity': 56500},
#    {'team_id': 121,
#     'name': 'Palmeiras',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/121.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Allianz Parque',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Turiaçu 1840, Perdizes',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 43713},
#    {'team_id': 133,
#     'name': 'Vasco DA Gama',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/133.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1898,
#     'venue_name': 'Estádio Club de Regatas Vasco da Gama',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Gal Almério de Moura 131, Bairro Vasco da Gama',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 22076},
#    {'team_id': 128,
#     'name': 'Santos',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/128.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1912,
#     'venue_name': 'Nickerie Stadion',
#     'venue_surface': 'grass',
#     'venue_address': 'F. O. Lashleystraat',
#     'venue_city': 'Nieuw Nickerie',
#     'venue_capacity': 3400},
#    {'team_id': 794,
#     'name': 'Bragantino',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/794.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1928,
#     'venue_name': 'Estádio Nabi Abi Chedid',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Emílio Coleta',
#     'venue_city': 'Bragança Paulista, São Paulo',
#     'venue_capacity': 17128},
#    {'team_id': 131,
#     'name': 'Corinthians',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/131.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1910,
#     'venue_name': 'Arena Corinthians',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Miguel Inácio Curi, 111, Vila Carmosina, Itaquera',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 47605},
#    {'team_id': 144,
#     'name': 'Atletico Goianiense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/144.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1937,
#     'venue_name': 'Estádio Antônio Accioly',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Perimetral 923 / Avenida 24 de Outubro, Bairro Campinas',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10525},
#    {'team_id': 130,
#     'name': 'Gremio',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/130.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1903,
#     'venue_name': 'Arena do Grêmio',
#     'venue_surface': 'grass',
#     'venue_address': 'Bairro Humaitá',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 60540},
#    {'team_id': 124,
#     'name': 'Fluminense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/124.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1902,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 123,
#     'name': 'Sport Recife',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/123.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1905,
#     'venue_name': 'Estádio Adelmar da Costa Carvalho',
#     'venue_surface': 'grass',
#     'venue_address': 'Praça da Bandeira',
#     'venue_city': 'Recife, Pernambuco',
#     'venue_capacity': 32983},
#    {'team_id': 129,
#     'name': 'Ceara',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/129.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 147,
#     'name': 'Coritiba',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/147.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio Major Antônio Couto Pereira',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Ubaldino do Amaral 37, Bairro Alto da Glória',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 45563},
#    {'team_id': 119,
#     'name': 'Internacional',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/119.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio José Pinheiro Borda',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 50128},
#    {'team_id': 154,
#     'name': 'Fortaleza EC',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/154.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1918,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 134,
#     'name': 'Atletico Paranaense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/134.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1924,
#     'venue_name': 'Estádio Joaquim Américo Guimarães',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Buenos Aires 1260, Água Verde',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 43981},
#    {'team_id': 151,
#     'name': 'Goias',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/151.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1943,
#     'venue_name': 'Estádio de Hailé Pinheiro',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Edmundo Pinheiro de Abreu 721, Setor Bela Vista',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10000},
#    {'team_id': 126,
#     'name': 'Sao Paulo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/126.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1930,
#     'venue_name': 'Estádio Cícero Pompeu de Toledo (Morumbi)',
#     'venue_surface': 'grass',
#     'venue_address': 'Praca Roberto Gomes Pedrosa 1, Morumbi',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 73501}]}}

# %%
inter_data = list(filter(lambda p: p['name'] in ['Internacional'],team['api']['teams']))
inter_data
# Out:
# [{'team_id': 119,
#   'name': 'Internacional',
#   'code': None,
#   'logo': 'https://media.api-sports.io/football/teams/119.png',
#   'country': 'Brazil',
#   'is_national': False,
#   'founded': 1909,
#   'venue_name': 'Estádio José Pinheiro Borda',
#   'venue_surface': 'grass',
#   'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus',
#   'venue_city': 'Porto Alegre, Rio Grande do Sul',
#   'venue_capacity': 50128}]

# %%
#find last fixture
import http.client
import json
import pandas as pd
import numpy as np

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/fixtures/team/119/last/1", headers=headers)

res = conn.getresponse()
data = res.read()

fix=json.loads(data.decode("utf-8"))
with open('20200817_flu_int_fix.txt','w') as outfile:
    json.dump(fix,outfile)
fix
# Out:
# {'api': {'results': 1,
#   'fixtures': [{'fixture_id': 328005,
#     'league_id': 1396,
#     'league': {'name': 'Serie A',
#      'country': 'Brazil',
#      'logo': 'https://media.api-sports.io/football/leagues/71.png',
#      'flag': 'https://media.api-sports.io/flags/br.svg'},
#     'event_date': '2020-08-16T21:00:00+00:00',
#     'event_timestamp': 1597611600,
#     'firstHalfStart': 1597611600,
#     'secondHalfStart': 1597615200,
#     'round': 'Regular Season - 3',
#     'status': 'Match Finished',
#     'statusShort': 'FT',
#     'elapsed': 90,
#     'venue': 'Estadio do Maracanã',
#     'referee': 'Raphael Claus, Brazil',
#     'homeTeam': {'team_id': 124,
#      'team_name': 'Fluminense',
#      'logo': 'https://media.api-sports.io/football/teams/124.png'},
#     'awayTeam': {'team_id': 119,
#      'team_name': 'Internacional',
#      'logo': 'https://media.api-sports.io/football/teams/119.png'},
#     'goalsHomeTeam': 2,
#     'goalsAwayTeam': 1,
#     'score': {'halftime': '1-1',
#      'fulltime': '2-1',
#      'extratime': None,
#      'penalty': None}}]}}

# %%
#Request statistical data from fixture
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/statistics/fixture/328005/", headers=headers)

res = conn.getresponse()
data = res.read()

match=json.loads(data.decode("utf-8"))
with open('20200816_flu_int_fixstat.txt','w') as outfile:
    json.dump(fix,outfile)
match
# Out:
# {'api': {'results': 16,
#   'statistics': {'Shots on Goal': {'home': '5', 'away': '3'},
#    'Shots off Goal': {'home': '2', 'away': '4'},
#    'Total Shots': {'home': '10', 'away': '9'},
#    'Blocked Shots': {'home': '3', 'away': '2'},
#    'Shots insidebox': {'home': '8', 'away': '5'},
#    'Shots outsidebox': {'home': '2', 'away': '4'},
#    'Fouls': {'home': '13', 'away': '24'},
#    'Corner Kicks': {'home': '1', 'away': '4'},
#    'Offsides': {'home': '1', 'away': '1'},
#    'Ball Possession': {'home': '43%', 'away': '57%'},
#    'Yellow Cards': {'home': '2', 'away': '2'},
#    'Red Cards': {'home': None, 'away': None},
#    'Goalkeeper Saves': {'home': '1', 'away': '3'},
#    'Total passes': {'home': '339', 'away': '435'},
#    'Passes accurate': {'home': '259', 'away': '339'},
#    'Passes %': {'home': '76%', 'away': '78%'}}}}

# %%
#Request statistical data from players on fixture
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/players/fixture/328005", headers=headers)

res = conn.getresponse()
data = res.read()

match_palyers=json.loads(data.decode("utf-8"))
with open('202000816_flu_int_plrstats.txt','w') as outfile:
    json.dump(match_palyers,outfile)
match_palyers
# Out:
# {'api': {'results': 31,
#   'players': [{'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 41227,
#     'player_name': 'Muriel',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 27,
#     'position': 'G',
#     'rating': '6.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 1, 'assists': 0, 'saves': 1},
#     'passes': {'total': 6, 'key': 0, 'accuracy': 42},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10300,
#     'player_name': 'Igor Julião',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 21,
#     'position': 'D',
#     'rating': '6.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 17, 'key': 1, 'accuracy': 63},
#     'tackles': {'total': 2, 'blocks': 1, 'interceptions': 0},
#     'duels': {'total': 11, 'won': 5},
#     'dribbles': {'attempts': 3, 'success': 1, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10306,
#     'player_name': 'Nino',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 33,
#     'position': 'D',
#     'rating': '6.6',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 22, 'key': 0, 'accuracy': 68},
#     'tackles': {'total': 1, 'blocks': 1, 'interceptions': 4},
#     'duels': {'total': 17, 'won': 10},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 3},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 61809,
#     'player_name': 'Luccas Claro',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 4,
#     'position': 'D',
#     'rating': '7.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 26, 'key': 0, 'accuracy': 78},
#     'tackles': {'total': 3, 'blocks': 1, 'interceptions': 2},
#     'duels': {'total': 11, 'won': 8},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10084,
#     'player_name': 'Egídio',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 6,
#     'position': 'D',
#     'rating': '7.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 3, 'on': 2},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 40, 'key': 0, 'accuracy': 81},
#     'tackles': {'total': 5, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 14, 'won': 11},
#     'dribbles': {'attempts': 2, 'success': 2, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 51701,
#     'player_name': 'Michel Araújo',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 15,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 73,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 20, 'key': 0, 'accuracy': 74},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 10, 'won': 6},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 4, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10315,
#     'player_name': 'Yuri',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 5,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 37, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 12, 'won': 4},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 3},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10314,
#     'player_name': 'Douglas Moreira',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 22,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 28, 'key': 0, 'accuracy': 87},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 3},
#     'duels': {'total': 7, 'won': 3},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 9970,
#     'player_name': 'Nenê',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 77,
#     'position': 'F',
#     'rating': '8.2',
#     'minutes_played': 83,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 2, 'on': 2},
#     'goals': {'total': 2, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 25, 'key': 1, 'accuracy': 83},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 7, 'won': 3},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 2,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 152856,
#     'player_name': 'Evanilson',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 99,
#     'position': 'F',
#     'rating': '7.2',
#     'minutes_played': 89,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 14, 'key': 4, 'accuracy': 82},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 21, 'won': 8},
#     'dribbles': {'attempts': 3, 'success': 2, 'past': 1},
#     'fouls': {'drawn': 4, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 1,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10322,
#     'player_name': 'Marcos Paulo',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 11,
#     'position': 'F',
#     'rating': '6.3',
#     'minutes_played': 73,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': 1,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 15, 'key': 0, 'accuracy': 68},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 8, 'won': 2},
#     'dribbles': {'attempts': 2, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10398,
#     'player_name': 'Wellington Silva',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 17,
#     'position': 'M',
#     'rating': '6.2',
#     'minutes_played': 17,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 1, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 7, 'won': 2},
#     'dribbles': {'attempts': 2, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10348,
#     'player_name': 'Yago Felipe',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 20,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 8,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 1, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10311,
#     'player_name': 'Ganso',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 10,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 14,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 3, 'key': 0, 'accuracy': 75},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 265785,
#     'player_name': 'Luiz Henrique',
#     'team_id': 124,
#     'team_name': 'Fluminense',
#     'number': 34,
#     'position': 'F',
#     'rating': '6.7',
#     'minutes_played': 17,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 4, 'key': 0, 'accuracy': 80},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 6, 'won': 3},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10372,
#     'player_name': 'Marcelo Lomba',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 12,
#     'position': 'G',
#     'rating': '6.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 2, 'assists': 0, 'saves': 3},
#     'passes': {'total': 14, 'key': 0, 'accuracy': 66},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 2470,
#     'player_name': 'Renzo Saravia',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 26,
#     'position': 'D',
#     'rating': '6.6',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 29, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 4, 'blocks': 1, 'interceptions': 1},
#     'duels': {'total': 15, 'won': 9},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': None,
#     'player_name': 'Zé Gabriel',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 35,
#     'position': 'D',
#     'rating': '6.6',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 39, 'key': 0, 'accuracy': 81},
#     'tackles': {'total': 6, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 13, 'won': 10},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 1,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10377,
#     'player_name': 'Víctor Cuesta',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 15,
#     'position': 'D',
#     'rating': '6.2',
#     'minutes_played': 90,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 41, 'key': 0, 'accuracy': 83},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 12, 'won': 7},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 4},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 1,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10013,
#     'player_name': 'Moisés',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 16,
#     'position': 'D',
#     'rating': '6.7',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 48, 'key': 0, 'accuracy': 76},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 8, 'won': 5},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10387,
#     'player_name': 'Edenílson',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 8,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 26, 'key': 1, 'accuracy': 76},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 14, 'won': 7},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10395,
#     'player_name': 'Rodrigo Lindoso',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 19,
#     'position': 'M',
#     'rating': '7.2',
#     'minutes_played': 77,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 1, 'saves': 0},
#     'passes': {'total': 39, 'key': 2, 'accuracy': 84},
#     'tackles': {'total': 2, 'blocks': 1, 'interceptions': 2},
#     'duels': {'total': 11, 'won': 5},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 2},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10388,
#     'player_name': 'Patrick',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 88,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 83,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 2, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 17, 'key': 0, 'accuracy': 81},
#     'tackles': {'total': 1, 'blocks': 1, 'interceptions': 1},
#     'duels': {'total': 12, 'won': 6},
#     'dribbles': {'attempts': 4, 'success': 2, 'past': 1},
#     'fouls': {'drawn': 2, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 21093,
#     'player_name': 'Gabriel Boschilia',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 21,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 67,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 28, 'key': 0, 'accuracy': 73},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 9, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 4},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10401,
#     'player_name': 'Paolo Guerrero',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 9,
#     'position': 'F',
#     'rating': '7.6',
#     'minutes_played': 66,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': 1,
#     'shots': {'total': 2, 'on': 1},
#     'goals': {'total': 1, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 14, 'key': 2, 'accuracy': 66},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 20, 'won': 10},
#     'dribbles': {'attempts': 3, 'success': 3, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 80166,
#     'player_name': 'Thiago Galhardo',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 17,
#     'position': 'F',
#     'rating': '6.9',
#     'minutes_played': 77,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 2, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 14, 'key': 1, 'accuracy': 77},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 9, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 44492,
#     'player_name': 'Marcos Guilherme',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 23,
#     'position': 'M',
#     'rating': '6.2',
#     'minutes_played': 23,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 8, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 2},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 47577,
#     'player_name': 'Damián Musto',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 5,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 13,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 12, 'key': 0, 'accuracy': 70},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 195090,
#     'player_name': 'Peglow',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 31,
#     'position': 'F',
#     'rating': '6.7',
#     'minutes_played': 13,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 5, 'key': 0, 'accuracy': 62},
#     'tackles': {'total': 3, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 6, 'won': 3},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 2},
#     'fouls': {'drawn': 0, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10400,
#     'player_name': 'William Pottker',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 7,
#     'position': 'F',
#     'rating': '6.3',
#     'minutes_played': 24,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 4, 'key': 1, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 2, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328005,
#     'updateAt': 1597654203,
#     'player_id': 10007,
#     'player_name': 'Yuri Alberto',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 11,
#     'position': 'F',
#     'rating': '6.5',
#     'minutes_played': 14,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 1, 'key': 0, 'accuracy': 33},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}}]}}

# %%
times = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
gols = [fix['api']['fixtures'][0]['goalsHomeTeam'],fix['api']['fixtures'][0]['goalsAwayTeam']]
posse = [match['api']['statistics']['Ball Possession']['home'],match['api']['statistics']['Ball Possession']['away']]
chutes = [match['api']['statistics']['Total Shots']['home'],match['api']['statistics']['Total Shots']['away']]
chutes_a_gol = [int(chutes[0])-int(match['api']['statistics']['Shots off Goal']['home'])-int(match['api']['statistics']['Blocked Shots']['home']),
               int(chutes[1])-int(match['api']['statistics']['Shots off Goal']['away'])-int(match['api']['statistics']['Blocked Shots']['away'])]
amarelos = [match['api']['statistics']['Yellow Cards']['home'],match['api']['statistics']['Yellow Cards']['away']]
vermelhos = [match['api']['statistics']['Red Cards']['home'],match['api']['statistics']['Red Cards']['away']]
acerto_passes = [match['api']['statistics']['Passes %']['home'],match['api']['statistics']['Passes %']['away']]
chutes_dentro_area = [match['api']['statistics']['Shots insidebox']['home'],match['api']['statistics']['Shots insidebox']['away']]
chutes_fora_area = [match['api']['statistics']['Shots outsidebox']['home'],match['api']['statistics']['Shots outsidebox']['away']]
faltas = [match['api']['statistics']['Fouls']['home'],match['api']['statistics']['Fouls']['away']]
defesas_goleiro = [match['api']['statistics']['Goalkeeper Saves']['home'],match['api']['statistics']['Goalkeeper Saves']['away']]

# %%
geral = pd.DataFrame([gols, posse, chutes, chutes_a_gol, amarelos, vermelhos, acerto_passes,chutes_dentro_area,chutes_fora_area,
                     faltas,defesas_goleiro],
                     index=['Placar','Posse de bola','Chutes','Chutes no gol','Cartões amarelos','Cartões vermelhos','Passes acertados',
                           'Chutes dentro área','Chutes fora área','Faltas','Defesas do goleiro'],
                    columns = times)
print('Visão Geral')
geral
# Out:
# Visão Geral
#                    Fluminense Internacional
# Placar                      2             1
# Posse de bola             43%           57%
# Chutes                     10             9
# Chutes no gol               5             3
# Cartões amarelos            2             2
# Cartões vermelhos        None          None
# Passes acertados          76%           78%
# Chutes dentro área          8             5
# Chutes fora área            2             4
# Faltas                     13            24
# Defesas do goleiro          1             3

# %%
#Players data to dataframe
players_Df = pd.DataFrame(match_palyers['api']['players'])
players_Df
# Out:
#     event_id    updateAt  player_id        player_name  team_id  \
# 0     328005  1597654203    41227.0             Muriel      124
# 1     328005  1597654203    10300.0        Igor Julião      124
# 2     328005  1597654203    10306.0               Nino      124
# 3     328005  1597654203    61809.0       Luccas Claro      124
# 4     328005  1597654203    10084.0             Egídio      124
# 5     328005  1597654203    51701.0      Michel Araújo      124
# 6     328005  1597654203    10315.0               Yuri      124
# 7     328005  1597654203    10314.0    Douglas Moreira      124
# 8     328005  1597654203     9970.0               Nenê      124
# 9     328005  1597654203   152856.0          Evanilson      124
# 10    328005  1597654203    10322.0       Marcos Paulo      124
# 11    328005  1597654203    10398.0   Wellington Silva      124
# 12    328005  1597654203    10348.0        Yago Felipe      124
# 13    328005  1597654203    10311.0              Ganso      124
# 14    328005  1597654203   265785.0      Luiz Henrique      124
# 15    328005  1597654203    10372.0      Marcelo Lomba      119
# 16    328005  1597654203     2470.0      Renzo Saravia      119
# 17    328005  1597654203        NaN         Zé Gabriel      119
# 18    328005  1597654203    10377.0      Víctor Cuesta      119
# 19    328005  1597654203    10013.0             Moisés      119
# 20    328005  1597654203    10387.0          Edenílson      119
# 21    328005  1597654203    10395.0    Rodrigo Lindoso      119
# 22    328005  1597654203    10388.0            Patrick      119
# 23    328005  1597654203    21093.0  Gabriel Boschilia      119
# 24    328005  1597654203    10401.0     Paolo Guerrero      119
# 25    328005  1597654203    80166.0    Thiago Galhardo      119
# 26    328005  1597654203    44492.0   Marcos Guilherme      119
# 27    328005  1597654203    47577.0       Damián Musto      119
# 28    328005  1597654203   195090.0             Peglow      119
# 29    328005  1597654203    10400.0    William Pottker      119
# 30    328005  1597654203    10007.0       Yuri Alberto      119
#
#         team_name  number position rating  minutes_played  ... offsides  \
# 0      Fluminense      27        G    6.3              90  ...      NaN
# 1      Fluminense      21        D    6.3              90  ...      NaN
# 2      Fluminense      33        D    6.6              90  ...      NaN
# 3      Fluminense       4        D    7.5              90  ...      NaN
# 4      Fluminense       6        D    7.3              90  ...      NaN
# 5      Fluminense      15        M    6.6              73  ...      NaN
# 6      Fluminense       5        M    6.3              90  ...      NaN
# 7      Fluminense      22        M    6.6              90  ...      NaN
# 8      Fluminense      77        F    8.2              83  ...      NaN
# 9      Fluminense      99        F    7.2              89  ...      NaN
# 10     Fluminense      11        F    6.3              73  ...      1.0
# 11     Fluminense      17        M    6.2              17  ...      NaN
# 12     Fluminense      20        M    6.5               8  ...      NaN
# 13     Fluminense      10        M    6.7              14  ...      NaN
# 14     Fluminense      34        F    6.7              17  ...      NaN
# 15  Internacional      12        G    6.5              90  ...      NaN
# 16  Internacional      26        D    6.6              90  ...      NaN
# 17  Internacional      35        D    6.6              90  ...      NaN
# 18  Internacional      15        D    6.2              90  ...      NaN
# 19  Internacional      16        D    6.7              90  ...      NaN
# 20  Internacional       8        M    6.5              90  ...      NaN
# 21  Internacional      19        M    7.2              77  ...      NaN
# 22  Internacional      88        M    6.6              83  ...      NaN
# 23  Internacional      21        M    6.5              67  ...      NaN
# 24  Internacional       9        F    7.6              66  ...      1.0
# 25  Internacional      17        F    6.9              77  ...      NaN
# 26  Internacional      23        M    6.2              23  ...      NaN
# 27  Internacional       5        M    6.7              13  ...      NaN
# 28  Internacional      31        F    6.7              13  ...      NaN
# 29  Internacional       7        F    6.3              24  ...      NaN
# 30  Internacional      11        F    6.5              14  ...      NaN
#
#                     shots                                              goals  \
# 0   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 1, 'assists': 0, 'sav...
# 1   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 2   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 3, 'on': 2}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 2, 'on': 2}  {'total': 2, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 10  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 15  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 2, 'assists': 0, 'sav...
# 16  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 1, 'sav...
# 22  {'total': 2, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 2, 'on': 1}  {'total': 1, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 2, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 30  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                      passes  \
# 0    {'total': 6, 'key': 0, 'accuracy': 42}
# 1   {'total': 17, 'key': 1, 'accuracy': 63}
# 2   {'total': 22, 'key': 0, 'accuracy': 68}
# 3   {'total': 26, 'key': 0, 'accuracy': 78}
# 4   {'total': 40, 'key': 0, 'accuracy': 81}
# 5   {'total': 20, 'key': 0, 'accuracy': 74}
# 6   {'total': 37, 'key': 0, 'accuracy': 82}
# 7   {'total': 28, 'key': 0, 'accuracy': 87}
# 8   {'total': 25, 'key': 1, 'accuracy': 83}
# 9   {'total': 14, 'key': 4, 'accuracy': 82}
# 10  {'total': 15, 'key': 0, 'accuracy': 68}
# 11  {'total': 1, 'key': 0, 'accuracy': 100}
# 12  {'total': 1, 'key': 0, 'accuracy': 100}
# 13   {'total': 3, 'key': 0, 'accuracy': 75}
# 14   {'total': 4, 'key': 0, 'accuracy': 80}
# 15  {'total': 14, 'key': 0, 'accuracy': 66}
# 16  {'total': 29, 'key': 0, 'accuracy': 82}
# 17  {'total': 39, 'key': 0, 'accuracy': 81}
# 18  {'total': 41, 'key': 0, 'accuracy': 83}
# 19  {'total': 48, 'key': 0, 'accuracy': 76}
# 20  {'total': 26, 'key': 1, 'accuracy': 76}
# 21  {'total': 39, 'key': 2, 'accuracy': 84}
# 22  {'total': 17, 'key': 0, 'accuracy': 81}
# 23  {'total': 28, 'key': 0, 'accuracy': 73}
# 24  {'total': 14, 'key': 2, 'accuracy': 66}
# 25  {'total': 14, 'key': 1, 'accuracy': 77}
# 26  {'total': 8, 'key': 0, 'accuracy': 100}
# 27  {'total': 12, 'key': 0, 'accuracy': 70}
# 28   {'total': 5, 'key': 0, 'accuracy': 62}
# 29  {'total': 4, 'key': 1, 'accuracy': 100}
# 30   {'total': 1, 'key': 0, 'accuracy': 33}
#
#                                           tackles                     duels  \
# 0   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 1   {'total': 2, 'blocks': 1, 'interceptions': 0}   {'total': 11, 'won': 5}
# 2   {'total': 1, 'blocks': 1, 'interceptions': 4}  {'total': 17, 'won': 10}
# 3   {'total': 3, 'blocks': 1, 'interceptions': 2}   {'total': 11, 'won': 8}
# 4   {'total': 5, 'blocks': 0, 'interceptions': 0}  {'total': 14, 'won': 11}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 2}   {'total': 10, 'won': 6}
# 6   {'total': 2, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 4}
# 7   {'total': 1, 'blocks': 0, 'interceptions': 3}    {'total': 7, 'won': 3}
# 8   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 7, 'won': 3}
# 9   {'total': 2, 'blocks': 0, 'interceptions': 1}   {'total': 21, 'won': 8}
# 10  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 8, 'won': 2}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 7, 'won': 2}
# 12  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 13  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 14  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 6, 'won': 3}
# 15  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 0, 'won': 0}
# 16  {'total': 4, 'blocks': 1, 'interceptions': 1}   {'total': 15, 'won': 9}
# 17  {'total': 6, 'blocks': 0, 'interceptions': 1}  {'total': 13, 'won': 10}
# 18  {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 7}
# 19  {'total': 2, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 5}
# 20  {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 14, 'won': 7}
# 21  {'total': 2, 'blocks': 1, 'interceptions': 2}   {'total': 11, 'won': 5}
# 22  {'total': 1, 'blocks': 1, 'interceptions': 1}   {'total': 12, 'won': 6}
# 23  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 2}
# 24  {'total': 0, 'blocks': 0, 'interceptions': 0}  {'total': 20, 'won': 10}
# 25  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 2}
# 26  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 27  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 28  {'total': 3, 'blocks': 0, 'interceptions': 0}    {'total': 6, 'won': 3}
# 29  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 0}
# 30  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
#
#                                     dribbles                         fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 1   {'attempts': 3, 'success': 1, 'past': 1}  {'drawn': 1, 'committed': 1}
# 2   {'attempts': 0, 'success': 0, 'past': 3}  {'drawn': 1, 'committed': 2}
# 3   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 2, 'committed': 1}
# 4   {'attempts': 2, 'success': 2, 'past': 1}  {'drawn': 3, 'committed': 1}
# 5   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 4, 'committed': 1}
# 6   {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 1, 'committed': 3}
# 7   {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 1}
# 8   {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 3, 'committed': 0}
# 9   {'attempts': 3, 'success': 2, 'past': 1}  {'drawn': 4, 'committed': 1}
# 10  {'attempts': 2, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 0}
# 11  {'attempts': 2, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 12  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 13  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 0}
# 14  {'attempts': 1, 'success': 1, 'past': 1}  {'drawn': 0, 'committed': 0}
# 15  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 16  {'attempts': 1, 'success': 1, 'past': 1}  {'drawn': 3, 'committed': 2}
# 17  {'attempts': 1, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 2}
# 18  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 4}
# 19  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 2}
# 20  {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 1, 'committed': 2}
# 21  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 1}
# 22  {'attempts': 4, 'success': 2, 'past': 1}  {'drawn': 2, 'committed': 2}
# 23  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 4}
# 24  {'attempts': 3, 'success': 3, 'past': 0}  {'drawn': 2, 'committed': 2}
# 25  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 2}
# 26  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 0}
# 27  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 28  {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 0, 'committed': 1}
# 29  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 30  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
#
#                       cards                                            penalty
# 0   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 1   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 2   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 3   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 4   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 5   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 6   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 7   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 8   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 2, 'misse...
# 9   {'yellow': 0, 'red': 0}  {'won': 1, 'commited': 0, 'success': 0, 'misse...
# 10  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 11  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 12  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 13  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 14  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 15  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 16  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 17  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 1, 'success': 0, 'misse...
# 18  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 1, 'success': 0, 'misse...
# 19  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 20  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 21  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 22  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 23  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 24  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 25  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 26  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 27  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 28  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 29  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 30  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
#
# [31 rows x 22 columns]

# %%
#Open shots data to columns
shots_Df = pd.DataFrame(players_Df['shots'])
shots_rows = []
for r in range(0,len(shots_Df)):
    shots_rows.append(list(shots_Df.loc[r,'shots'].values()))
    
open_shots = pd.DataFrame(shots_rows,columns=['total shots','on goal'])
n_players_Df = pd.concat([players_Df,open_shots],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id        player_name  team_id  \
# 0     328005  1597654203    41227.0             Muriel      124
# 1     328005  1597654203    10300.0        Igor Julião      124
# 2     328005  1597654203    10306.0               Nino      124
# 3     328005  1597654203    61809.0       Luccas Claro      124
# 4     328005  1597654203    10084.0             Egídio      124
# 5     328005  1597654203    51701.0      Michel Araújo      124
# 6     328005  1597654203    10315.0               Yuri      124
# 7     328005  1597654203    10314.0    Douglas Moreira      124
# 8     328005  1597654203     9970.0               Nenê      124
# 9     328005  1597654203   152856.0          Evanilson      124
# 10    328005  1597654203    10322.0       Marcos Paulo      124
# 11    328005  1597654203    10398.0   Wellington Silva      124
# 12    328005  1597654203    10348.0        Yago Felipe      124
# 13    328005  1597654203    10311.0              Ganso      124
# 14    328005  1597654203   265785.0      Luiz Henrique      124
# 15    328005  1597654203    10372.0      Marcelo Lomba      119
# 16    328005  1597654203     2470.0      Renzo Saravia      119
# 17    328005  1597654203        NaN         Zé Gabriel      119
# 18    328005  1597654203    10377.0      Víctor Cuesta      119
# 19    328005  1597654203    10013.0             Moisés      119
# 20    328005  1597654203    10387.0          Edenílson      119
# 21    328005  1597654203    10395.0    Rodrigo Lindoso      119
# 22    328005  1597654203    10388.0            Patrick      119
# 23    328005  1597654203    21093.0  Gabriel Boschilia      119
# 24    328005  1597654203    10401.0     Paolo Guerrero      119
# 25    328005  1597654203    80166.0    Thiago Galhardo      119
# 26    328005  1597654203    44492.0   Marcos Guilherme      119
# 27    328005  1597654203    47577.0       Damián Musto      119
# 28    328005  1597654203   195090.0             Peglow      119
# 29    328005  1597654203    10400.0    William Pottker      119
# 30    328005  1597654203    10007.0       Yuri Alberto      119
#
#         team_name  number position rating  minutes_played  ...  \
# 0      Fluminense      27        G    6.3              90  ...
# 1      Fluminense      21        D    6.3              90  ...
# 2      Fluminense      33        D    6.6              90  ...
# 3      Fluminense       4        D    7.5              90  ...
# 4      Fluminense       6        D    7.3              90  ...
# 5      Fluminense      15        M    6.6              73  ...
# 6      Fluminense       5        M    6.3              90  ...
# 7      Fluminense      22        M    6.6              90  ...
# 8      Fluminense      77        F    8.2              83  ...
# 9      Fluminense      99        F    7.2              89  ...
# 10     Fluminense      11        F    6.3              73  ...
# 11     Fluminense      17        M    6.2              17  ...
# 12     Fluminense      20        M    6.5               8  ...
# 13     Fluminense      10        M    6.7              14  ...
# 14     Fluminense      34        F    6.7              17  ...
# 15  Internacional      12        G    6.5              90  ...
# 16  Internacional      26        D    6.6              90  ...
# 17  Internacional      35        D    6.6              90  ...
# 18  Internacional      15        D    6.2              90  ...
# 19  Internacional      16        D    6.7              90  ...
# 20  Internacional       8        M    6.5              90  ...
# 21  Internacional      19        M    7.2              77  ...
# 22  Internacional      88        M    6.6              83  ...
# 23  Internacional      21        M    6.5              67  ...
# 24  Internacional       9        F    7.6              66  ...
# 25  Internacional      17        F    6.9              77  ...
# 26  Internacional      23        M    6.2              23  ...
# 27  Internacional       5        M    6.7              13  ...
# 28  Internacional      31        F    6.7              13  ...
# 29  Internacional       7        F    6.3              24  ...
# 30  Internacional      11        F    6.5              14  ...
#
#                                                 goals  \
# 0   {'total': 0, 'conceded': 1, 'assists': 0, 'sav...
# 1   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 2   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 2, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 10  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 15  {'total': 0, 'conceded': 2, 'assists': 0, 'sav...
# 16  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'conceded': 0, 'assists': 1, 'sav...
# 22  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 1, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 30  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                      passes  \
# 0    {'total': 6, 'key': 0, 'accuracy': 42}
# 1   {'total': 17, 'key': 1, 'accuracy': 63}
# 2   {'total': 22, 'key': 0, 'accuracy': 68}
# 3   {'total': 26, 'key': 0, 'accuracy': 78}
# 4   {'total': 40, 'key': 0, 'accuracy': 81}
# 5   {'total': 20, 'key': 0, 'accuracy': 74}
# 6   {'total': 37, 'key': 0, 'accuracy': 82}
# 7   {'total': 28, 'key': 0, 'accuracy': 87}
# 8   {'total': 25, 'key': 1, 'accuracy': 83}
# 9   {'total': 14, 'key': 4, 'accuracy': 82}
# 10  {'total': 15, 'key': 0, 'accuracy': 68}
# 11  {'total': 1, 'key': 0, 'accuracy': 100}
# 12  {'total': 1, 'key': 0, 'accuracy': 100}
# 13   {'total': 3, 'key': 0, 'accuracy': 75}
# 14   {'total': 4, 'key': 0, 'accuracy': 80}
# 15  {'total': 14, 'key': 0, 'accuracy': 66}
# 16  {'total': 29, 'key': 0, 'accuracy': 82}
# 17  {'total': 39, 'key': 0, 'accuracy': 81}
# 18  {'total': 41, 'key': 0, 'accuracy': 83}
# 19  {'total': 48, 'key': 0, 'accuracy': 76}
# 20  {'total': 26, 'key': 1, 'accuracy': 76}
# 21  {'total': 39, 'key': 2, 'accuracy': 84}
# 22  {'total': 17, 'key': 0, 'accuracy': 81}
# 23  {'total': 28, 'key': 0, 'accuracy': 73}
# 24  {'total': 14, 'key': 2, 'accuracy': 66}
# 25  {'total': 14, 'key': 1, 'accuracy': 77}
# 26  {'total': 8, 'key': 0, 'accuracy': 100}
# 27  {'total': 12, 'key': 0, 'accuracy': 70}
# 28   {'total': 5, 'key': 0, 'accuracy': 62}
# 29  {'total': 4, 'key': 1, 'accuracy': 100}
# 30   {'total': 1, 'key': 0, 'accuracy': 33}
#
#                                           tackles                     duels  \
# 0   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 1   {'total': 2, 'blocks': 1, 'interceptions': 0}   {'total': 11, 'won': 5}
# 2   {'total': 1, 'blocks': 1, 'interceptions': 4}  {'total': 17, 'won': 10}
# 3   {'total': 3, 'blocks': 1, 'interceptions': 2}   {'total': 11, 'won': 8}
# 4   {'total': 5, 'blocks': 0, 'interceptions': 0}  {'total': 14, 'won': 11}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 2}   {'total': 10, 'won': 6}
# 6   {'total': 2, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 4}
# 7   {'total': 1, 'blocks': 0, 'interceptions': 3}    {'total': 7, 'won': 3}
# 8   {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 7, 'won': 3}
# 9   {'total': 2, 'blocks': 0, 'interceptions': 1}   {'total': 21, 'won': 8}
# 10  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 8, 'won': 2}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 7, 'won': 2}
# 12  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 13  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 14  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 6, 'won': 3}
# 15  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 0, 'won': 0}
# 16  {'total': 4, 'blocks': 1, 'interceptions': 1}   {'total': 15, 'won': 9}
# 17  {'total': 6, 'blocks': 0, 'interceptions': 1}  {'total': 13, 'won': 10}
# 18  {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 7}
# 19  {'total': 2, 'blocks': 0, 'interceptions': 1}    {'total': 8, 'won': 5}
# 20  {'total': 3, 'blocks': 0, 'interceptions': 0}   {'total': 14, 'won': 7}
# 21  {'total': 2, 'blocks': 1, 'interceptions': 2}   {'total': 11, 'won': 5}
# 22  {'total': 1, 'blocks': 1, 'interceptions': 1}   {'total': 12, 'won': 6}
# 23  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 2}
# 24  {'total': 0, 'blocks': 0, 'interceptions': 0}  {'total': 20, 'won': 10}
# 25  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 9, 'won': 2}
# 26  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 2}
# 27  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 28  {'total': 3, 'blocks': 0, 'interceptions': 0}    {'total': 6, 'won': 3}
# 29  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 0}
# 30  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
#
#                                     dribbles                         fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 1   {'attempts': 3, 'success': 1, 'past': 1}  {'drawn': 1, 'committed': 1}
# 2   {'attempts': 0, 'success': 0, 'past': 3}  {'drawn': 1, 'committed': 2}
# 3   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 2, 'committed': 1}
# 4   {'attempts': 2, 'success': 2, 'past': 1}  {'drawn': 3, 'committed': 1}
# 5   {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 4, 'committed': 1}
# 6   {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 1, 'committed': 3}
# 7   {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 1}
# 8   {'attempts': 0, 'success': 0, 'past': 1}  {'drawn': 3, 'committed': 0}
# 9   {'attempts': 3, 'success': 2, 'past': 1}  {'drawn': 4, 'committed': 1}
# 10  {'attempts': 2, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 0}
# 11  {'attempts': 2, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 12  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 1}
# 13  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 0}
# 14  {'attempts': 1, 'success': 1, 'past': 1}  {'drawn': 0, 'committed': 0}
# 15  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 16  {'attempts': 1, 'success': 1, 'past': 1}  {'drawn': 3, 'committed': 2}
# 17  {'attempts': 1, 'success': 0, 'past': 0}  {'drawn': 1, 'committed': 2}
# 18  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 4}
# 19  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 0, 'committed': 2}
# 20  {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 1, 'committed': 2}
# 21  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 1}
# 22  {'attempts': 4, 'success': 2, 'past': 1}  {'drawn': 2, 'committed': 2}
# 23  {'attempts': 1, 'success': 1, 'past': 0}  {'drawn': 1, 'committed': 4}
# 24  {'attempts': 3, 'success': 3, 'past': 0}  {'drawn': 2, 'committed': 2}
# 25  {'attempts': 1, 'success': 0, 'past': 1}  {'drawn': 1, 'committed': 2}
# 26  {'attempts': 1, 'success': 1, 'past': 2}  {'drawn': 0, 'committed': 0}
# 27  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 28  {'attempts': 0, 'success': 0, 'past': 2}  {'drawn': 0, 'committed': 1}
# 29  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
# 30  {'attempts': 0, 'success': 0, 'past': 0}  {'drawn': 0, 'committed': 0}
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 1, 'red': 0}
# 3   {'yellow': 0, 'red': 0}
# 4   {'yellow': 0, 'red': 0}
# 5   {'yellow': 0, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 1, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 0, 'red': 0}
# 16  {'yellow': 0, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 0, 'red': 0}
# 20  {'yellow': 1, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 1, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 0, 'red': 0}
# 30  {'yellow': 0, 'red': 0}
#
#                                               penalty total shots on goal
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           3       2
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 8   {'won': 0, 'commited': 0, 'success': 2, 'misse...           2       2
# 9   {'won': 1, 'commited': 0, 'success': 0, 'misse...           0       0
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 17  {'won': 0, 'commited': 1, 'success': 0, 'misse...           0       0
# 18  {'won': 0, 'commited': 1, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       1
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       1
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 30  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
#
# [31 rows x 24 columns]

# %%
time = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
shots_position=[]

for p in position:
    shots_aux = []
    for t in time:
        shots_aux.append(n_players_Df[(n_players_Df['position']==p) & (n_players_Df['team_name']==t)]['total shots'].sum())
        
    shots_position.append(shots_aux)

shots_position_df = pd.DataFrame(shots_position, index=position, columns = time)
print('Shots by team and position')
shots_position_df
# Out:
# Shots by team and position
#    Fluminense  Internacional
# G           0              0
# M           2              4
# F           3              4
# D           5              1

# %%
#Total shots by player
import seaborn as sns
import matplotlib.pyplot as plt

home_player_shots=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['total shots','player_name','team_name']]
home_player_shots = home_player_shots[home_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
home_graph = sns.barplot(x=home_player_shots['total shots'],y=home_player_shots['player_name'],palette='Greens')
home_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,3)
plt.show()

away_player_shots=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['total shots','player_name','team_name']]
away_player_shots = away_player_shots[away_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
away_graph = sns.barplot(x=away_player_shots['total shots'],y=away_player_shots['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,3)
plt.show()

# %%
#passes
passes_Df = pd.DataFrame(players_Df['passes'])
passes_rows = []
for r in range(0,len(passes_Df)):
    passes_rows.append(list(passes_Df.loc[r,'passes'].values()))
    
open_passes = pd.DataFrame(passes_rows,columns=['total passes','keys','accuracy'])
n_players_Df = pd.concat([n_players_Df,open_passes],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id        player_name  team_id  \
# 0     328005  1597654203    41227.0             Muriel      124
# 1     328005  1597654203    10300.0        Igor Julião      124
# 2     328005  1597654203    10306.0               Nino      124
# 3     328005  1597654203    61809.0       Luccas Claro      124
# 4     328005  1597654203    10084.0             Egídio      124
# 5     328005  1597654203    51701.0      Michel Araújo      124
# 6     328005  1597654203    10315.0               Yuri      124
# 7     328005  1597654203    10314.0    Douglas Moreira      124
# 8     328005  1597654203     9970.0               Nenê      124
# 9     328005  1597654203   152856.0          Evanilson      124
# 10    328005  1597654203    10322.0       Marcos Paulo      124
# 11    328005  1597654203    10398.0   Wellington Silva      124
# 12    328005  1597654203    10348.0        Yago Felipe      124
# 13    328005  1597654203    10311.0              Ganso      124
# 14    328005  1597654203   265785.0      Luiz Henrique      124
# 15    328005  1597654203    10372.0      Marcelo Lomba      119
# 16    328005  1597654203     2470.0      Renzo Saravia      119
# 17    328005  1597654203        NaN         Zé Gabriel      119
# 18    328005  1597654203    10377.0      Víctor Cuesta      119
# 19    328005  1597654203    10013.0             Moisés      119
# 20    328005  1597654203    10387.0          Edenílson      119
# 21    328005  1597654203    10395.0    Rodrigo Lindoso      119
# 22    328005  1597654203    10388.0            Patrick      119
# 23    328005  1597654203    21093.0  Gabriel Boschilia      119
# 24    328005  1597654203    10401.0     Paolo Guerrero      119
# 25    328005  1597654203    80166.0    Thiago Galhardo      119
# 26    328005  1597654203    44492.0   Marcos Guilherme      119
# 27    328005  1597654203    47577.0       Damián Musto      119
# 28    328005  1597654203   195090.0             Peglow      119
# 29    328005  1597654203    10400.0    William Pottker      119
# 30    328005  1597654203    10007.0       Yuri Alberto      119
#
#         team_name  number position rating  minutes_played  ...  \
# 0      Fluminense      27        G    6.3              90  ...
# 1      Fluminense      21        D    6.3              90  ...
# 2      Fluminense      33        D    6.6              90  ...
# 3      Fluminense       4        D    7.5              90  ...
# 4      Fluminense       6        D    7.3              90  ...
# 5      Fluminense      15        M    6.6              73  ...
# 6      Fluminense       5        M    6.3              90  ...
# 7      Fluminense      22        M    6.6              90  ...
# 8      Fluminense      77        F    8.2              83  ...
# 9      Fluminense      99        F    7.2              89  ...
# 10     Fluminense      11        F    6.3              73  ...
# 11     Fluminense      17        M    6.2              17  ...
# 12     Fluminense      20        M    6.5               8  ...
# 13     Fluminense      10        M    6.7              14  ...
# 14     Fluminense      34        F    6.7              17  ...
# 15  Internacional      12        G    6.5              90  ...
# 16  Internacional      26        D    6.6              90  ...
# 17  Internacional      35        D    6.6              90  ...
# 18  Internacional      15        D    6.2              90  ...
# 19  Internacional      16        D    6.7              90  ...
# 20  Internacional       8        M    6.5              90  ...
# 21  Internacional      19        M    7.2              77  ...
# 22  Internacional      88        M    6.6              83  ...
# 23  Internacional      21        M    6.5              67  ...
# 24  Internacional       9        F    7.6              66  ...
# 25  Internacional      17        F    6.9              77  ...
# 26  Internacional      23        M    6.2              23  ...
# 27  Internacional       5        M    6.7              13  ...
# 28  Internacional      31        F    6.7              13  ...
# 29  Internacional       7        F    6.3              24  ...
# 30  Internacional      11        F    6.5              14  ...
#
#                        duels                                  dribbles  \
# 0     {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 1    {'total': 11, 'won': 5}  {'attempts': 3, 'success': 1, 'past': 1}
# 2   {'total': 17, 'won': 10}  {'attempts': 0, 'success': 0, 'past': 3}
# 3    {'total': 11, 'won': 8}  {'attempts': 1, 'success': 1, 'past': 0}
# 4   {'total': 14, 'won': 11}  {'attempts': 2, 'success': 2, 'past': 1}
# 5    {'total': 10, 'won': 6}  {'attempts': 1, 'success': 1, 'past': 0}
# 6    {'total': 12, 'won': 4}  {'attempts': 0, 'success': 0, 'past': 2}
# 7     {'total': 7, 'won': 3}  {'attempts': 0, 'success': 0, 'past': 1}
# 8     {'total': 7, 'won': 3}  {'attempts': 0, 'success': 0, 'past': 1}
# 9    {'total': 21, 'won': 8}  {'attempts': 3, 'success': 2, 'past': 1}
# 10    {'total': 8, 'won': 2}  {'attempts': 2, 'success': 1, 'past': 0}
# 11    {'total': 7, 'won': 2}  {'attempts': 2, 'success': 1, 'past': 0}
# 12    {'total': 5, 'won': 2}  {'attempts': 1, 'success': 1, 'past': 0}
# 13    {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 14    {'total': 6, 'won': 3}  {'attempts': 1, 'success': 1, 'past': 1}
# 15    {'total': 0, 'won': 0}  {'attempts': 0, 'success': 0, 'past': 0}
# 16   {'total': 15, 'won': 9}  {'attempts': 1, 'success': 1, 'past': 1}
# 17  {'total': 13, 'won': 10}  {'attempts': 1, 'success': 0, 'past': 0}
# 18   {'total': 12, 'won': 7}  {'attempts': 1, 'success': 1, 'past': 0}
# 19    {'total': 8, 'won': 5}  {'attempts': 1, 'success': 1, 'past': 0}
# 20   {'total': 14, 'won': 7}  {'attempts': 0, 'success': 0, 'past': 2}
# 21   {'total': 11, 'won': 5}  {'attempts': 1, 'success': 1, 'past': 2}
# 22   {'total': 12, 'won': 6}  {'attempts': 4, 'success': 2, 'past': 1}
# 23    {'total': 9, 'won': 2}  {'attempts': 1, 'success': 1, 'past': 0}
# 24  {'total': 20, 'won': 10}  {'attempts': 3, 'success': 3, 'past': 0}
# 25    {'total': 9, 'won': 2}  {'attempts': 1, 'success': 0, 'past': 1}
# 26    {'total': 5, 'won': 2}  {'attempts': 1, 'success': 1, 'past': 2}
# 27    {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 28    {'total': 6, 'won': 3}  {'attempts': 0, 'success': 0, 'past': 2}
# 29    {'total': 2, 'won': 0}  {'attempts': 0, 'success': 0, 'past': 0}
# 30    {'total': 1, 'won': 0}  {'attempts': 0, 'success': 0, 'past': 0}
#
#                            fouls                    cards  \
# 0   {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 1   {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 2   {'drawn': 1, 'committed': 2}  {'yellow': 1, 'red': 0}
# 3   {'drawn': 2, 'committed': 1}  {'yellow': 0, 'red': 0}
# 4   {'drawn': 3, 'committed': 1}  {'yellow': 0, 'red': 0}
# 5   {'drawn': 4, 'committed': 1}  {'yellow': 0, 'red': 0}
# 6   {'drawn': 1, 'committed': 3}  {'yellow': 0, 'red': 0}
# 7   {'drawn': 1, 'committed': 1}  {'yellow': 1, 'red': 0}
# 8   {'drawn': 3, 'committed': 0}  {'yellow': 0, 'red': 0}
# 9   {'drawn': 4, 'committed': 1}  {'yellow': 0, 'red': 0}
# 10  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 11  {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 12  {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 13  {'drawn': 1, 'committed': 0}  {'yellow': 0, 'red': 0}
# 14  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 15  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 16  {'drawn': 3, 'committed': 2}  {'yellow': 0, 'red': 0}
# 17  {'drawn': 1, 'committed': 2}  {'yellow': 0, 'red': 0}
# 18  {'drawn': 0, 'committed': 4}  {'yellow': 0, 'red': 0}
# 19  {'drawn': 0, 'committed': 2}  {'yellow': 0, 'red': 0}
# 20  {'drawn': 1, 'committed': 2}  {'yellow': 1, 'red': 0}
# 21  {'drawn': 0, 'committed': 1}  {'yellow': 0, 'red': 0}
# 22  {'drawn': 2, 'committed': 2}  {'yellow': 0, 'red': 0}
# 23  {'drawn': 1, 'committed': 4}  {'yellow': 1, 'red': 0}
# 24  {'drawn': 2, 'committed': 2}  {'yellow': 0, 'red': 0}
# 25  {'drawn': 1, 'committed': 2}  {'yellow': 0, 'red': 0}
# 26  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 27  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 28  {'drawn': 0, 'committed': 1}  {'yellow': 0, 'red': 0}
# 29  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 30  {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
#
#                                               penalty total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           3       2
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 8   {'won': 0, 'commited': 0, 'success': 2, 'misse...           2       2
# 9   {'won': 1, 'commited': 0, 'success': 0, 'misse...           0       0
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 17  {'won': 0, 'commited': 1, 'success': 0, 'misse...           0       0
# 18  {'won': 0, 'commited': 1, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       1
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       1
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 30  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
#
#    total passes keys accuracy
# 0             6    0       42
# 1            17    1       63
# 2            22    0       68
# 3            26    0       78
# 4            40    0       81
# 5            20    0       74
# 6            37    0       82
# 7            28    0       87
# 8            25    1       83
# 9            14    4       82
# 10           15    0       68
# 11            1    0      100
# 12            1    0      100
# 13            3    0       75
# 14            4    0       80
# 15           14    0       66
# 16           29    0       82
# 17           39    0       81
# 18           41    0       83
# 19           48    0       76
# 20           26    1       76
# 21           39    2       84
# 22           17    0       81
# 23           28    0       73
# 24           14    2       66
# 25           14    1       77
# 26            8    0      100
# 27           12    0       70
# 28            5    0       62
# 29            4    1      100
# 30            1    0       33
#
# [31 rows x 27 columns]

# %%
#passes
time = [fix['api']['fixtures'][0]['homeTeam']['team_name'],fix['api']['fixtures'][0]['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
columns = ['Home_passes','Home_keys','Home_acc','Away_passes','Away_keys','Away_acc']
passes_position = []

for p in position:
    passes_aux = []
    for t in time:
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['total passes'].sum())
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['keys'].sum())
        
        pass_list=[]
        acc_list=[]
        for i in n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)].index:
            pass_list.append(n_players_Df.loc[i,'total passes'])
            acc_list.append(n_players_Df.loc[i,'accuracy'])
            
        lists = pass_list, acc_list
        passes_aux.append(sum([x * y for x, y in zip(*lists)])/sum(pass_list))
    
    passes_position.append(passes_aux)
    
passes_position_df = pd.DataFrame(passes_position, index=position, columns = columns)
passes_position_df
# Out:
#    Home_passes  Home_keys   Home_acc  Away_passes  Away_keys   Away_acc
# G            6          0  42.000000           14          0  66.000000
# M           90          0  81.944444          130          3  79.330769
# F           58          5  78.672414           38          4  72.236842
# D          105          1  74.619048          157          0  80.178344

# %%
passes_sum = pd.DataFrame([[passes_position_df[columns[0]].sum(),passes_position_df[columns[1]].sum(),passes_position_df[columns[2]].sum(),
                          passes_position_df[columns[3]].sum(),passes_position_df[columns[4]].sum(),passes_position_df[columns[5]].sum()]],
                         index=['Total'],columns = columns)
passes_sum
# Out:
#        Home_passes  Home_keys    Home_acc  Away_passes  Away_keys    Away_acc
# Total          259          6  277.235906          339          7  297.745955

# %%
#Key passes by player
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['keys','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['keys'],y=home_player_passes['player_name'],palette='Greens')
home_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,4)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['keys','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['keys'],y=away_player_passes['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,4)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['total passes','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['total passes'],y=home_player_passes['player_name'],palette='Greens')
home_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,60)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['total passes','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['total passes'],y=away_player_passes['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,60)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['accuracy','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['accuracy'],y=home_player_passes['player_name'])
home_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['accuracy','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['accuracy'],y=away_player_passes['player_name'])
away_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.show()

# %%
#tackles
tackles_Df = pd.DataFrame(players_Df['tackles'])
tackles_rows = []
for r in range(0,len(tackles_Df)):
    tackles_rows.append(list(tackles_Df.loc[r,'tackles'].values()))
    
open_tackles = pd.DataFrame(tackles_rows,columns=['Desarmes','bloqueios','interceptações'])
n_players_Df = pd.concat([n_players_Df,open_tackles],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id        player_name  team_id  \
# 0     328005  1597654203    41227.0             Muriel      124
# 1     328005  1597654203    10300.0        Igor Julião      124
# 2     328005  1597654203    10306.0               Nino      124
# 3     328005  1597654203    61809.0       Luccas Claro      124
# 4     328005  1597654203    10084.0             Egídio      124
# 5     328005  1597654203    51701.0      Michel Araújo      124
# 6     328005  1597654203    10315.0               Yuri      124
# 7     328005  1597654203    10314.0    Douglas Moreira      124
# 8     328005  1597654203     9970.0               Nenê      124
# 9     328005  1597654203   152856.0          Evanilson      124
# 10    328005  1597654203    10322.0       Marcos Paulo      124
# 11    328005  1597654203    10398.0   Wellington Silva      124
# 12    328005  1597654203    10348.0        Yago Felipe      124
# 13    328005  1597654203    10311.0              Ganso      124
# 14    328005  1597654203   265785.0      Luiz Henrique      124
# 15    328005  1597654203    10372.0      Marcelo Lomba      119
# 16    328005  1597654203     2470.0      Renzo Saravia      119
# 17    328005  1597654203        NaN         Zé Gabriel      119
# 18    328005  1597654203    10377.0      Víctor Cuesta      119
# 19    328005  1597654203    10013.0             Moisés      119
# 20    328005  1597654203    10387.0          Edenílson      119
# 21    328005  1597654203    10395.0    Rodrigo Lindoso      119
# 22    328005  1597654203    10388.0            Patrick      119
# 23    328005  1597654203    21093.0  Gabriel Boschilia      119
# 24    328005  1597654203    10401.0     Paolo Guerrero      119
# 25    328005  1597654203    80166.0    Thiago Galhardo      119
# 26    328005  1597654203    44492.0   Marcos Guilherme      119
# 27    328005  1597654203    47577.0       Damián Musto      119
# 28    328005  1597654203   195090.0             Peglow      119
# 29    328005  1597654203    10400.0    William Pottker      119
# 30    328005  1597654203    10007.0       Yuri Alberto      119
#
#         team_name  number position rating  minutes_played  ...  \
# 0      Fluminense      27        G    6.3              90  ...
# 1      Fluminense      21        D    6.3              90  ...
# 2      Fluminense      33        D    6.6              90  ...
# 3      Fluminense       4        D    7.5              90  ...
# 4      Fluminense       6        D    7.3              90  ...
# 5      Fluminense      15        M    6.6              73  ...
# 6      Fluminense       5        M    6.3              90  ...
# 7      Fluminense      22        M    6.6              90  ...
# 8      Fluminense      77        F    8.2              83  ...
# 9      Fluminense      99        F    7.2              89  ...
# 10     Fluminense      11        F    6.3              73  ...
# 11     Fluminense      17        M    6.2              17  ...
# 12     Fluminense      20        M    6.5               8  ...
# 13     Fluminense      10        M    6.7              14  ...
# 14     Fluminense      34        F    6.7              17  ...
# 15  Internacional      12        G    6.5              90  ...
# 16  Internacional      26        D    6.6              90  ...
# 17  Internacional      35        D    6.6              90  ...
# 18  Internacional      15        D    6.2              90  ...
# 19  Internacional      16        D    6.7              90  ...
# 20  Internacional       8        M    6.5              90  ...
# 21  Internacional      19        M    7.2              77  ...
# 22  Internacional      88        M    6.6              83  ...
# 23  Internacional      21        M    6.5              67  ...
# 24  Internacional       9        F    7.6              66  ...
# 25  Internacional      17        F    6.9              77  ...
# 26  Internacional      23        M    6.2              23  ...
# 27  Internacional       5        M    6.7              13  ...
# 28  Internacional      31        F    6.7              13  ...
# 29  Internacional       7        F    6.3              24  ...
# 30  Internacional      11        F    6.5              14  ...
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 1, 'red': 0}
# 3   {'yellow': 0, 'red': 0}
# 4   {'yellow': 0, 'red': 0}
# 5   {'yellow': 0, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 1, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 0, 'red': 0}
# 16  {'yellow': 0, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 0, 'red': 0}
# 20  {'yellow': 1, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 1, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 0, 'red': 0}
# 30  {'yellow': 0, 'red': 0}
#
#                                               penalty  total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...            3       2
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       1
# 8   {'won': 0, 'commited': 0, 'success': 2, 'misse...            2       2
# 9   {'won': 1, 'commited': 0, 'success': 0, 'misse...            0       0
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 17  {'won': 0, 'commited': 1, 'success': 0, 'misse...            0       0
# 18  {'won': 0, 'commited': 1, 'success': 0, 'misse...            0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       1
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...            2       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...            2       1
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...            2       1
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 30  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
#
#    total passes keys accuracy Desarmes bloqueios interceptações
# 0             6    0       42        0         0              0
# 1            17    1       63        2         1              0
# 2            22    0       68        1         1              4
# 3            26    0       78        3         1              2
# 4            40    0       81        5         0              0
# 5            20    0       74        0         0              2
# 6            37    0       82        2         0              0
# 7            28    0       87        1         0              3
# 8            25    1       83        0         0              0
# 9            14    4       82        2         0              1
# 10           15    0       68        1         0              0
# 11            1    0      100        0         0              1
# 12            1    0      100        0         0              0
# 13            3    0       75        0         0              0
# 14            4    0       80        1         0              0
# 15           14    0       66        0         0              0
# 16           29    0       82        4         1              1
# 17           39    0       81        6         0              1
# 18           41    0       83        3         0              0
# 19           48    0       76        2         0              1
# 20           26    1       76        3         0              0
# 21           39    2       84        2         1              2
# 22           17    0       81        1         1              1
# 23           28    0       73        0         0              0
# 24           14    2       66        0         0              0
# 25           14    1       77        1         0              0
# 26            8    0      100        1         0              0
# 27           12    0       70        1         0              0
# 28            5    0       62        3         0              0
# 29            4    1      100        0         0              0
# 30            1    0       33        0         0              0
#
# [31 rows x 30 columns]

# %%
tackles_players = n_players_Df[n_players_Df['position']=='D'][['player_name','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players

#Tackles by player
home_player_tackles=tackles_players[n_players_Df['team_name']==fix['api']['fixtures'][0]['homeTeam']['team_name']][['player_name','interceptações','team_name']]
home_player_tackles = home_player_tackles[home_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
home_graph = sns.barplot(x=home_player_tackles['interceptações'],y=home_player_tackles['player_name'],palette='Blues')
home_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['api']['fixtures'][0]['homeTeam']['team_name'])
plt.xlim(0,5)
plt.show()

away_player_tackles=tackles_players[n_players_Df['team_name']==fix['api']['fixtures'][0]['awayTeam']['team_name']][['player_name','interceptações','team_name']]
away_player_tackles = away_player_tackles[away_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
away_graph = sns.barplot(x=away_player_tackles['interceptações'],y=away_player_tackles['player_name'],palette='Reds')
away_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['api']['fixtures'][0]['awayTeam']['team_name'])
plt.xlim(0,5)
plt.show()
# Out:
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':

# %%
tackles_players = n_players_Df[['player_name','position','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players
# Out:
#           player_name position      team_name  Desarmes  bloqueios  \
# 0              Muriel        G     Fluminense         0          0
# 1         Igor Julião        D     Fluminense         2          1
# 2                Nino        D     Fluminense         1          1
# 3        Luccas Claro        D     Fluminense         3          1
# 4              Egídio        D     Fluminense         5          0
# 5       Michel Araújo        M     Fluminense         0          0
# 6                Yuri        M     Fluminense         2          0
# 7     Douglas Moreira        M     Fluminense         1          0
# 8                Nenê        F     Fluminense         0          0
# 9           Evanilson        F     Fluminense         2          0
# 10       Marcos Paulo        F     Fluminense         1          0
# 11   Wellington Silva        M     Fluminense         0          0
# 12        Yago Felipe        M     Fluminense         0          0
# 13              Ganso        M     Fluminense         0          0
# 14      Luiz Henrique        F     Fluminense         1          0
# 15      Marcelo Lomba        G  Internacional         0          0
# 16      Renzo Saravia        D  Internacional         4          1
# 17         Zé Gabriel        D  Internacional         6          0
# 18      Víctor Cuesta        D  Internacional         3          0
# 19             Moisés        D  Internacional         2          0
# 20          Edenílson        M  Internacional         3          0
# 21    Rodrigo Lindoso        M  Internacional         2          1
# 22            Patrick        M  Internacional         1          1
# 23  Gabriel Boschilia        M  Internacional         0          0
# 24     Paolo Guerrero        F  Internacional         0          0
# 25    Thiago Galhardo        F  Internacional         1          0
# 26   Marcos Guilherme        M  Internacional         1          0
# 27       Damián Musto        M  Internacional         1          0
# 28             Peglow        F  Internacional         3          0
# 29    William Pottker        F  Internacional         0          0
# 30       Yuri Alberto        F  Internacional         0          0
#
#     interceptações
# 0                0
# 1                0
# 2                4
# 3                2
# 4                0
# 5                2
# 6                0
# 7                3
# 8                0
# 9                1
# 10               0
# 11               1
# 12               0
# 13               0
# 14               0
# 15               0
# 16               1
# 17               1
# 18               0
# 19               1
# 20               0
# 21               2
# 22               1
# 23               0
# 24               0
# 25               0
# 26               0
# 27               0
# 28               0
# 29               0
# 30               0

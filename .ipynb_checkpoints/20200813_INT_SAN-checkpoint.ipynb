# %% [markdown]
# # INTERNACIONAL X SANTOS DATA ANALYSIS

# %% [markdown]
# The objective of this analyisis is to work on data of brazilian football match between Internacional and Santos, played on 2020 August 13th, and understand how data from the match can explain the result of the match

# %% [markdown]
# Find the commented video analysis for this match on my youtube channel, here: https://youtu.be/3g84LvfyKyg

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/teams/league/1396", headers=headers)

res = conn.getresponse()
data = res.read()


team=json.loads(data.decode("utf-8"))
team
# Out:
# {'api': {'results': 20,
#   'teams': [{'team_id': 127,
#     'name': 'Flamengo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/127.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1895,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 1062,
#     'name': 'Atletico-MG',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/1062.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1908,
#     'venue_name': 'Estádio Raimundo Sampaio',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Ismênia Tunes, Bairro Horto',
#     'venue_city': 'Belo Horizonte, Minas Gerais',
#     'venue_capacity': 23018},
#    {'team_id': 120,
#     'name': 'Botafogo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/120.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1904,
#     'venue_name': 'Estádio Nilton Santos',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Arquias Cordeiro, Engenho de Dentro',
#     'venue_city': 'Rio de Janeiro',
#     'venue_capacity': 46931},
#    {'team_id': 118,
#     'name': 'Bahia',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/118.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1931,
#     'venue_name': 'Arena Fonte Nova',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Lions Club, Nazaré',
#     'venue_city': 'Salvador, Bahia',
#     'venue_capacity': 56500},
#    {'team_id': 121,
#     'name': 'Palmeiras',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/121.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Allianz Parque',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Turiaçu 1840, Perdizes',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 43713},
#    {'team_id': 133,
#     'name': 'Vasco DA Gama',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/133.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1898,
#     'venue_name': 'Estádio Club de Regatas Vasco da Gama',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Gal Almério de Moura 131, Bairro Vasco da Gama',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 22076},
#    {'team_id': 128,
#     'name': 'Santos',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/128.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1912,
#     'venue_name': 'Nickerie Stadion',
#     'venue_surface': 'grass',
#     'venue_address': 'F. O. Lashleystraat',
#     'venue_city': 'Nieuw Nickerie',
#     'venue_capacity': 3400},
#    {'team_id': 794,
#     'name': 'Bragantino',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/794.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1928,
#     'venue_name': 'Estádio Nabi Abi Chedid',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Emílio Coleta',
#     'venue_city': 'Bragança Paulista, São Paulo',
#     'venue_capacity': 17128},
#    {'team_id': 131,
#     'name': 'Corinthians',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/131.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1910,
#     'venue_name': 'Arena Corinthians',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Miguel Inácio Curi, 111, Vila Carmosina, Itaquera',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 47605},
#    {'team_id': 144,
#     'name': 'Atletico Goianiense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/144.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1937,
#     'venue_name': 'Estádio Antônio Accioly',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Perimetral 923 / Avenida 24 de Outubro, Bairro Campinas',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10525},
#    {'team_id': 130,
#     'name': 'Gremio',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/130.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1903,
#     'venue_name': 'Arena do Grêmio',
#     'venue_surface': 'grass',
#     'venue_address': 'Bairro Humaitá',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 60540},
#    {'team_id': 124,
#     'name': 'Fluminense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/124.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1902,
#     'venue_name': 'Estadio Jornalista Mário Filho (Maracanã)',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Professor Eurico Rabelo, Maracanã',
#     'venue_city': 'Rio de Janeiro, Rio de Janeiro',
#     'venue_capacity': 78838},
#    {'team_id': 123,
#     'name': 'Sport Recife',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/123.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1905,
#     'venue_name': 'Estádio Adelmar da Costa Carvalho',
#     'venue_surface': 'grass',
#     'venue_address': 'Praça da Bandeira',
#     'venue_city': 'Recife, Pernambuco',
#     'venue_capacity': 32983},
#    {'team_id': 129,
#     'name': 'Ceara',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/129.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1914,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 147,
#     'name': 'Coritiba',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/147.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio Major Antônio Couto Pereira',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Ubaldino do Amaral 37, Bairro Alto da Glória',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 45563},
#    {'team_id': 119,
#     'name': 'Internacional',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/119.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1909,
#     'venue_name': 'Estádio José Pinheiro Borda',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus',
#     'venue_city': 'Porto Alegre, Rio Grande do Sul',
#     'venue_capacity': 50128},
#    {'team_id': 154,
#     'name': 'Fortaleza EC',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/154.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1918,
#     'venue_name': 'Estádio Governador Plácido Aderaldo Castelo',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Alberto Craveiro, Passaré',
#     'venue_city': 'Fortaleza, Ceará',
#     'venue_capacity': 63903},
#    {'team_id': 134,
#     'name': 'Atletico Paranaense',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/134.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1924,
#     'venue_name': 'Estádio Joaquim Américo Guimarães',
#     'venue_surface': 'grass',
#     'venue_address': 'Rua Buenos Aires 1260, Água Verde',
#     'venue_city': 'Curitiba, Paraná',
#     'venue_capacity': 43981},
#    {'team_id': 151,
#     'name': 'Goias',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/151.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1943,
#     'venue_name': 'Estádio de Hailé Pinheiro',
#     'venue_surface': 'grass',
#     'venue_address': 'Avenida Edmundo Pinheiro de Abreu 721, Setor Bela Vista',
#     'venue_city': 'Goiânia, Goiás',
#     'venue_capacity': 10000},
#    {'team_id': 126,
#     'name': 'Sao Paulo',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/126.png',
#     'country': 'Brazil',
#     'is_national': False,
#     'founded': 1930,
#     'venue_name': 'Estádio Cícero Pompeu de Toledo (Morumbi)',
#     'venue_surface': 'grass',
#     'venue_address': 'Praca Roberto Gomes Pedrosa 1, Morumbi',
#     'venue_city': 'São Paulo, São Paulo',
#     'venue_capacity': 73501}]}}

# %%
inter_data = list(filter(lambda p: p['name'] in ['Internacional'],team['api']['teams']))
inter_data
# Out:
# [{'team_id': 119,
#   'name': 'Internacional',
#   'code': None,
#   'logo': 'https://media.api-sports.io/football/teams/119.png',
#   'country': 'Brazil',
#   'is_national': False,
#   'founded': 1909,
#   'venue_name': 'Estádio José Pinheiro Borda',
#   'venue_surface': 'grass',
#   'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus',
#   'venue_city': 'Porto Alegre, Rio Grande do Sul',
#   'venue_capacity': 50128}]

# %%
#find last fixture
import http.client
import json
import pandas as pd
import numpy as np

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/fixtures/team/119/last/2", headers=headers)

res = conn.getresponse()
data = res.read()

fix=json.loads(data.decode("utf-8"))
fix = fix['api']['fixtures'][1]
with open('20200813_ago_fla_fix.txt','w') as outfile:
    json.dump(fix,outfile)
fix
# Out:
# {'fixture_id': 328000,
#  'league_id': 1396,
#  'league': {'name': 'Serie A',
#   'country': 'Brazil',
#   'logo': 'https://media.api-sports.io/football/leagues/71.png',
#   'flag': 'https://media.api-sports.io/flags/br.svg'},
#  'event_date': '2020-08-13T22:30:00+00:00',
#  'event_timestamp': 1597357800,
#  'firstHalfStart': 1597357800,
#  'secondHalfStart': 1597361400,
#  'round': 'Regular Season - 2',
#  'status': 'Match Finished',
#  'statusShort': 'FT',
#  'elapsed': 90,
#  'venue': 'Estádio José Pinheiro Borda',
#  'referee': 'Marcelo de Lima Henrique',
#  'homeTeam': {'team_id': 119,
#   'team_name': 'Internacional',
#   'logo': 'https://media.api-sports.io/football/teams/119.png'},
#  'awayTeam': {'team_id': 128,
#   'team_name': 'Santos',
#   'logo': 'https://media.api-sports.io/football/teams/128.png'},
#  'goalsHomeTeam': 2,
#  'goalsAwayTeam': 0,
#  'score': {'halftime': '0-0',
#   'fulltime': '2-0',
#   'extratime': None,
#   'penalty': None}}

# %%
#Request statistical data from fixture
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/statistics/fixture/328000/", headers=headers)

res = conn.getresponse()
data = res.read()

match=json.loads(data.decode("utf-8"))
with open('20200813_int_san_fixstat.txt','w') as outfile:
    json.dump(fix,outfile)
match
# Out:
# {'api': {'results': 16,
#   'statistics': {'Shots on Goal': {'home': '7', 'away': '1'},
#    'Shots off Goal': {'home': '13', 'away': '3'},
#    'Total Shots': {'home': '25', 'away': '6'},
#    'Blocked Shots': {'home': '5', 'away': '2'},
#    'Shots insidebox': {'home': '15', 'away': '4'},
#    'Shots outsidebox': {'home': '10', 'away': '2'},
#    'Fouls': {'home': '28', 'away': '14'},
#    'Corner Kicks': {'home': '9', 'away': '4'},
#    'Offsides': {'home': '2', 'away': '2'},
#    'Ball Possession': {'home': '58%', 'away': '42%'},
#    'Yellow Cards': {'home': '2', 'away': '3'},
#    'Red Cards': {'home': None, 'away': None},
#    'Goalkeeper Saves': {'home': '1', 'away': '5'},
#    'Total passes': {'home': '514', 'away': '374'},
#    'Passes accurate': {'home': '432', 'away': '297'},
#    'Passes %': {'home': '84%', 'away': '79%'}}}}

# %%
#Request statistical data from players on fixture
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/players/fixture/328000", headers=headers)

res = conn.getresponse()
data = res.read()

match_palyers=json.loads(data.decode("utf-8"))
with open('20200813_int_san_plrstats.txt','w') as outfile:
    json.dump(match_palyers,outfile)
match_palyers
# Out:
# {'api': {'results': 30,
#   'players': [{'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10372,
#     'player_name': 'Marcelo Lomba',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 12,
#     'position': 'G',
#     'rating': '7.2',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 1},
#     'passes': {'total': 20, 'key': 0, 'accuracy': 80},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 2470,
#     'player_name': 'Renzo Saravia',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 26,
#     'position': 'D',
#     'rating': '7.7',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 1, 'saves': 0},
#     'passes': {'total': 33, 'key': 2, 'accuracy': 84},
#     'tackles': {'total': 4, 'blocks': 0, 'interceptions': 3},
#     'duels': {'total': 12, 'won': 6},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 3},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10379,
#     'player_name': 'Bruno Fuchs',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 3,
#     'position': 'D',
#     'rating': '7.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 50, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 3},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10377,
#     'player_name': 'Víctor Cuesta',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 15,
#     'position': 'D',
#     'rating': '7.2',
#     'minutes_played': 90,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 53, 'key': 0, 'accuracy': 85},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 5, 'won': 3},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10013,
#     'player_name': 'Moisés',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 16,
#     'position': 'D',
#     'rating': '7.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 47, 'key': 2, 'accuracy': 92},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 12, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 7},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10387,
#     'player_name': 'Edenílson',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 8,
#     'position': 'M',
#     'rating': '8.0',
#     'minutes_played': 89,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 6, 'on': 2},
#     'goals': {'total': 1, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 42, 'key': 0, 'accuracy': 85},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 6, 'won': 4},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 2},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10395,
#     'player_name': 'Rodrigo Lindoso',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 19,
#     'position': 'M',
#     'rating': '7.2',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 68, 'key': 3, 'accuracy': 91},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 12, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 3},
#     'fouls': {'drawn': 0, 'committed': 5},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10388,
#     'player_name': 'Patrick',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 88,
#     'position': 'M',
#     'rating': '7.6',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 3, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 25, 'key': 2, 'accuracy': 71},
#     'tackles': {'total': 6, 'blocks': 0, 'interceptions': 3},
#     'duels': {'total': 23, 'won': 11},
#     'dribbles': {'attempts': 5, 'success': 4, 'past': 4},
#     'fouls': {'drawn': 0, 'committed': 5},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 21093,
#     'player_name': 'Gabriel Boschilia',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 21,
#     'position': 'M',
#     'rating': '7.2',
#     'minutes_played': 87,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 4, 'on': 2},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 42, 'key': 2, 'accuracy': 82},
#     'tackles': {'total': 2, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 10, 'won': 4},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10401,
#     'player_name': 'Paolo Guerrero',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 9,
#     'position': 'F',
#     'rating': '8.9',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': 2,
#     'shots': {'total': 6, 'on': 2},
#     'goals': {'total': 1, 'conceded': 0, 'assists': 1, 'saves': 0},
#     'passes': {'total': 17, 'key': 4, 'accuracy': 68},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 27, 'won': 10},
#     'dribbles': {'attempts': 3, 'success': 2, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 3},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 80166,
#     'player_name': 'Thiago Galhardo',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 17,
#     'position': 'F',
#     'rating': '6.2',
#     'minutes_played': 79,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 4, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 17, 'key': 2, 'accuracy': 77},
#     'tackles': {'total': 1, 'blocks': 1, 'interceptions': 0},
#     'duels': {'total': 12, 'won': 7},
#     'dribbles': {'attempts': 4, 'success': 3, 'past': 0},
#     'fouls': {'drawn': 2, 'committed': 3},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 44492,
#     'player_name': 'Marcos Guilherme',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 23,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 9,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 5, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 47577,
#     'player_name': 'Damián Musto',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 5,
#     'position': 'M',
#     'rating': '7.0',
#     'minutes_played': 11,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 11, 'key': 1, 'accuracy': 84},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 2},
#     'duels': {'total': 5, 'won': 3},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10391,
#     'player_name': "Andres D'Alessandro",
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'number': 10,
#     'position': 'M',
#     'rating': '–',
#     'minutes_played': 1,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 2, 'key': 0, 'accuracy': 100},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 2, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10508,
#     'player_name': 'Vladimir',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 1,
#     'position': 'G',
#     'rating': '7.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 2, 'assists': 0, 'saves': 5},
#     'passes': {'total': 25, 'key': 0, 'accuracy': 92},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9991,
#     'player_name': 'Lucas Veríssimo',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 28,
#     'position': 'D',
#     'rating': '7.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 38, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 4},
#     'duels': {'total': 13, 'won': 8},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 1},
#     'fouls': {'drawn': 0, 'committed': 3},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9986,
#     'player_name': 'Luiz Felipe',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 2,
#     'position': 'D',
#     'rating': '6.7',
#     'minutes_played': 16,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 4, 'key': 0, 'accuracy': 80},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 2, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 71,
#     'player_name': 'Luan Peres',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 14,
#     'position': 'D',
#     'rating': '7.3',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 30, 'key': 0, 'accuracy': 78},
#     'tackles': {'total': 2, 'blocks': 2, 'interceptions': 1},
#     'duels': {'total': 10, 'won': 8},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 2, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10162,
#     'player_name': 'Pará',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 4,
#     'position': 'M',
#     'rating': '6.5',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 34, 'key': 0, 'accuracy': 79},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 0},
#     'duels': {'total': 12, 'won': 5},
#     'dribbles': {'attempts': 3, 'success': 3, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10000,
#     'player_name': 'Carlos Sánchez',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 7,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 45,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 8, 'key': 1, 'accuracy': 57},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 8, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 3, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9995,
#     'player_name': 'Alison',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 5,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 65,
#     'captain': 'True',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 18, 'key': 0, 'accuracy': 72},
#     'tackles': {'total': 1, 'blocks': 1, 'interceptions': 0},
#     'duels': {'total': 6, 'won': 2},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9987,
#     'player_name': 'Diego Pituca',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 21,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 45,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 13, 'key': 0, 'accuracy': 72},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 1, 'won': 1},
#     'dribbles': {'attempts': 0, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9989,
#     'player_name': 'Felipe Jonatan',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 3,
#     'position': 'M',
#     'rating': '6.3',
#     'minutes_played': 66,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 22, 'key': 0, 'accuracy': 73},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 7, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 1},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10506,
#     'player_name': 'Marinho',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 11,
#     'position': 'F',
#     'rating': '6.9',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 1},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 13, 'key': 3, 'accuracy': 81},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 26, 'won': 14},
#     'dribbles': {'attempts': 7, 'success': 2, 'past': 1},
#     'fouls': {'drawn': 11, 'committed': 1},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 2454,
#     'player_name': 'Yeferson Soteldo',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 10,
#     'position': 'F',
#     'rating': '7.0',
#     'minutes_played': 90,
#     'captain': 'False',
#     'substitute': 'False',
#     'offsides': 1,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 18, 'key': 1, 'accuracy': 78},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 13, 'won': 8},
#     'dribbles': {'attempts': 7, 'success': 5, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10117,
#     'player_name': 'Madson',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 13,
#     'position': 'D',
#     'rating': '6.7',
#     'minutes_played': 24,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': 1,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 13, 'key': 0, 'accuracy': 86},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10002,
#     'player_name': 'Jobson',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 8,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 45,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 29, 'key': 0, 'accuracy': 82},
#     'tackles': {'total': 0, 'blocks': 1, 'interceptions': 2},
#     'duels': {'total': 7, 'won': 2},
#     'dribbles': {'attempts': 1, 'success': 0, 'past': 2},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 9999,
#     'player_name': 'Tailson',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 39,
#     'position': 'M',
#     'rating': '6.7',
#     'minutes_played': 45,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 7, 'key': 0, 'accuracy': 70},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 4, 'won': 3},
#     'dribbles': {'attempts': 2, 'success': 2, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 0},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 133181,
#     'player_name': 'Ivonei Rabelo',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 45,
#     'position': 'M',
#     'rating': '6.6',
#     'minutes_played': 25,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 1, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 12, 'key': 0, 'accuracy': 92},
#     'tackles': {'total': 1, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 5, 'won': 4},
#     'dribbles': {'attempts': 1, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 1},
#     'cards': {'yellow': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}},
#    {'event_id': 328000,
#     'updateAt': 1597400403,
#     'player_id': 10008,
#     'player_name': 'Kaio Jorge',
#     'team_id': 128,
#     'team_name': 'Santos',
#     'number': 19,
#     'position': 'F',
#     'rating': '6.3',
#     'minutes_played': 74,
#     'captain': 'False',
#     'substitute': 'True',
#     'offsides': None,
#     'shots': {'total': 2, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 13, 'key': 0, 'accuracy': 81},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 10, 'won': 3},
#     'dribbles': {'attempts': 3, 'success': 1, 'past': 0},
#     'fouls': {'drawn': 1, 'committed': 2},
#     'cards': {'yellow': 1, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0}}]}}

# %%
times = [fix['homeTeam']['team_name'],fix['awayTeam']['team_name']]
gols = [fix['goalsHomeTeam'],fix['goalsAwayTeam']]
posse = [match['api']['statistics']['Ball Possession']['home'],match['api']['statistics']['Ball Possession']['away']]
chutes = [match['api']['statistics']['Total Shots']['home'],match['api']['statistics']['Total Shots']['away']]
chutes_a_gol = [int(chutes[0])-int(match['api']['statistics']['Shots off Goal']['home'])-int(match['api']['statistics']['Blocked Shots']['home']),
               int(chutes[1])-int(match['api']['statistics']['Shots off Goal']['away'])-int(match['api']['statistics']['Blocked Shots']['away'])]
amarelos = [match['api']['statistics']['Yellow Cards']['home'],match['api']['statistics']['Yellow Cards']['away']]
vermelhos = [match['api']['statistics']['Red Cards']['home'],match['api']['statistics']['Red Cards']['away']]
acerto_passes = [match['api']['statistics']['Passes %']['home'],match['api']['statistics']['Passes %']['away']]
chutes_dentro_area = [match['api']['statistics']['Shots insidebox']['home'],match['api']['statistics']['Shots insidebox']['away']]
chutes_fora_area = [match['api']['statistics']['Shots outsidebox']['home'],match['api']['statistics']['Shots outsidebox']['away']]
faltas = [match['api']['statistics']['Fouls']['home'],match['api']['statistics']['Fouls']['away']]
defesas_goleiro = [match['api']['statistics']['Goalkeeper Saves']['home'],match['api']['statistics']['Goalkeeper Saves']['away']]

# %%
geral = pd.DataFrame([gols, posse, chutes, chutes_a_gol, amarelos, vermelhos, acerto_passes,chutes_dentro_area,chutes_fora_area,
                     faltas,defesas_goleiro],
                     index=['Placar','Posse de bola','Chutes','Chutes no gol','Cartões amarelos','Cartões vermelhos','Passes acertados',
                           'Chutes dentro área','Chutes fora área','Faltas','Defesas do goleiro'],
                    columns = times)
print('Visão Geral')
geral
# Out:
# Visão Geral
#                    Internacional Santos
# Placar                         2      0
# Posse de bola                58%    42%
# Chutes                        25      6
# Chutes no gol                  7      1
# Cartões amarelos               2      3
# Cartões vermelhos           None   None
# Passes acertados             84%    79%
# Chutes dentro área            15      4
# Chutes fora área              10      2
# Faltas                        28     14
# Defesas do goleiro             1      5

# %%
#Players data to dataframe
players_Df = pd.DataFrame(match_palyers['api']['players'])
players_Df
# Out:
#     event_id    updateAt  player_id          player_name  team_id  \
# 0     328000  1597400403      10372        Marcelo Lomba      119
# 1     328000  1597400403       2470        Renzo Saravia      119
# 2     328000  1597400403      10379          Bruno Fuchs      119
# 3     328000  1597400403      10377        Víctor Cuesta      119
# 4     328000  1597400403      10013               Moisés      119
# 5     328000  1597400403      10387            Edenílson      119
# 6     328000  1597400403      10395      Rodrigo Lindoso      119
# 7     328000  1597400403      10388              Patrick      119
# 8     328000  1597400403      21093    Gabriel Boschilia      119
# 9     328000  1597400403      10401       Paolo Guerrero      119
# 10    328000  1597400403      80166      Thiago Galhardo      119
# 11    328000  1597400403      44492     Marcos Guilherme      119
# 12    328000  1597400403      47577         Damián Musto      119
# 13    328000  1597400403      10391  Andres D'Alessandro      119
# 14    328000  1597400403      10508             Vladimir      128
# 15    328000  1597400403       9991      Lucas Veríssimo      128
# 16    328000  1597400403       9986          Luiz Felipe      128
# 17    328000  1597400403         71           Luan Peres      128
# 18    328000  1597400403      10162                 Pará      128
# 19    328000  1597400403      10000       Carlos Sánchez      128
# 20    328000  1597400403       9995               Alison      128
# 21    328000  1597400403       9987         Diego Pituca      128
# 22    328000  1597400403       9989       Felipe Jonatan      128
# 23    328000  1597400403      10506              Marinho      128
# 24    328000  1597400403       2454     Yeferson Soteldo      128
# 25    328000  1597400403      10117               Madson      128
# 26    328000  1597400403      10002               Jobson      128
# 27    328000  1597400403       9999              Tailson      128
# 28    328000  1597400403     133181        Ivonei Rabelo      128
# 29    328000  1597400403      10008           Kaio Jorge      128
#
#         team_name  number position rating  minutes_played  ... offsides  \
# 0   Internacional      12        G    7.2              90  ...      NaN
# 1   Internacional      26        D    7.7              90  ...      NaN
# 2   Internacional       3        D    7.3              90  ...      NaN
# 3   Internacional      15        D    7.2              90  ...      NaN
# 4   Internacional      16        D    7.5              90  ...      NaN
# 5   Internacional       8        M    8.0              89  ...      NaN
# 6   Internacional      19        M    7.2              90  ...      NaN
# 7   Internacional      88        M    7.6              90  ...      NaN
# 8   Internacional      21        M    7.2              87  ...      NaN
# 9   Internacional       9        F    8.9              90  ...      2.0
# 10  Internacional      17        F    6.2              79  ...      NaN
# 11  Internacional      23        M    6.3               9  ...      NaN
# 12  Internacional       5        M    7.0              11  ...      NaN
# 13  Internacional      10        M      –               1  ...      NaN
# 14         Santos       1        G    7.5              90  ...      NaN
# 15         Santos      28        D    7.3              90  ...      NaN
# 16         Santos       2        D    6.7              16  ...      NaN
# 17         Santos      14        D    7.3              90  ...      NaN
# 18         Santos       4        M    6.5              90  ...      NaN
# 19         Santos       7        M    6.6              45  ...      NaN
# 20         Santos       5        M    6.3              65  ...      NaN
# 21         Santos      21        M    6.6              45  ...      NaN
# 22         Santos       3        M    6.3              66  ...      NaN
# 23         Santos      11        F    6.9              90  ...      NaN
# 24         Santos      10        F    7.0              90  ...      1.0
# 25         Santos      13        D    6.7              24  ...      1.0
# 26         Santos       8        M    6.7              45  ...      NaN
# 27         Santos      39        M    6.7              45  ...      NaN
# 28         Santos      45        M    6.6              25  ...      NaN
# 29         Santos      19        F    6.3              74  ...      NaN
#
#                     shots                                              goals  \
# 0   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 1   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 1, 'sav...
# 2   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 6, 'on': 2}  {'total': 1, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 3, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 4, 'on': 2}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 6, 'on': 2}  {'total': 1, 'conceded': 0, 'assists': 1, 'sav...
# 10  {'total': 4, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 2, 'assists': 0, 'sav...
# 15  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 16  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 22  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 1, 'on': 1}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 1, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 2, 'on': 0}  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                      passes  \
# 0   {'total': 20, 'key': 0, 'accuracy': 80}
# 1   {'total': 33, 'key': 2, 'accuracy': 84}
# 2   {'total': 50, 'key': 0, 'accuracy': 82}
# 3   {'total': 53, 'key': 0, 'accuracy': 85}
# 4   {'total': 47, 'key': 2, 'accuracy': 92}
# 5   {'total': 42, 'key': 0, 'accuracy': 85}
# 6   {'total': 68, 'key': 3, 'accuracy': 91}
# 7   {'total': 25, 'key': 2, 'accuracy': 71}
# 8   {'total': 42, 'key': 2, 'accuracy': 82}
# 9   {'total': 17, 'key': 4, 'accuracy': 68}
# 10  {'total': 17, 'key': 2, 'accuracy': 77}
# 11  {'total': 5, 'key': 0, 'accuracy': 100}
# 12  {'total': 11, 'key': 1, 'accuracy': 84}
# 13  {'total': 2, 'key': 0, 'accuracy': 100}
# 14  {'total': 25, 'key': 0, 'accuracy': 92}
# 15  {'total': 38, 'key': 0, 'accuracy': 82}
# 16   {'total': 4, 'key': 0, 'accuracy': 80}
# 17  {'total': 30, 'key': 0, 'accuracy': 78}
# 18  {'total': 34, 'key': 0, 'accuracy': 79}
# 19   {'total': 8, 'key': 1, 'accuracy': 57}
# 20  {'total': 18, 'key': 0, 'accuracy': 72}
# 21  {'total': 13, 'key': 0, 'accuracy': 72}
# 22  {'total': 22, 'key': 0, 'accuracy': 73}
# 23  {'total': 13, 'key': 3, 'accuracy': 81}
# 24  {'total': 18, 'key': 1, 'accuracy': 78}
# 25  {'total': 13, 'key': 0, 'accuracy': 86}
# 26  {'total': 29, 'key': 0, 'accuracy': 82}
# 27   {'total': 7, 'key': 0, 'accuracy': 70}
# 28  {'total': 12, 'key': 0, 'accuracy': 92}
# 29  {'total': 13, 'key': 0, 'accuracy': 81}
#
#                                           tackles                     duels  \
# 0   {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 1   {'total': 4, 'blocks': 0, 'interceptions': 3}   {'total': 12, 'won': 6}
# 2   {'total': 1, 'blocks': 0, 'interceptions': 3}    {'total': 1, 'won': 1}
# 3   {'total': 1, 'blocks': 0, 'interceptions': 2}    {'total': 5, 'won': 3}
# 4   {'total': 1, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 4}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 6, 'won': 4}
# 6   {'total': 2, 'blocks': 0, 'interceptions': 1}   {'total': 12, 'won': 4}
# 7   {'total': 6, 'blocks': 0, 'interceptions': 3}  {'total': 23, 'won': 11}
# 8   {'total': 2, 'blocks': 0, 'interceptions': 0}   {'total': 10, 'won': 4}
# 9   {'total': 1, 'blocks': 0, 'interceptions': 1}  {'total': 27, 'won': 10}
# 10  {'total': 1, 'blocks': 1, 'interceptions': 0}   {'total': 12, 'won': 7}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 12  {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 5, 'won': 3}
# 13  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 14  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 15  {'total': 1, 'blocks': 0, 'interceptions': 4}   {'total': 13, 'won': 8}
# 16  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 17  {'total': 2, 'blocks': 2, 'interceptions': 1}   {'total': 10, 'won': 8}
# 18  {'total': 0, 'blocks': 1, 'interceptions': 0}   {'total': 12, 'won': 5}
# 19  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 8, 'won': 4}
# 20  {'total': 1, 'blocks': 1, 'interceptions': 0}    {'total': 6, 'won': 2}
# 21  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 22  {'total': 0, 'blocks': 0, 'interceptions': 2}    {'total': 7, 'won': 2}
# 23  {'total': 1, 'blocks': 0, 'interceptions': 0}  {'total': 26, 'won': 14}
# 24  {'total': 1, 'blocks': 0, 'interceptions': 0}   {'total': 13, 'won': 8}
# 25  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 4}
# 26  {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 7, 'won': 2}
# 27  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 4, 'won': 3}
# 28  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 4}
# 29  {'total': 0, 'blocks': 0, 'interceptions': 0}   {'total': 10, 'won': 3}
#
#                                     dribbles                          fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 1   {'attempts': 1, 'success': 1, 'past': 3}   {'drawn': 1, 'committed': 1}
# 2   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 3   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 4   {'attempts': 1, 'success': 1, 'past': 0}   {'drawn': 0, 'committed': 7}
# 5   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 2, 'committed': 2}
# 6   {'attempts': 1, 'success': 1, 'past': 3}   {'drawn': 0, 'committed': 5}
# 7   {'attempts': 5, 'success': 4, 'past': 4}   {'drawn': 0, 'committed': 5}
# 8   {'attempts': 0, 'success': 0, 'past': 2}   {'drawn': 1, 'committed': 1}
# 9   {'attempts': 3, 'success': 2, 'past': 1}   {'drawn': 3, 'committed': 3}
# 10  {'attempts': 4, 'success': 3, 'past': 0}   {'drawn': 2, 'committed': 3}
# 11  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 12  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 3, 'committed': 1}
# 13  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 0, 'committed': 0}
# 14  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 15  {'attempts': 1, 'success': 1, 'past': 1}   {'drawn': 0, 'committed': 3}
# 16  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 17  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 2, 'committed': 0}
# 18  {'attempts': 3, 'success': 3, 'past': 2}   {'drawn': 1, 'committed': 2}
# 19  {'attempts': 1, 'success': 0, 'past': 1}   {'drawn': 3, 'committed': 0}
# 20  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 1, 'committed': 2}
# 21  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 22  {'attempts': 1, 'success': 0, 'past': 1}   {'drawn': 1, 'committed': 1}
# 23  {'attempts': 7, 'success': 2, 'past': 1}  {'drawn': 11, 'committed': 1}
# 24  {'attempts': 7, 'success': 5, 'past': 2}   {'drawn': 1, 'committed': 1}
# 25  {'attempts': 1, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 26  {'attempts': 1, 'success': 0, 'past': 2}   {'drawn': 1, 'committed': 1}
# 27  {'attempts': 2, 'success': 2, 'past': 0}   {'drawn': 1, 'committed': 0}
# 28  {'attempts': 1, 'success': 1, 'past': 0}   {'drawn': 1, 'committed': 1}
# 29  {'attempts': 3, 'success': 1, 'past': 0}   {'drawn': 1, 'committed': 2}
#
#                       cards                                            penalty
# 0   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 1   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 2   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 3   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 4   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 5   {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 6   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 7   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 8   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 9   {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 10  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 11  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 12  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 13  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 14  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 15  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 16  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 17  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 18  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 19  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 20  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 21  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 22  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 23  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 24  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 25  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 26  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 27  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 28  {'yellow': 0, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
# 29  {'yellow': 1, 'red': 0}  {'won': 0, 'commited': 0, 'success': 0, 'misse...
#
# [30 rows x 22 columns]

# %%
#Open shots data to columns
shots_Df = pd.DataFrame(players_Df['shots'])
shots_rows = []
for r in range(0,len(shots_Df)):
    shots_rows.append(list(shots_Df.loc[r,'shots'].values()))
    
open_shots = pd.DataFrame(shots_rows,columns=['total shots','on goal'])
n_players_Df = pd.concat([players_Df,open_shots],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id          player_name  team_id  \
# 0     328000  1597400403      10372        Marcelo Lomba      119
# 1     328000  1597400403       2470        Renzo Saravia      119
# 2     328000  1597400403      10379          Bruno Fuchs      119
# 3     328000  1597400403      10377        Víctor Cuesta      119
# 4     328000  1597400403      10013               Moisés      119
# 5     328000  1597400403      10387            Edenílson      119
# 6     328000  1597400403      10395      Rodrigo Lindoso      119
# 7     328000  1597400403      10388              Patrick      119
# 8     328000  1597400403      21093    Gabriel Boschilia      119
# 9     328000  1597400403      10401       Paolo Guerrero      119
# 10    328000  1597400403      80166      Thiago Galhardo      119
# 11    328000  1597400403      44492     Marcos Guilherme      119
# 12    328000  1597400403      47577         Damián Musto      119
# 13    328000  1597400403      10391  Andres D'Alessandro      119
# 14    328000  1597400403      10508             Vladimir      128
# 15    328000  1597400403       9991      Lucas Veríssimo      128
# 16    328000  1597400403       9986          Luiz Felipe      128
# 17    328000  1597400403         71           Luan Peres      128
# 18    328000  1597400403      10162                 Pará      128
# 19    328000  1597400403      10000       Carlos Sánchez      128
# 20    328000  1597400403       9995               Alison      128
# 21    328000  1597400403       9987         Diego Pituca      128
# 22    328000  1597400403       9989       Felipe Jonatan      128
# 23    328000  1597400403      10506              Marinho      128
# 24    328000  1597400403       2454     Yeferson Soteldo      128
# 25    328000  1597400403      10117               Madson      128
# 26    328000  1597400403      10002               Jobson      128
# 27    328000  1597400403       9999              Tailson      128
# 28    328000  1597400403     133181        Ivonei Rabelo      128
# 29    328000  1597400403      10008           Kaio Jorge      128
#
#         team_name  number position rating  minutes_played  ...  \
# 0   Internacional      12        G    7.2              90  ...
# 1   Internacional      26        D    7.7              90  ...
# 2   Internacional       3        D    7.3              90  ...
# 3   Internacional      15        D    7.2              90  ...
# 4   Internacional      16        D    7.5              90  ...
# 5   Internacional       8        M    8.0              89  ...
# 6   Internacional      19        M    7.2              90  ...
# 7   Internacional      88        M    7.6              90  ...
# 8   Internacional      21        M    7.2              87  ...
# 9   Internacional       9        F    8.9              90  ...
# 10  Internacional      17        F    6.2              79  ...
# 11  Internacional      23        M    6.3               9  ...
# 12  Internacional       5        M    7.0              11  ...
# 13  Internacional      10        M      –               1  ...
# 14         Santos       1        G    7.5              90  ...
# 15         Santos      28        D    7.3              90  ...
# 16         Santos       2        D    6.7              16  ...
# 17         Santos      14        D    7.3              90  ...
# 18         Santos       4        M    6.5              90  ...
# 19         Santos       7        M    6.6              45  ...
# 20         Santos       5        M    6.3              65  ...
# 21         Santos      21        M    6.6              45  ...
# 22         Santos       3        M    6.3              66  ...
# 23         Santos      11        F    6.9              90  ...
# 24         Santos      10        F    7.0              90  ...
# 25         Santos      13        D    6.7              24  ...
# 26         Santos       8        M    6.7              45  ...
# 27         Santos      39        M    6.7              45  ...
# 28         Santos      45        M    6.6              25  ...
# 29         Santos      19        F    6.3              74  ...
#
#                                                 goals  \
# 0   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 1   {'total': 0, 'conceded': 0, 'assists': 1, 'sav...
# 2   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 3   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 4   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 5   {'total': 1, 'conceded': 0, 'assists': 0, 'sav...
# 6   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 7   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 8   {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 9   {'total': 1, 'conceded': 0, 'assists': 1, 'sav...
# 10  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 11  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 12  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 13  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 14  {'total': 0, 'conceded': 2, 'assists': 0, 'sav...
# 15  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 16  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 17  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 18  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 19  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 20  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 21  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 22  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 23  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 24  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 25  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 26  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 27  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 28  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
# 29  {'total': 0, 'conceded': 0, 'assists': 0, 'sav...
#
#                                      passes  \
# 0   {'total': 20, 'key': 0, 'accuracy': 80}
# 1   {'total': 33, 'key': 2, 'accuracy': 84}
# 2   {'total': 50, 'key': 0, 'accuracy': 82}
# 3   {'total': 53, 'key': 0, 'accuracy': 85}
# 4   {'total': 47, 'key': 2, 'accuracy': 92}
# 5   {'total': 42, 'key': 0, 'accuracy': 85}
# 6   {'total': 68, 'key': 3, 'accuracy': 91}
# 7   {'total': 25, 'key': 2, 'accuracy': 71}
# 8   {'total': 42, 'key': 2, 'accuracy': 82}
# 9   {'total': 17, 'key': 4, 'accuracy': 68}
# 10  {'total': 17, 'key': 2, 'accuracy': 77}
# 11  {'total': 5, 'key': 0, 'accuracy': 100}
# 12  {'total': 11, 'key': 1, 'accuracy': 84}
# 13  {'total': 2, 'key': 0, 'accuracy': 100}
# 14  {'total': 25, 'key': 0, 'accuracy': 92}
# 15  {'total': 38, 'key': 0, 'accuracy': 82}
# 16   {'total': 4, 'key': 0, 'accuracy': 80}
# 17  {'total': 30, 'key': 0, 'accuracy': 78}
# 18  {'total': 34, 'key': 0, 'accuracy': 79}
# 19   {'total': 8, 'key': 1, 'accuracy': 57}
# 20  {'total': 18, 'key': 0, 'accuracy': 72}
# 21  {'total': 13, 'key': 0, 'accuracy': 72}
# 22  {'total': 22, 'key': 0, 'accuracy': 73}
# 23  {'total': 13, 'key': 3, 'accuracy': 81}
# 24  {'total': 18, 'key': 1, 'accuracy': 78}
# 25  {'total': 13, 'key': 0, 'accuracy': 86}
# 26  {'total': 29, 'key': 0, 'accuracy': 82}
# 27   {'total': 7, 'key': 0, 'accuracy': 70}
# 28  {'total': 12, 'key': 0, 'accuracy': 92}
# 29  {'total': 13, 'key': 0, 'accuracy': 81}
#
#                                           tackles                     duels  \
# 0   {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 1   {'total': 4, 'blocks': 0, 'interceptions': 3}   {'total': 12, 'won': 6}
# 2   {'total': 1, 'blocks': 0, 'interceptions': 3}    {'total': 1, 'won': 1}
# 3   {'total': 1, 'blocks': 0, 'interceptions': 2}    {'total': 5, 'won': 3}
# 4   {'total': 1, 'blocks': 0, 'interceptions': 0}   {'total': 12, 'won': 4}
# 5   {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 6, 'won': 4}
# 6   {'total': 2, 'blocks': 0, 'interceptions': 1}   {'total': 12, 'won': 4}
# 7   {'total': 6, 'blocks': 0, 'interceptions': 3}  {'total': 23, 'won': 11}
# 8   {'total': 2, 'blocks': 0, 'interceptions': 0}   {'total': 10, 'won': 4}
# 9   {'total': 1, 'blocks': 0, 'interceptions': 1}  {'total': 27, 'won': 10}
# 10  {'total': 1, 'blocks': 1, 'interceptions': 0}   {'total': 12, 'won': 7}
# 11  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 0}
# 12  {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 5, 'won': 3}
# 13  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 14  {'total': 0, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 15  {'total': 1, 'blocks': 0, 'interceptions': 4}   {'total': 13, 'won': 8}
# 16  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 2, 'won': 1}
# 17  {'total': 2, 'blocks': 2, 'interceptions': 1}   {'total': 10, 'won': 8}
# 18  {'total': 0, 'blocks': 1, 'interceptions': 0}   {'total': 12, 'won': 5}
# 19  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 8, 'won': 4}
# 20  {'total': 1, 'blocks': 1, 'interceptions': 0}    {'total': 6, 'won': 2}
# 21  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 1, 'won': 1}
# 22  {'total': 0, 'blocks': 0, 'interceptions': 2}    {'total': 7, 'won': 2}
# 23  {'total': 1, 'blocks': 0, 'interceptions': 0}  {'total': 26, 'won': 14}
# 24  {'total': 1, 'blocks': 0, 'interceptions': 0}   {'total': 13, 'won': 8}
# 25  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 4}
# 26  {'total': 0, 'blocks': 1, 'interceptions': 2}    {'total': 7, 'won': 2}
# 27  {'total': 0, 'blocks': 0, 'interceptions': 1}    {'total': 4, 'won': 3}
# 28  {'total': 1, 'blocks': 0, 'interceptions': 0}    {'total': 5, 'won': 4}
# 29  {'total': 0, 'blocks': 0, 'interceptions': 0}   {'total': 10, 'won': 3}
#
#                                     dribbles                          fouls  \
# 0   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 1   {'attempts': 1, 'success': 1, 'past': 3}   {'drawn': 1, 'committed': 1}
# 2   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 3   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 4   {'attempts': 1, 'success': 1, 'past': 0}   {'drawn': 0, 'committed': 7}
# 5   {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 2, 'committed': 2}
# 6   {'attempts': 1, 'success': 1, 'past': 3}   {'drawn': 0, 'committed': 5}
# 7   {'attempts': 5, 'success': 4, 'past': 4}   {'drawn': 0, 'committed': 5}
# 8   {'attempts': 0, 'success': 0, 'past': 2}   {'drawn': 1, 'committed': 1}
# 9   {'attempts': 3, 'success': 2, 'past': 1}   {'drawn': 3, 'committed': 3}
# 10  {'attempts': 4, 'success': 3, 'past': 0}   {'drawn': 2, 'committed': 3}
# 11  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 12  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 3, 'committed': 1}
# 13  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 0, 'committed': 0}
# 14  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 15  {'attempts': 1, 'success': 1, 'past': 1}   {'drawn': 0, 'committed': 3}
# 16  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 17  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 2, 'committed': 0}
# 18  {'attempts': 3, 'success': 3, 'past': 2}   {'drawn': 1, 'committed': 2}
# 19  {'attempts': 1, 'success': 0, 'past': 1}   {'drawn': 3, 'committed': 0}
# 20  {'attempts': 0, 'success': 0, 'past': 1}   {'drawn': 1, 'committed': 2}
# 21  {'attempts': 0, 'success': 0, 'past': 0}   {'drawn': 0, 'committed': 0}
# 22  {'attempts': 1, 'success': 0, 'past': 1}   {'drawn': 1, 'committed': 1}
# 23  {'attempts': 7, 'success': 2, 'past': 1}  {'drawn': 11, 'committed': 1}
# 24  {'attempts': 7, 'success': 5, 'past': 2}   {'drawn': 1, 'committed': 1}
# 25  {'attempts': 1, 'success': 0, 'past': 0}   {'drawn': 1, 'committed': 0}
# 26  {'attempts': 1, 'success': 0, 'past': 2}   {'drawn': 1, 'committed': 1}
# 27  {'attempts': 2, 'success': 2, 'past': 0}   {'drawn': 1, 'committed': 0}
# 28  {'attempts': 1, 'success': 1, 'past': 0}   {'drawn': 1, 'committed': 1}
# 29  {'attempts': 3, 'success': 1, 'past': 0}   {'drawn': 1, 'committed': 2}
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 0, 'red': 0}
# 3   {'yellow': 0, 'red': 0}
# 4   {'yellow': 1, 'red': 0}
# 5   {'yellow': 1, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 0, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 1, 'red': 0}
# 16  {'yellow': 0, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 0, 'red': 0}
# 20  {'yellow': 0, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 1, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 1, 'red': 0}
#
#                                               penalty total shots on goal
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           6       2
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           3       0
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       2
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...           6       2
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       0
#
# [30 rows x 24 columns]

# %%
time = [fix['homeTeam']['team_name'],fix['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
shots_position=[]

for p in position:
    shots_aux = []
    for t in time:
        shots_aux.append(n_players_Df[(n_players_Df['position']==p) & (n_players_Df['team_name']==t)]['total shots'].sum())
        
    shots_position.append(shots_aux)

shots_position_df = pd.DataFrame(shots_position, index=position, columns = time)
print('Shots by team and position')
shots_position_df
# Out:
# Shots by team and position
#    Internacional  Santos
# G              0       0
# D              1       2
# M             14       1
# F             10       3

# %%
#Total shots by player
import seaborn as sns
import matplotlib.pyplot as plt

home_player_shots=n_players_Df[n_players_Df['team_name']==fix['homeTeam']['team_name']][['total shots','player_name','team_name']]
home_player_shots = home_player_shots[home_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
home_graph = sns.barplot(x=home_player_shots['total shots'],y=home_player_shots['player_name'],palette='Reds')
home_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['homeTeam']['team_name'])
plt.xlim(0,6)
plt.show()

away_player_shots=n_players_Df[n_players_Df['team_name']==fix['awayTeam']['team_name']][['total shots','player_name','team_name']]
away_player_shots = away_player_shots[away_player_shots['total shots']>0].sort_values(by=['total shots'],ascending=False)
away_graph = sns.barplot(x=away_player_shots['total shots'],y=away_player_shots['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Chutes a gol',title = 'Chutes a gol por jogador - '+fix['awayTeam']['team_name'])
plt.xlim(0,6)
plt.show()

# %%
#passes
passes_Df = pd.DataFrame(players_Df['passes'])
passes_rows = []
for r in range(0,len(passes_Df)):
    passes_rows.append(list(passes_Df.loc[r,'passes'].values()))
    
open_passes = pd.DataFrame(passes_rows,columns=['total passes','keys','accuracy'])
n_players_Df = pd.concat([n_players_Df,open_passes],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id          player_name  team_id  \
# 0     328000  1597400403      10372        Marcelo Lomba      119
# 1     328000  1597400403       2470        Renzo Saravia      119
# 2     328000  1597400403      10379          Bruno Fuchs      119
# 3     328000  1597400403      10377        Víctor Cuesta      119
# 4     328000  1597400403      10013               Moisés      119
# 5     328000  1597400403      10387            Edenílson      119
# 6     328000  1597400403      10395      Rodrigo Lindoso      119
# 7     328000  1597400403      10388              Patrick      119
# 8     328000  1597400403      21093    Gabriel Boschilia      119
# 9     328000  1597400403      10401       Paolo Guerrero      119
# 10    328000  1597400403      80166      Thiago Galhardo      119
# 11    328000  1597400403      44492     Marcos Guilherme      119
# 12    328000  1597400403      47577         Damián Musto      119
# 13    328000  1597400403      10391  Andres D'Alessandro      119
# 14    328000  1597400403      10508             Vladimir      128
# 15    328000  1597400403       9991      Lucas Veríssimo      128
# 16    328000  1597400403       9986          Luiz Felipe      128
# 17    328000  1597400403         71           Luan Peres      128
# 18    328000  1597400403      10162                 Pará      128
# 19    328000  1597400403      10000       Carlos Sánchez      128
# 20    328000  1597400403       9995               Alison      128
# 21    328000  1597400403       9987         Diego Pituca      128
# 22    328000  1597400403       9989       Felipe Jonatan      128
# 23    328000  1597400403      10506              Marinho      128
# 24    328000  1597400403       2454     Yeferson Soteldo      128
# 25    328000  1597400403      10117               Madson      128
# 26    328000  1597400403      10002               Jobson      128
# 27    328000  1597400403       9999              Tailson      128
# 28    328000  1597400403     133181        Ivonei Rabelo      128
# 29    328000  1597400403      10008           Kaio Jorge      128
#
#         team_name  number position rating  minutes_played  ...  \
# 0   Internacional      12        G    7.2              90  ...
# 1   Internacional      26        D    7.7              90  ...
# 2   Internacional       3        D    7.3              90  ...
# 3   Internacional      15        D    7.2              90  ...
# 4   Internacional      16        D    7.5              90  ...
# 5   Internacional       8        M    8.0              89  ...
# 6   Internacional      19        M    7.2              90  ...
# 7   Internacional      88        M    7.6              90  ...
# 8   Internacional      21        M    7.2              87  ...
# 9   Internacional       9        F    8.9              90  ...
# 10  Internacional      17        F    6.2              79  ...
# 11  Internacional      23        M    6.3               9  ...
# 12  Internacional       5        M    7.0              11  ...
# 13  Internacional      10        M      –               1  ...
# 14         Santos       1        G    7.5              90  ...
# 15         Santos      28        D    7.3              90  ...
# 16         Santos       2        D    6.7              16  ...
# 17         Santos      14        D    7.3              90  ...
# 18         Santos       4        M    6.5              90  ...
# 19         Santos       7        M    6.6              45  ...
# 20         Santos       5        M    6.3              65  ...
# 21         Santos      21        M    6.6              45  ...
# 22         Santos       3        M    6.3              66  ...
# 23         Santos      11        F    6.9              90  ...
# 24         Santos      10        F    7.0              90  ...
# 25         Santos      13        D    6.7              24  ...
# 26         Santos       8        M    6.7              45  ...
# 27         Santos      39        M    6.7              45  ...
# 28         Santos      45        M    6.6              25  ...
# 29         Santos      19        F    6.3              74  ...
#
#                        duels                                  dribbles  \
# 0     {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 1    {'total': 12, 'won': 6}  {'attempts': 1, 'success': 1, 'past': 3}
# 2     {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 3     {'total': 5, 'won': 3}  {'attempts': 0, 'success': 0, 'past': 0}
# 4    {'total': 12, 'won': 4}  {'attempts': 1, 'success': 1, 'past': 0}
# 5     {'total': 6, 'won': 4}  {'attempts': 0, 'success': 0, 'past': 0}
# 6    {'total': 12, 'won': 4}  {'attempts': 1, 'success': 1, 'past': 3}
# 7   {'total': 23, 'won': 11}  {'attempts': 5, 'success': 4, 'past': 4}
# 8    {'total': 10, 'won': 4}  {'attempts': 0, 'success': 0, 'past': 2}
# 9   {'total': 27, 'won': 10}  {'attempts': 3, 'success': 2, 'past': 1}
# 10   {'total': 12, 'won': 7}  {'attempts': 4, 'success': 3, 'past': 0}
# 11    {'total': 1, 'won': 0}  {'attempts': 0, 'success': 0, 'past': 0}
# 12    {'total': 5, 'won': 3}  {'attempts': 0, 'success': 0, 'past': 1}
# 13    {'total': 2, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 1}
# 14    {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 15   {'total': 13, 'won': 8}  {'attempts': 1, 'success': 1, 'past': 1}
# 16    {'total': 2, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 17   {'total': 10, 'won': 8}  {'attempts': 0, 'success': 0, 'past': 1}
# 18   {'total': 12, 'won': 5}  {'attempts': 3, 'success': 3, 'past': 2}
# 19    {'total': 8, 'won': 4}  {'attempts': 1, 'success': 0, 'past': 1}
# 20    {'total': 6, 'won': 2}  {'attempts': 0, 'success': 0, 'past': 1}
# 21    {'total': 1, 'won': 1}  {'attempts': 0, 'success': 0, 'past': 0}
# 22    {'total': 7, 'won': 2}  {'attempts': 1, 'success': 0, 'past': 1}
# 23  {'total': 26, 'won': 14}  {'attempts': 7, 'success': 2, 'past': 1}
# 24   {'total': 13, 'won': 8}  {'attempts': 7, 'success': 5, 'past': 2}
# 25    {'total': 5, 'won': 4}  {'attempts': 1, 'success': 0, 'past': 0}
# 26    {'total': 7, 'won': 2}  {'attempts': 1, 'success': 0, 'past': 2}
# 27    {'total': 4, 'won': 3}  {'attempts': 2, 'success': 2, 'past': 0}
# 28    {'total': 5, 'won': 4}  {'attempts': 1, 'success': 1, 'past': 0}
# 29   {'total': 10, 'won': 3}  {'attempts': 3, 'success': 1, 'past': 0}
#
#                             fouls                    cards  \
# 0    {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 1    {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 2    {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 3    {'drawn': 1, 'committed': 0}  {'yellow': 0, 'red': 0}
# 4    {'drawn': 0, 'committed': 7}  {'yellow': 1, 'red': 0}
# 5    {'drawn': 2, 'committed': 2}  {'yellow': 1, 'red': 0}
# 6    {'drawn': 0, 'committed': 5}  {'yellow': 0, 'red': 0}
# 7    {'drawn': 0, 'committed': 5}  {'yellow': 0, 'red': 0}
# 8    {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 9    {'drawn': 3, 'committed': 3}  {'yellow': 0, 'red': 0}
# 10   {'drawn': 2, 'committed': 3}  {'yellow': 0, 'red': 0}
# 11   {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 12   {'drawn': 3, 'committed': 1}  {'yellow': 0, 'red': 0}
# 13   {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 14   {'drawn': 1, 'committed': 0}  {'yellow': 0, 'red': 0}
# 15   {'drawn': 0, 'committed': 3}  {'yellow': 1, 'red': 0}
# 16   {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 17   {'drawn': 2, 'committed': 0}  {'yellow': 0, 'red': 0}
# 18   {'drawn': 1, 'committed': 2}  {'yellow': 0, 'red': 0}
# 19   {'drawn': 3, 'committed': 0}  {'yellow': 0, 'red': 0}
# 20   {'drawn': 1, 'committed': 2}  {'yellow': 0, 'red': 0}
# 21   {'drawn': 0, 'committed': 0}  {'yellow': 0, 'red': 0}
# 22   {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 23  {'drawn': 11, 'committed': 1}  {'yellow': 1, 'red': 0}
# 24   {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 25   {'drawn': 1, 'committed': 0}  {'yellow': 0, 'red': 0}
# 26   {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 27   {'drawn': 1, 'committed': 0}  {'yellow': 0, 'red': 0}
# 28   {'drawn': 1, 'committed': 1}  {'yellow': 0, 'red': 0}
# 29   {'drawn': 1, 'committed': 2}  {'yellow': 1, 'red': 0}
#
#                                               penalty total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...           6       2
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...           3       0
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       2
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...           6       2
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...           4       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...           0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...           1       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...           2       0
#
#    total passes keys accuracy
# 0            20    0       80
# 1            33    2       84
# 2            50    0       82
# 3            53    0       85
# 4            47    2       92
# 5            42    0       85
# 6            68    3       91
# 7            25    2       71
# 8            42    2       82
# 9            17    4       68
# 10           17    2       77
# 11            5    0      100
# 12           11    1       84
# 13            2    0      100
# 14           25    0       92
# 15           38    0       82
# 16            4    0       80
# 17           30    0       78
# 18           34    0       79
# 19            8    1       57
# 20           18    0       72
# 21           13    0       72
# 22           22    0       73
# 23           13    3       81
# 24           18    1       78
# 25           13    0       86
# 26           29    0       82
# 27            7    0       70
# 28           12    0       92
# 29           13    0       81
#
# [30 rows x 27 columns]

# %%
#passes
time = [fix['homeTeam']['team_name'],fix['awayTeam']['team_name']]
position = list(set(n_players_Df['position']))
columns = ['Home_passes','Home_keys','Home_acc','Away_passes','Away_keys','Away_acc']
passes_position = []

for p in position:
    passes_aux = []
    for t in time:
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['total passes'].sum())
        passes_aux.append(n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)]['keys'].sum())
        
        pass_list=[]
        acc_list=[]
        for i in n_players_Df[(n_players_Df['team_name']==t)& (n_players_Df['position']==p)].index:
            pass_list.append(n_players_Df.loc[i,'total passes'])
            acc_list.append(n_players_Df.loc[i,'accuracy'])
            
        lists = pass_list, acc_list
        passes_aux.append(sum([x * y for x, y in zip(*lists)])/sum(pass_list))
    
    passes_position.append(passes_aux)
    
passes_position_df = pd.DataFrame(passes_position, index=position, columns = columns)
passes_position_df
# Out:
#    Home_passes  Home_keys   Home_acc  Away_passes  Away_keys   Away_acc
# G           20          0  80.000000           25          0  92.000000
# D          183          4  85.797814           85          0  81.105882
# M          195          8  85.133333          143          1  76.587413
# F           34          6  72.500000           44          4  79.772727

# %%
passes_sum = pd.DataFrame([[passes_position_df[columns[0]].sum(),passes_position_df[columns[1]].sum(),passes_position_df[columns[2]].sum(),
                          passes_position_df[columns[3]].sum(),passes_position_df[columns[4]].sum(),passes_position_df[columns[5]].sum()]],
                         index=['Total'],columns = columns)
passes_sum
# Out:
#        Home_passes  Home_keys    Home_acc  Away_passes  Away_keys    Away_acc
# Total          432         18  323.431148          297          5  329.466022

# %%
#Key passes by player
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['homeTeam']['team_name']][['keys','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['keys'],y=home_player_passes['player_name'],palette='Reds')
home_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['homeTeam']['team_name'])
plt.xlim(0,5)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['awayTeam']['team_name']][['keys','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['keys']>0].sort_values(by=['keys'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['keys'],y=away_player_passes['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Passes decisivos',title = 'Passes decisivos por jogador - '+fix['awayTeam']['team_name'])
plt.xlim(0,5)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['homeTeam']['team_name']][['total passes','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['total passes'],y=home_player_passes['player_name'],palette='Reds')
home_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['homeTeam']['team_name'])
plt.xlim(0,80)
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['awayTeam']['team_name']][['total passes','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['total passes']>0].sort_values(by=['total passes'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['total passes'],y=away_player_passes['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Total de passes',title = 'Total de passes por jogador - '+fix['awayTeam']['team_name'])
plt.xlim(0,80)
plt.show()

# %%
home_player_passes=n_players_Df[n_players_Df['team_name']==fix['homeTeam']['team_name']][['accuracy','player_name','team_name']]
home_player_passes = home_player_passes[home_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
home_graph = sns.barplot(x=home_player_passes['accuracy'],y=home_player_passes['player_name'],palette='Reds')
home_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['homeTeam']['team_name'])
plt.show()

away_player_passes=n_players_Df[n_players_Df['team_name']==fix['awayTeam']['team_name']][['accuracy','player_name','team_name']]
away_player_passes = away_player_passes[away_player_passes['accuracy']>0].sort_values(by=['accuracy'],ascending=False)
away_graph = sns.barplot(x=away_player_passes['accuracy'],y=away_player_passes['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='% acerto de passes',title = '% acerto de passes por jogador - '+fix['awayTeam']['team_name'])
plt.show()

# %%
#tackles
tackles_Df = pd.DataFrame(players_Df['tackles'])
tackles_rows = []
for r in range(0,len(tackles_Df)):
    tackles_rows.append(list(tackles_Df.loc[r,'tackles'].values()))
    
open_tackles = pd.DataFrame(tackles_rows,columns=['Desarmes','bloqueios','interceptações'])
n_players_Df = pd.concat([n_players_Df,open_tackles],axis=1)
n_players_Df
# Out:
#     event_id    updateAt  player_id          player_name  team_id  \
# 0     328000  1597400403      10372        Marcelo Lomba      119
# 1     328000  1597400403       2470        Renzo Saravia      119
# 2     328000  1597400403      10379          Bruno Fuchs      119
# 3     328000  1597400403      10377        Víctor Cuesta      119
# 4     328000  1597400403      10013               Moisés      119
# 5     328000  1597400403      10387            Edenílson      119
# 6     328000  1597400403      10395      Rodrigo Lindoso      119
# 7     328000  1597400403      10388              Patrick      119
# 8     328000  1597400403      21093    Gabriel Boschilia      119
# 9     328000  1597400403      10401       Paolo Guerrero      119
# 10    328000  1597400403      80166      Thiago Galhardo      119
# 11    328000  1597400403      44492     Marcos Guilherme      119
# 12    328000  1597400403      47577         Damián Musto      119
# 13    328000  1597400403      10391  Andres D'Alessandro      119
# 14    328000  1597400403      10508             Vladimir      128
# 15    328000  1597400403       9991      Lucas Veríssimo      128
# 16    328000  1597400403       9986          Luiz Felipe      128
# 17    328000  1597400403         71           Luan Peres      128
# 18    328000  1597400403      10162                 Pará      128
# 19    328000  1597400403      10000       Carlos Sánchez      128
# 20    328000  1597400403       9995               Alison      128
# 21    328000  1597400403       9987         Diego Pituca      128
# 22    328000  1597400403       9989       Felipe Jonatan      128
# 23    328000  1597400403      10506              Marinho      128
# 24    328000  1597400403       2454     Yeferson Soteldo      128
# 25    328000  1597400403      10117               Madson      128
# 26    328000  1597400403      10002               Jobson      128
# 27    328000  1597400403       9999              Tailson      128
# 28    328000  1597400403     133181        Ivonei Rabelo      128
# 29    328000  1597400403      10008           Kaio Jorge      128
#
#         team_name  number position rating  minutes_played  ...  \
# 0   Internacional      12        G    7.2              90  ...
# 1   Internacional      26        D    7.7              90  ...
# 2   Internacional       3        D    7.3              90  ...
# 3   Internacional      15        D    7.2              90  ...
# 4   Internacional      16        D    7.5              90  ...
# 5   Internacional       8        M    8.0              89  ...
# 6   Internacional      19        M    7.2              90  ...
# 7   Internacional      88        M    7.6              90  ...
# 8   Internacional      21        M    7.2              87  ...
# 9   Internacional       9        F    8.9              90  ...
# 10  Internacional      17        F    6.2              79  ...
# 11  Internacional      23        M    6.3               9  ...
# 12  Internacional       5        M    7.0              11  ...
# 13  Internacional      10        M      –               1  ...
# 14         Santos       1        G    7.5              90  ...
# 15         Santos      28        D    7.3              90  ...
# 16         Santos       2        D    6.7              16  ...
# 17         Santos      14        D    7.3              90  ...
# 18         Santos       4        M    6.5              90  ...
# 19         Santos       7        M    6.6              45  ...
# 20         Santos       5        M    6.3              65  ...
# 21         Santos      21        M    6.6              45  ...
# 22         Santos       3        M    6.3              66  ...
# 23         Santos      11        F    6.9              90  ...
# 24         Santos      10        F    7.0              90  ...
# 25         Santos      13        D    6.7              24  ...
# 26         Santos       8        M    6.7              45  ...
# 27         Santos      39        M    6.7              45  ...
# 28         Santos      45        M    6.6              25  ...
# 29         Santos      19        F    6.3              74  ...
#
#                       cards  \
# 0   {'yellow': 0, 'red': 0}
# 1   {'yellow': 0, 'red': 0}
# 2   {'yellow': 0, 'red': 0}
# 3   {'yellow': 0, 'red': 0}
# 4   {'yellow': 1, 'red': 0}
# 5   {'yellow': 1, 'red': 0}
# 6   {'yellow': 0, 'red': 0}
# 7   {'yellow': 0, 'red': 0}
# 8   {'yellow': 0, 'red': 0}
# 9   {'yellow': 0, 'red': 0}
# 10  {'yellow': 0, 'red': 0}
# 11  {'yellow': 0, 'red': 0}
# 12  {'yellow': 0, 'red': 0}
# 13  {'yellow': 0, 'red': 0}
# 14  {'yellow': 0, 'red': 0}
# 15  {'yellow': 1, 'red': 0}
# 16  {'yellow': 0, 'red': 0}
# 17  {'yellow': 0, 'red': 0}
# 18  {'yellow': 0, 'red': 0}
# 19  {'yellow': 0, 'red': 0}
# 20  {'yellow': 0, 'red': 0}
# 21  {'yellow': 0, 'red': 0}
# 22  {'yellow': 0, 'red': 0}
# 23  {'yellow': 1, 'red': 0}
# 24  {'yellow': 0, 'red': 0}
# 25  {'yellow': 0, 'red': 0}
# 26  {'yellow': 0, 'red': 0}
# 27  {'yellow': 0, 'red': 0}
# 28  {'yellow': 0, 'red': 0}
# 29  {'yellow': 1, 'red': 0}
#
#                                               penalty  total shots on goal  \
# 0   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 1   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 2   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 3   {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 4   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 5   {'won': 0, 'commited': 0, 'success': 0, 'misse...            6       2
# 6   {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       1
# 7   {'won': 0, 'commited': 0, 'success': 0, 'misse...            3       0
# 8   {'won': 0, 'commited': 0, 'success': 0, 'misse...            4       2
# 9   {'won': 0, 'commited': 0, 'success': 0, 'misse...            6       2
# 10  {'won': 0, 'commited': 0, 'success': 0, 'misse...            4       0
# 11  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 12  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 13  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 14  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 15  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 16  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 17  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 18  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 19  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 20  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 21  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 22  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 23  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       1
# 24  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 25  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 26  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 27  {'won': 0, 'commited': 0, 'success': 0, 'misse...            0       0
# 28  {'won': 0, 'commited': 0, 'success': 0, 'misse...            1       0
# 29  {'won': 0, 'commited': 0, 'success': 0, 'misse...            2       0
#
#    total passes keys accuracy Desarmes bloqueios interceptações
# 0            20    0       80        1         0              0
# 1            33    2       84        4         0              3
# 2            50    0       82        1         0              3
# 3            53    0       85        1         0              2
# 4            47    2       92        1         0              0
# 5            42    0       85        0         0              1
# 6            68    3       91        2         0              1
# 7            25    2       71        6         0              3
# 8            42    2       82        2         0              0
# 9            17    4       68        1         0              1
# 10           17    2       77        1         1              0
# 11            5    0      100        0         0              0
# 12           11    1       84        0         1              2
# 13            2    0      100        1         0              0
# 14           25    0       92        0         0              0
# 15           38    0       82        1         0              4
# 16            4    0       80        1         0              0
# 17           30    0       78        2         2              1
# 18           34    0       79        0         1              0
# 19            8    1       57        1         0              0
# 20           18    0       72        1         1              0
# 21           13    0       72        1         0              0
# 22           22    0       73        0         0              2
# 23           13    3       81        1         0              0
# 24           18    1       78        1         0              0
# 25           13    0       86        1         0              0
# 26           29    0       82        0         1              2
# 27            7    0       70        0         0              1
# 28           12    0       92        1         0              0
# 29           13    0       81        0         0              0
#
# [30 rows x 30 columns]

# %%
tackles_players = n_players_Df[n_players_Df['position']=='D'][['player_name','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players

#Tackles by player
home_player_tackles=tackles_players[n_players_Df['team_name']==fix['homeTeam']['team_name']][['player_name','interceptações','team_name']]
home_player_tackles = home_player_tackles[home_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
home_graph = sns.barplot(x=home_player_tackles['interceptações'],y=home_player_tackles['player_name'],palette='Reds')
home_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['homeTeam']['team_name'])
plt.xlim(0,5)
plt.show()

away_player_tackles=tackles_players[n_players_Df['team_name']==fix['awayTeam']['team_name']][['player_name','interceptações','team_name']]
away_player_tackles = away_player_tackles[away_player_tackles['interceptações']>0].sort_values(by=['interceptações'],ascending=False)
away_graph = sns.barplot(x=away_player_tackles['interceptações'],y=away_player_tackles['player_name'],palette='Greys')
away_graph.set(ylabel='Jogadores',xlabel='Interceptações',title = 'Interceptações por jogador - '+fix['awayTeam']['team_name'])
plt.xlim(0,5)
plt.show()
# Out:
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\jefms\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':

# %%
tackles_players = n_players_Df[['player_name','position','team_name','Desarmes', 'bloqueios','interceptações']]
tackles_players
# Out:
#             player_name position      team_name  Desarmes  bloqueios  \
# 0         Marcelo Lomba        G  Internacional         1          0
# 1         Renzo Saravia        D  Internacional         4          0
# 2           Bruno Fuchs        D  Internacional         1          0
# 3         Víctor Cuesta        D  Internacional         1          0
# 4                Moisés        D  Internacional         1          0
# 5             Edenílson        M  Internacional         0          0
# 6       Rodrigo Lindoso        M  Internacional         2          0
# 7               Patrick        M  Internacional         6          0
# 8     Gabriel Boschilia        M  Internacional         2          0
# 9        Paolo Guerrero        F  Internacional         1          0
# 10      Thiago Galhardo        F  Internacional         1          1
# 11     Marcos Guilherme        M  Internacional         0          0
# 12         Damián Musto        M  Internacional         0          1
# 13  Andres D'Alessandro        M  Internacional         1          0
# 14             Vladimir        G         Santos         0          0
# 15      Lucas Veríssimo        D         Santos         1          0
# 16          Luiz Felipe        D         Santos         1          0
# 17           Luan Peres        D         Santos         2          2
# 18                 Pará        M         Santos         0          1
# 19       Carlos Sánchez        M         Santos         1          0
# 20               Alison        M         Santos         1          1
# 21         Diego Pituca        M         Santos         1          0
# 22       Felipe Jonatan        M         Santos         0          0
# 23              Marinho        F         Santos         1          0
# 24     Yeferson Soteldo        F         Santos         1          0
# 25               Madson        D         Santos         1          0
# 26               Jobson        M         Santos         0          1
# 27              Tailson        M         Santos         0          0
# 28        Ivonei Rabelo        M         Santos         1          0
# 29           Kaio Jorge        F         Santos         0          0
#
#     interceptações
# 0                0
# 1                3
# 2                3
# 3                2
# 4                0
# 5                1
# 6                1
# 7                3
# 8                0
# 9                1
# 10               0
# 11               0
# 12               2
# 13               0
# 14               0
# 15               4
# 16               0
# 17               1
# 18               0
# 19               0
# 20               0
# 21               0
# 22               2
# 23               0
# 24               0
# 25               0
# 26               2
# 27               1
# 28               0
# 29               0

# %% [markdown]
# Paolo Guerrero was the star of the match, socring goal, making assists and many key passes. So, let's compare his numbers from this match with his averages from 2019 season.

# %%
#Paolo Guerrero statistics

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "ffb5742c9dmsh99722e642ef88b5p1ecdc4jsn3a869f379168"
    }

conn.request("GET", "/v2/players/player/10401/2019", headers=headers)

res = conn.getresponse()
data = res.read()

guerrero=json.loads(data.decode("utf-8"))
with open('20200813_int_san_guerrero.txt','w') as outfile:
    json.dump(guerrero,outfile)
guerrero
# Out:
# {'api': {'results': 5,
#   'players': [{'player_id': 10401,
#     'player_name': 'P. Guerrero',
#     'firstname': 'José Paolo',
#     'lastname': 'Guerrero Gonzáles',
#     'number': None,
#     'position': 'Attacker',
#     'age': 36,
#     'birth_date': '01/01/1984',
#     'birth_place': 'Lima',
#     'birth_country': 'Peru',
#     'nationality': 'Peru',
#     'height': '185 cm',
#     'weight': '82 kg',
#     'injured': None,
#     'rating': '7.237500',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'league': 'Serie A',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 81, 'on': 35},
#     'goals': {'total': 10, 'conceded': 0, 'assists': 1, 'saves': 0},
#     'passes': {'total': 462, 'key': 32, 'accuracy': 74},
#     'tackles': {'total': 7, 'blocks': 3, 'interceptions': 1},
#     'duels': {'total': 102, 'won': 41},
#     'dribbles': {'attempts': 36, 'success': 23},
#     'fouls': {'drawn': 43, 'committed': 41},
#     'cards': {'yellow': 3, 'yellowred': 0, 'red': 1},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 1,
#      'saved': 0},
#     'games': {'appearences': 24, 'minutes_played': 2014, 'lineups': 23},
#     'substitutes': {'in': 1, 'out': 4, 'bench': 2}},
#    {'player_id': 10401,
#     'player_name': 'P. Guerrero',
#     'firstname': 'José Paolo',
#     'lastname': 'Guerrero Gonzáles',
#     'number': None,
#     'position': 'Attacker',
#     'age': 36,
#     'birth_date': '01/01/1984',
#     'birth_place': 'Lima',
#     'birth_country': 'Peru',
#     'nationality': 'Peru',
#     'height': '185 cm',
#     'weight': '82 kg',
#     'injured': None,
#     'rating': None,
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'league': 'Gaúcho 1',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 1, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 0, 'key': 0, 'accuracy': 0},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 1, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 3, 'minutes_played': 235, 'lineups': 3},
#     'substitutes': {'in': 0, 'out': 2, 'bench': 0}},
#    {'player_id': 10401,
#     'player_name': 'P. Guerrero',
#     'firstname': 'José Paolo',
#     'lastname': 'Guerrero Gonzáles',
#     'number': None,
#     'position': 'Attacker',
#     'age': 36,
#     'birth_date': '01/01/1984',
#     'birth_place': 'Lima',
#     'birth_country': 'Peru',
#     'nationality': 'Peru',
#     'height': '185 cm',
#     'weight': '82 kg',
#     'injured': None,
#     'rating': '7.650000',
#     'team_id': 119,
#     'team_name': 'Internacional',
#     'league': 'Copa do Brasil',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 24, 'on': 13},
#     'goals': {'total': 5, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 170, 'key': 16, 'accuracy': 73},
#     'tackles': {'total': 4, 'blocks': 0, 'interceptions': 2},
#     'duels': {'total': 85, 'won': 42},
#     'dribbles': {'attempts': 24, 'success': 15},
#     'fouls': {'drawn': 14, 'committed': 19},
#     'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 8, 'minutes_played': 720, 'lineups': 8},
#     'substitutes': {'in': 0, 'out': 1, 'bench': 0}},
#    {'player_id': 10401,
#     'player_name': 'P. Guerrero',
#     'firstname': 'José Paolo',
#     'lastname': 'Guerrero Gonzáles',
#     'number': None,
#     'position': 'Attacker',
#     'age': 36,
#     'birth_date': '01/01/1984',
#     'birth_place': 'Lima',
#     'birth_country': 'Peru',
#     'nationality': 'Peru',
#     'height': '185 cm',
#     'weight': '82 kg',
#     'injured': None,
#     'rating': '7.220000',
#     'team_id': 30,
#     'team_name': 'Peru',
#     'league': 'Copa America',
#     'season': '2019',
#     'captain': 5,
#     'shots': {'total': 11, 'on': 5},
#     'goals': {'total': 3, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 81, 'key': 5, 'accuracy': 68},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 1},
#     'duels': {'total': 83, 'won': 41},
#     'dribbles': {'attempts': 6, 'success': 4},
#     'fouls': {'drawn': 12, 'committed': 12},
#     'cards': {'yellow': 1, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 1,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 6, 'minutes_played': 505, 'lineups': 6},
#     'substitutes': {'in': 0, 'out': 2, 'bench': 0}},
#    {'player_id': 10401,
#     'player_name': 'P. Guerrero',
#     'firstname': 'José Paolo',
#     'lastname': 'Guerrero Gonzáles',
#     'number': None,
#     'position': 'Attacker',
#     'age': 36,
#     'birth_date': '01/01/1984',
#     'birth_place': 'Lima',
#     'birth_country': 'Peru',
#     'nationality': 'Peru',
#     'height': '185 cm',
#     'weight': '82 kg',
#     'injured': None,
#     'rating': None,
#     'team_id': 30,
#     'team_name': 'Peru',
#     'league': 'Friendlies',
#     'season': '2019',
#     'captain': 0,
#     'shots': {'total': 0, 'on': 0},
#     'goals': {'total': 0, 'conceded': 0, 'assists': 0, 'saves': 0},
#     'passes': {'total': 0, 'key': 0, 'accuracy': 0},
#     'tackles': {'total': 0, 'blocks': 0, 'interceptions': 0},
#     'duels': {'total': 0, 'won': 0},
#     'dribbles': {'attempts': 0, 'success': 0},
#     'fouls': {'drawn': 0, 'committed': 0},
#     'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#     'penalty': {'won': 0,
#      'commited': 0,
#      'success': 0,
#      'missed': 0,
#      'saved': 0},
#     'games': {'appearences': 5, 'minutes_played': 384, 'lineups': 4},
#     'substitutes': {'in': 1, 'out': 1, 'bench': 1}}]}}

# %%
guerrero_2019_A = list(filter(lambda p: p['league'] in ['Serie A'],guerrero['api']['players']))
shots = guerrero_2019_A[0]['shots']['total']
goals = guerrero_2019_A[0]['goals']['total']
assists = guerrero_2019_A[0]['goals']['assists']
key_passes = guerrero_2019_A[0]['passes']['key']
dribbles = guerrero_2019_A[0]['dribbles']['success']
appearences = guerrero_2019_A[0]['games']['appearences']
avg_shots = shots / appearences
avg_goals = goals / appearences
avg_assists = assists / appearences
avg_key_passes = key_passes / appearences
avg_dribbles = dribbles / appearences

print('Paolo Guerrero in 2019:')
print('Shots: '+str(round(avg_shots,2)))
print('Goals: '+str(round(avg_goals,2)))
print('Assists: '+str(round(avg_assists,2)))
print('Key passes: '+str(round(avg_key_passes,2)))
print('Dribbles: ' + str(round(avg_dribbles,2)))

print('\n')
print('Paolo Guerrero on match:')
print('Shots: '+str(list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['shots']['total']))
print('Goals: '+str(list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['goals']['total']))
print('Assists: '+str(list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['goals']['assists']))
print('Key passes: '+str(list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['passes']['key']))
print('Dribbles: ' + str(list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['dribbles']['success']))
# Out:
# Paolo Guerrero in 2019:
# Shots: 3.38
# Goals: 0.42
# Assists: 0.04
# Key passes: 1.33
# Dribbles: 0.96
#
#
# Paolo Guerrero on match:
# Shots: 6
# Goals: 1
# Assists: 1
# Key passes: 4
# Dribbles: 2

# %%
list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['shots']['total']
list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['goals']['total']
list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['goals']['assists']
list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['passes']['key']
list(filter(lambda p: p['player_name'] in ['Paolo Guerrero'],match_palyers['api']['players']))[0]['dribbles']['success']
# Out:
# 2
